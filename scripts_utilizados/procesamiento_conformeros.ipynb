# %%
#validacion de la metodología de docking: construccion de una curva ROC
'''Descarga de archivos predeterminados de compuestos activos y decoys en formato smile, los archivos de formato .picked
 y busqueda de el ligando activo utilizado para la construccion de los decoys'''
# Out:
# 'Descarga de archivos predeterminados de compuestos activos y decoys en formato smile, los archivos de formato .picked\n y busqueda de el ligando activo utilizado para la construccion de los decoys'

# %%
import csv
import pandas as pd
import os 
from openbabel import openbabel
import numpy as np
import random 
import subprocess

# %%
#Descarga de decoys desde la base de datos dude
os.system('wget https://dude.docking.org//targets/cdk2/dudgen_clustered/search')
#La salida de esta celda es un archivo de tipo html con la información del total de decoys disponibles en la base de datos
# Out:
# --2023-03-12 16:31:33--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: no especificado [text/html]
# Guardando como: “search.3”
#
#      0K .......... .......... .......... .......... ..........  123K
#     50K .......... .......... .......... .......... ..........  251K
#    100K .......... .......... .......... .......... ..........  260K
#    150K .......... .......... .......... .......... ..........  254K
#    200K .......... .......... .......... .......... ..........  232K
#    250K .......... .......... .......... .......... ..........  237K
#    300K .......... .......... .......... .......... ..........  264K
#    350K .......... .......... .......... .......... ..........  291K
#    400K .......... .......... ....                              670K=1,8s
#
# 2023-03-12 16:31:36 (233 KB/s) - “search.3” guardado [434965]
# 0

# %%
#Extraccion de los archivos .picked donde se almacenan los smiles de decoys y compuestos activos desde el archivo html
picked = []
with open('search.txt', 'r') as csvfile:
    datareader = csv.reader(csvfile)
    for row in datareader:
        if row:
            if row[0].endswith('.picked</a></li>'):
                picked.append(row)

# %%
#Obtencion de las direcciones de los decoys en DUDE
picked_limpios = [(picked[p][0].replace('    <li><img src="https://dude.docking.org//icons/text.gif"> <a href="','')).replace('</a></li>','') for p,picked_file in enumerate(picked)]
picked_limpios_completo = [picked_limpios[p].split('">')[0] for p,picked in enumerate(picked_limpios)]
picked_limpios_completo
# Out:
# ['https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81000100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81001500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81003000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81003100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81003600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81003800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004601.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81005000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81005100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81005200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81006500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81006600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81007000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81007400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81009000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81009500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81011600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81012500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81012501.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81013500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81014000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81014900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81016400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81016800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81016801.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017301.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017401.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81020200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81020300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81021000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81022700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81022800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81023200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81023500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81023800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81024000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81024200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81024400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81024800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81024900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81025000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81025100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81027600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81027601.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81028000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81028100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81028800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81028900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81029200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81029900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81030100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81030500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81030700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81030800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81031300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81035000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81035200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81035201.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81035400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81036200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81036300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81036400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81036700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81036800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81037300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81037302.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81037500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81038400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81038500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81040500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81040700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81042500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81043800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81044600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81044700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81044900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81045000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81045100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81047700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81047800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81048600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81049100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81049200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81051400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81051600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81053700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81054300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81056900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81059400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81061700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81061800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81061900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81062600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81062800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81063000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81063100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81063101.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81066300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81066301.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81069700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81069800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81070000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81071200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81071300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81071600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81071800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81072100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81073600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81074400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81074600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81074800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81075700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81076100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81076200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81076400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81076401.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81076700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81077100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81077400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81078400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81080300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81080600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81083400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81084000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81084400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81084500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81084700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81085200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81085700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81086000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81086200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81087900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81088100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81089600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81091000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81092300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81096800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81096900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81099300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81099400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81099500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81099900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81100400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81101100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81101600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81101700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81101800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81102700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81103500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81103700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81103900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81104300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81105700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81106300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81107700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81108800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81110400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81110600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81110800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81111900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81111901.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81113500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81116100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81116200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81116400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81116600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82000100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82000500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82003300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82003500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82005600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82009900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82011200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82011700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82012100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82012300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82012500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82012700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82013100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82013101.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82013500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82014100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82014101.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82014300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82014301.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82014600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82014601.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82014800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82018300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82018800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82022800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82025100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82025500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82025600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82025900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82026500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82026800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82027000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82027100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82027300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82027400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82027500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82027600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82027700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82027800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82027900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82028000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82028800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82029500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82029600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82029700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82029800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82030100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82030500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82030900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82034300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82034800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82035700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82036000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82038800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91000300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91000500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91001000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91001100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91001400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91001500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91001700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91003100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91005500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91005700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91006400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91006600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91006700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91006900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91007000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91007100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91007200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91007300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91007400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91007600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91007700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91007800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91007900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91009300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91009400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91009500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91009600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91010100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91011300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91011400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91011500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91011700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91011900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91012400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91012700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91012900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91013000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91013200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91013600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91013700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91013800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91014200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91014400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91014600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91014800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91015400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91015500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91015600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91015700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91015800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91016200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91017200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91017500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91017600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91017700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91017800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91017900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91018000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91018100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91018200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91018400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91018500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91018600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91019000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91019200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91019500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91020000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91021300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91021400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91021500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91022700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91023200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91023300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91023500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91023800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91025400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91025800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91027000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91027100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91027400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91027600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91029300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91031200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91031600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91031800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91032100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91032200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91033000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91033200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91033400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91033500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91033600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91033700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91033800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91034000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91034500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91034900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91035400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91036600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91037600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91038100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91038300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91038400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91038500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91039800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91040300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91040500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91040700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91042400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91042500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91042700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91042900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91043100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91043200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91043300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91043400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91043600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91044100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91044200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91044300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91044500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91044900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91045200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91045300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91045500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91046500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91046600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91046800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91047300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91047400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91047500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91047600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91047900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91048400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91048500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91048800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91049000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91049100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91049300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91049900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91050700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91050800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91051800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91051900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91052700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91053000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91053200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91053700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91054100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91054300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91054400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91056500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91056900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91057300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91057700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91058400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91058900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91059000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91059400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91059600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91061900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91062100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91062500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91063400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91064200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91064300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91064400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91064600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91065100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91068500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91068700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91069500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91069700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91069800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91070000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91071200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91071300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91071600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91071800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91072100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91073600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91074400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91074600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91074800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91075700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91076100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91076200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91076400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91076700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91076900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91077000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91077400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91078400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91080300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91080400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91080500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91080600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91081000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91082000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91086800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91087100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91087500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91089100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91089200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91089600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91090000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91090100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91091300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91091500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91091600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91091900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91092200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91092600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91092800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91094100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91094700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91094800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91095000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91095100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91095200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91095300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91095400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91095500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91096000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91096500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91096600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91096700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91096900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91098100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91098200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91098400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91098500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91100500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91101900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91102100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91102400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91102800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91103200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91103300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91103500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91103900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91104300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91104500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91104600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91104700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91104800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91105000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91105700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91105900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91107200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91107700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91110200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91110300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91110400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91112200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91112400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91112800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91113500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91113700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91114700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92000300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92000400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92000500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92000600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92000700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92000800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92000900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92001000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92001100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92002000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92002200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92002300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92002400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92002700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92003300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92003500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92003700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92003800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92005200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92005400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92005600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92006000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92006100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92006300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92007100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92007700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92007900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92008700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92009200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92009400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92009600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92009800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92010200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92010400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92011000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92012100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92012500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92012700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92013300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92014800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92016000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92018800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92019400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92020100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92020700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92021100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92021200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92021800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92022300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92022400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92024500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92024800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92025100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92025200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92030300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92030400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92030600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92030800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92031900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92034500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92034800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92034900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92035000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92035300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92035700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92036800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92037300.picked']

# %%
#descarga de los decoys desde dude 
for picked in picked_limpios_completo:
    os.system(f'wget {picked}')
# Out:
# --2023-03-12 16:23:30--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81000100.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3097 (3,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81000100.picked.1”
#
#      0K ...                                                   100%  673M=0s
#
# 2023-03-12 16:23:31 (673 MB/s) - “decoys.F81000100.picked.1” guardado [3097/3097]
#
# --2023-03-12 16:23:31--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81001500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3962 (3,9K) [application/x-not-regular-file]
# Guardando como: “decoys.F81001500.picked.1”
#
#      0K ...                                                   100%  110M=0s
#
# 2023-03-12 16:23:32 (110 MB/s) - “decoys.F81001500.picked.1” guardado [3962/3962]
#
# --2023-03-12 16:23:32--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81003000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4094 (4,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81003000.picked.1”
#
#      0K ...                                                   100% 59,5M=0s
#
# 2023-03-12 16:23:33 (59,5 MB/s) - “decoys.F81003000.picked.1” guardado [4094/4094]
#
# --2023-03-12 16:23:33--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81003100.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3876 (3,8K) [application/x-not-regular-file]
# Guardando como: “decoys.F81003100.picked.1”
#
#      0K ...                                                   100% 58,7M=0s
#
# 2023-03-12 16:23:34 (58,7 MB/s) - “decoys.F81003100.picked.1” guardado [3876/3876]
#
# --2023-03-12 16:23:34--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81003600.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4965 (4,8K) [application/x-not-regular-file]
# Guardando como: “decoys.F81003600.picked”
#
#      0K ....                                                  100% 14,7M=0s
#
# 2023-03-12 16:23:35 (14,7 MB/s) - “decoys.F81003600.picked” guardado [4965/4965]
#
# --2023-03-12 16:23:35--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81003800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3897 (3,8K) [application/x-not-regular-file]
# Guardando como: “decoys.F81003800.picked.1”
#
#      0K ...                                                   100% 69,5M=0s
#
# 2023-03-12 16:23:36 (69,5 MB/s) - “decoys.F81003800.picked.1” guardado [3897/3897]
#
# --2023-03-12 16:23:36--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4290 (4,2K) [application/x-not-regular-file]
# Guardando como: “decoys.F81004000.picked.1”
#
#      0K ....                                                  100% 39,6M=0s
#
# 2023-03-12 16:23:36 (39,6 MB/s) - “decoys.F81004000.picked.1” guardado [4290/4290]
#
# --2023-03-12 16:23:36--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004400.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4614 (4,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F81004400.picked.1”
#
#      0K ....                                                  100% 24,3M=0s
#
# 2023-03-12 16:23:37 (24,3 MB/s) - “decoys.F81004400.picked.1” guardado [4614/4614]
#
# --2023-03-12 16:23:37--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004600.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4692 (4,6K) [application/x-not-regular-file]
# Guardando como: “decoys.F81004600.picked.1”
#
#      0K ....                                                  100% 69,7M=0s
#
# 2023-03-12 16:23:38 (69,7 MB/s) - “decoys.F81004600.picked.1” guardado [4692/4692]
#
# --2023-03-12 16:23:38--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004601.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4707 (4,6K) [application/x-not-regular-file]
# Guardando como: “decoys.F81004601.picked.1”
#
#      0K ....                                                  100% 21,6M=0s
#
# 2023-03-12 16:23:39 (21,6 MB/s) - “decoys.F81004601.picked.1” guardado [4707/4707]
#
# --2023-03-12 16:23:39--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004700.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3405 (3,3K) [application/x-not-regular-file]
# Guardando como: “decoys.F81004700.picked.1”
#
#      0K ...                                                   100%  852M=0s
#
# 2023-03-12 16:23:40 (852 MB/s) - “decoys.F81004700.picked.1” guardado [3405/3405]
#
# --2023-03-12 16:23:40--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 2960 (2,9K) [application/x-not-regular-file]
# Guardando como: “decoys.F81004800.picked.1”
#
#      0K ..                                                    100%  649M=0s
#
# 2023-03-12 16:23:41 (649 MB/s) - “decoys.F81004800.picked.1” guardado [2960/2960]
#
# --2023-03-12 16:23:41--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81004900.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3121 (3,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81004900.picked.1”
#
#      0K ...                                                   100% 1,39G=0s
#
# 2023-03-12 16:23:41 (1,39 GB/s) - “decoys.F81004900.picked.1” guardado [3121/3121]
#
# --2023-03-12 16:23:41--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81005000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3023 (3,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81005000.picked.1”
#
#      0K ..                                                    100%  599M=0s
#
# 2023-03-12 16:23:42 (599 MB/s) - “decoys.F81005000.picked.1” guardado [3023/3023]
#
# --2023-03-12 16:23:42--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81005100.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3092 (3,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81005100.picked.1”
#
#      0K ...                                                   100% 1,07G=0s
#
# 2023-03-12 16:23:43 (1,07 GB/s) - “decoys.F81005100.picked.1” guardado [3092/3092]
#
# --2023-03-12 16:23:43--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81005200.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3101 (3,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81005200.picked.1”
#
#      0K ...                                                   100%  617M=0s
#
# 2023-03-12 16:23:44 (617 MB/s) - “decoys.F81005200.picked.1” guardado [3101/3101]
#
# --2023-03-12 16:23:44--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81006500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3662 (3,6K) [application/x-not-regular-file]
# Guardando como: “decoys.F81006500.picked.1”
#
#      0K ...                                                   100%  929M=0s
#
# 2023-03-12 16:23:45 (929 MB/s) - “decoys.F81006500.picked.1” guardado [3662/3662]
#
# --2023-03-12 16:23:45--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81006600.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3641 (3,6K) [application/x-not-regular-file]
# Guardando como: “decoys.F81006600.picked.1”
#
#      0K ...                                                   100%  707M=0s
#
# 2023-03-12 16:23:46 (707 MB/s) - “decoys.F81006600.picked.1” guardado [3641/3641]
#
# --2023-03-12 16:23:46--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81007000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3374 (3,3K) [application/x-not-regular-file]
# Guardando como: “decoys.F81007000.picked.1”
#
#      0K ...                                                   100%  606M=0s
#
# 2023-03-12 16:23:46 (606 MB/s) - “decoys.F81007000.picked.1” guardado [3374/3374]
#
# --2023-03-12 16:23:46--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81007400.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3445 (3,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F81007400.picked.1”
#
#      0K ...                                                   100% 1,49G=0s
#
# 2023-03-12 16:23:47 (1,49 GB/s) - “decoys.F81007400.picked.1” guardado [3445/3445]
#
# --2023-03-12 16:23:47--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81009000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 2697 (2,6K) [application/x-not-regular-file]
# Guardando como: “decoys.F81009000.picked.1”
#
#      0K ..                                                    100%  759M=0s
#
# 2023-03-12 16:23:48 (759 MB/s) - “decoys.F81009000.picked.1” guardado [2697/2697]
#
# --2023-03-12 16:23:48--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81009500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3471 (3,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F81009500.picked.1”
#
#      0K ...                                                   100% 1,08G=0s
#
# 2023-03-12 16:23:49 (1,08 GB/s) - “decoys.F81009500.picked.1” guardado [3471/3471]
#
# --2023-03-12 16:23:49--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81011600.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3036 (3,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81011600.picked.1”
#
#      0K ..                                                    100% 1,34G=0s
#
# 2023-03-12 16:23:50 (1,34 GB/s) - “decoys.F81011600.picked.1” guardado [3036/3036]
#
# --2023-03-12 16:23:50--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81012500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4366 (4,3K) [application/x-not-regular-file]
# Guardando como: “decoys.F81012500.picked.1”
#
#      0K ....                                                  100% 58,9M=0s
#
# 2023-03-12 16:23:51 (58,9 MB/s) - “decoys.F81012500.picked.1” guardado [4366/4366]
#
# --2023-03-12 16:23:51--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81012501.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4539 (4,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F81012501.picked.1”
#
#      0K ....                                                  100% 29,4M=0s
#
# 2023-03-12 16:23:52 (29,4 MB/s) - “decoys.F81012501.picked.1” guardado [4539/4539]
#
# --2023-03-12 16:23:52--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81013500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3755 (3,7K) [application/x-not-regular-file]
# Guardando como: “decoys.F81013500.picked.1”
#
#      0K ...                                                   100% 79,3M=0s
#
# 2023-03-12 16:23:52 (79,3 MB/s) - “decoys.F81013500.picked.1” guardado [3755/3755]
#
# --2023-03-12 16:23:52--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81014000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3657 (3,6K) [application/x-not-regular-file]
# Guardando como: “decoys.F81014000.picked.1”
#
#      0K ...                                                   100%  913M=0s
#
# 2023-03-12 16:23:53 (913 MB/s) - “decoys.F81014000.picked.1” guardado [3657/3657]
#
# --2023-03-12 16:23:53--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81014900.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3038 (3,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81014900.picked”
#
#      0K ..                                                    100%  535M=0s
#
# 2023-03-12 16:23:54 (535 MB/s) - “decoys.F81014900.picked” guardado [3038/3038]
#
# --2023-03-12 16:23:54--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81016400.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3273 (3,2K) [application/x-not-regular-file]
# Guardando como: “decoys.F81016400.picked.1”
#
#      0K ...                                                   100%  813M=0s
#
# 2023-03-12 16:23:55 (813 MB/s) - “decoys.F81016400.picked.1” guardado [3273/3273]
#
# --2023-03-12 16:23:55--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81016800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3206 (3,1K) [application/x-not-regular-file]
# Guardando como: “decoys.F81016800.picked.1”
#
#      0K ...                                                   100%  614M=0s
#
# 2023-03-12 16:23:56 (614 MB/s) - “decoys.F81016800.picked.1” guardado [3206/3206]
#
# --2023-03-12 16:23:56--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81016801.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3401 (3,3K) [application/x-not-regular-file]
# Guardando como: “decoys.F81016801.picked.1”
#
#      0K ...                                                   100% 1,08G=0s
#
# 2023-03-12 16:23:57 (1,08 GB/s) - “decoys.F81016801.picked.1” guardado [3401/3401]
#
# --2023-03-12 16:23:57--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017100.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3749 (3,7K) [application/x-not-regular-file]
# Guardando como: “decoys.F81017100.picked.1”
#
#      0K ...                                                   100% 1,30G=0s
#
# 2023-03-12 16:23:58 (1,30 GB/s) - “decoys.F81017100.picked.1” guardado [3749/3749]
#
# --2023-03-12 16:23:58--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017300.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3450 (3,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F81017300.picked.1”
#
#      0K ...                                                   100%  534M=0s
#
# 2023-03-12 16:23:59 (534 MB/s) - “decoys.F81017300.picked.1” guardado [3450/3450]
#
# --2023-03-12 16:23:59--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017301.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3527 (3,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F81017301.picked.1”
#
#      0K ...                                                   100% 1,24G=0s
#
# 2023-03-12 16:24:00 (1,24 GB/s) - “decoys.F81017301.picked.1” guardado [3527/3527]
#
# --2023-03-12 16:24:00--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017400.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3399 (3,3K) [application/x-not-regular-file]
# Guardando como: “decoys.F81017400.picked.1”
#
#      0K ...                                                   100%  926M=0s
#
# 2023-03-12 16:24:00 (926 MB/s) - “decoys.F81017400.picked.1” guardado [3399/3399]
#
# --2023-03-12 16:24:00--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017401.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3626 (3,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F81017401.picked.1”
#
#      0K ...                                                   100% 1,13G=0s
#
# 2023-03-12 16:24:01 (1,13 GB/s) - “decoys.F81017401.picked.1” guardado [3626/3626]
#
# --2023-03-12 16:24:01--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017900.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4429 (4,3K) [application/x-not-regular-file]
# Guardando como: “decoys.F81017900.picked.1”
#
#      0K ....                                                  100% 3,63M=0,001s
#
# 2023-03-12 16:24:02 (3,63 MB/s) - “decoys.F81017900.picked.1” guardado [4429/4429]
#
# --2023-03-12 16:24:02--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81020200.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3069 (3,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81020200.picked”
#
#      0K ..                                                    100%  721M=0s
#
# 2023-03-12 16:24:03 (721 MB/s) - “decoys.F81020200.picked” guardado [3069/3069]
#
# --2023-03-12 16:24:03--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81020300.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3586 (3,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F81020300.picked.1”
#
#      0K ...                                                   100%  891M=0s
#
# 2023-03-12 16:24:04 (891 MB/s) - “decoys.F81020300.picked.1” guardado [3586/3586]
#
# --2023-03-12 16:24:04--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81021000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3622 (3,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F81021000.picked.1”
#
#      0K ...                                                   100% 1,14G=0s
#
# 2023-03-12 16:24:05 (1,14 GB/s) - “decoys.F81021000.picked.1” guardado [3622/3622]
#
# --2023-03-12 16:24:05--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81022700.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4544 (4,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F81022700.picked.1”
#
#      0K ....                                                  100% 29,8M=0s
#
# 2023-03-12 16:24:06 (29,8 MB/s) - “decoys.F81022700.picked.1” guardado [4544/4544]
#
# --2023-03-12 16:24:06--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81022800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3627 (3,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F81022800.picked.1”
#
#      0K ...                                                   100%  700M=0s
#
# 2023-03-12 16:24:07 (700 MB/s) - “decoys.F81022800.picked.1” guardado [3627/3627]
#
# --2023-03-12 16:24:07--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81023200.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3509 (3,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F81023200.picked.1”
#
#      0K ...                                                   100%  812M=0s
#
# 2023-03-12 16:24:08 (812 MB/s) - “decoys.F81023200.picked.1” guardado [3509/3509]
#
# --2023-03-12 16:24:08--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81023500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3319 (3,2K) [application/x-not-regular-file]
# Guardando como: “decoys.F81023500.picked.1”
#
#      0K ...                                                   100%  559M=0s
#
# 2023-03-12 16:24:08 (559 MB/s) - “decoys.F81023500.picked.1” guardado [3319/3319]
#
# --2023-03-12 16:24:08--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81023800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4191 (4,1K) [application/x-not-regular-file]
# Guardando como: “decoys.F81023800.picked.1”
#
#      0K ....                                                  100% 67,6M=0s
#
# 2023-03-12 16:24:09 (67,6 MB/s) - “decoys.F81023800.picked.1” guardado [4191/4191]
#
# --2023-03-12 16:24:09--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81024000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3297 (3,2K) [application/x-not-regular-file]
# Guardando como: “decoys.F81024000.picked.1”
#
#      0K ...                                                   100%  843M=0s
#
# 2023-03-12 16:24:10 (843 MB/s) - “decoys.F81024000.picked.1” guardado [3297/3297]
#
# --2023-03-12 16:24:10--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81024200.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3281 (3,2K) [application/x-not-regular-file]
# Guardando como: “decoys.F81024200.picked.1”
#
#      0K ...                                                   100%  572M=0s
#
# 2023-03-12 16:24:11 (572 MB/s) - “decoys.F81024200.picked.1” guardado [3281/3281]
#
# --2023-03-12 16:24:11--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81024400.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3116 (3,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81024400.picked.1”
#
#      0K ...                                                   100% 1,77G=0s
#
# 2023-03-12 16:24:12 (1,77 GB/s) - “decoys.F81024400.picked.1” guardado [3116/3116]
#
# --2023-03-12 16:24:12--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81024800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3226 (3,2K) [application/x-not-regular-file]
# Guardando como: “decoys.F81024800.picked.1”
#
#      0K ...                                                   100% 1,11G=0s
#
# 2023-03-12 16:24:13 (1,11 GB/s) - “decoys.F81024800.picked.1” guardado [3226/3226]
#
# --2023-03-12 16:24:13--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81024900.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3278 (3,2K) [application/x-not-regular-file]
# Guardando como: “decoys.F81024900.picked.1”
#
#      0K ...                                                   100%  896M=0s
#
# 2023-03-12 16:24:14 (896 MB/s) - “decoys.F81024900.picked.1” guardado [3278/3278]
#
# --2023-03-12 16:24:14--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81025000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3282 (3,2K) [application/x-not-regular-file]
# Guardando como: “decoys.F81025000.picked.1”
#
#      0K ...                                                   100%  557M=0s
#
# 2023-03-12 16:24:14 (557 MB/s) - “decoys.F81025000.picked.1” guardado [3282/3282]
#
# --2023-03-12 16:24:14--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81025100.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3805 (3,7K) [application/x-not-regular-file]
# Guardando como: “decoys.F81025100.picked.1”
#
#      0K ...                                                   100% 64,2M=0s
#
# 2023-03-12 16:24:15 (64,2 MB/s) - “decoys.F81025100.picked.1” guardado [3805/3805]
#
# --2023-03-12 16:24:15--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81027600.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4484 (4,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F81027600.picked.1”
#
#      0K ....                                                  100% 41,7M=0s
#
# 2023-03-12 16:24:16 (41,7 MB/s) - “decoys.F81027600.picked.1” guardado [4484/4484]
#
# --2023-03-12 16:24:16--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81027601.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4575 (4,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F81027601.picked.1”
#
#      0K ....                                                  100%  726K=0,006s
#
# 2023-03-12 16:24:17 (726 KB/s) - “decoys.F81027601.picked.1” guardado [4575/4575]
#
# --2023-03-12 16:24:17--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81028000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3599 (3,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F81028000.picked.1”
#
#      0K ...                                                   100%  653M=0s
#
# 2023-03-12 16:24:18 (653 MB/s) - “decoys.F81028000.picked.1” guardado [3599/3599]
#
# --2023-03-12 16:24:18--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81028100.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3614 (3,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F81028100.picked.1”
#
#      0K ...                                                   100% 1,13G=0s
#
# 2023-03-12 16:24:19 (1,13 GB/s) - “decoys.F81028100.picked.1” guardado [3614/3614]
#
# --2023-03-12 16:24:19--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81028800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3271 (3,2K) [application/x-not-regular-file]
# Guardando como: “decoys.F81028800.picked.1”
#
#      0K ...                                                   100% 1,13G=0s
#
# 2023-03-12 16:24:20 (1,13 GB/s) - “decoys.F81028800.picked.1” guardado [3271/3271]
#
# --2023-03-12 16:24:20--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81028900.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3443 (3,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F81028900.picked.1”
#
#      0K ...                                                   100% 1,45G=0s
#
# 2023-03-12 16:24:21 (1,45 GB/s) - “decoys.F81028900.picked.1” guardado [3443/3443]
#
# --2023-03-12 16:24:21--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81029200.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4719 (4,6K) [application/x-not-regular-file]
# Guardando como: “decoys.F81029200.picked.1”
#
#      0K ....                                                  100% 4,21M=0,001s
#
# 2023-03-12 16:24:21 (4,21 MB/s) - “decoys.F81029200.picked.1” guardado [4719/4719]
#
# --2023-03-12 16:24:21--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81029900.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3840 (3,8K) [application/x-not-regular-file]
# Guardando como: “decoys.F81029900.picked.1”
#
#      0K ...                                                   100% 66,5M=0s
#
# 2023-03-12 16:24:22 (66,5 MB/s) - “decoys.F81029900.picked.1” guardado [3840/3840]
#
# --2023-03-12 16:24:22--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81030100.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3793 (3,7K) [application/x-not-regular-file]
# Guardando como: “decoys.F81030100.picked.1”
#
#      0K ...                                                   100% 75,8M=0s
#
# 2023-03-12 16:24:23 (75,8 MB/s) - “decoys.F81030100.picked.1” guardado [3793/3793]
#
# --2023-03-12 16:24:23--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81030500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3611 (3,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F81030500.picked.1”
#
#      0K ...                                                   100%  633M=0s
#
# 2023-03-12 16:24:24 (633 MB/s) - “decoys.F81030500.picked.1” guardado [3611/3611]
#
# --2023-03-12 16:24:24--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81030700.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3868 (3,8K) [application/x-not-regular-file]
# Guardando como: “decoys.F81030700.picked.1”
#
#      0K ...                                                   100% 67,0M=0s
#
# 2023-03-12 16:24:25 (67,0 MB/s) - “decoys.F81030700.picked.1” guardado [3868/3868]
#
# --2023-03-12 16:24:25--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81030800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3679 (3,6K) [application/x-not-regular-file]
# Guardando como: “decoys.F81030800.picked.1”
#
#      0K ...                                                   100%  634M=0s
#
# 2023-03-12 16:24:26 (634 MB/s) - “decoys.F81030800.picked.1” guardado [3679/3679]
#
# --2023-03-12 16:24:26--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81031300.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3662 (3,6K) [application/x-not-regular-file]
# Guardando como: “decoys.F81031300.picked.1”
#
#      0K ...                                                   100% 1,17G=0s
#
# 2023-03-12 16:24:26 (1,17 GB/s) - “decoys.F81031300.picked.1” guardado [3662/3662]
#
# --2023-03-12 16:24:26--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81035000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3835 (3,7K) [application/x-not-regular-file]
# Guardando como: “decoys.F81035000.picked.1”
#
#      0K ...                                                   100% 66,3M=0s
#
# 2023-03-12 16:24:27 (66,3 MB/s) - “decoys.F81035000.picked.1” guardado [3835/3835]
#
# --2023-03-12 16:24:27--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81035200.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4632 (4,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F81035200.picked.1”
#
#      0K ....                                                  100% 29,8M=0s
#
# 2023-03-12 16:24:28 (29,8 MB/s) - “decoys.F81035200.picked.1” guardado [4632/4632]
#
# --2023-03-12 16:24:28--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81035201.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4168 (4,1K) [application/x-not-regular-file]
# Guardando como: “decoys.F81035201.picked.1”
#
#      0K ....                                                  100% 70,1M=0s
#
# 2023-03-12 16:24:29 (70,1 MB/s) - “decoys.F81035201.picked.1” guardado [4168/4168]
#
# --2023-03-12 16:24:29--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81035400.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4117 (4,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81035400.picked.1”
#
#      0K ....                                                  100% 72,8M=0s
#
# 2023-03-12 16:24:30 (72,8 MB/s) - “decoys.F81035400.picked.1” guardado [4117/4117]
#
# --2023-03-12 16:24:30--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81036200.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3397 (3,3K) [application/x-not-regular-file]
# Guardando como: “decoys.F81036200.picked.1”
#
#      0K ...                                                   100%  915M=0s
#
# 2023-03-12 16:24:31 (915 MB/s) - “decoys.F81036200.picked.1” guardado [3397/3397]
#
# --2023-03-12 16:24:31--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81036300.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3198 (3,1K) [application/x-not-regular-file]
# Guardando como: “decoys.F81036300.picked.1”
#
#      0K ...                                                   100%  713M=0s
#
# 2023-03-12 16:24:32 (713 MB/s) - “decoys.F81036300.picked.1” guardado [3198/3198]
#
# --2023-03-12 16:24:32--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81036400.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4640 (4,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F81036400.picked.1”
#
#      0K ....                                                  100% 28,1M=0s
#
# 2023-03-12 16:24:32 (28,1 MB/s) - “decoys.F81036400.picked.1” guardado [4640/4640]
#
# --2023-03-12 16:24:32--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81036700.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4141 (4,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81036700.picked.1”
#
#      0K ....                                                  100% 66,4M=0s
#
# 2023-03-12 16:24:33 (66,4 MB/s) - “decoys.F81036700.picked.1” guardado [4141/4141]
#
# --2023-03-12 16:24:33--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81036800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4265 (4,2K) [application/x-not-regular-file]
# Guardando como: “decoys.F81036800.picked.1”
#
#      0K ....                                                  100% 64,3M=0s
#
# 2023-03-12 16:24:34 (64,3 MB/s) - “decoys.F81036800.picked.1” guardado [4265/4265]
#
# --2023-03-12 16:24:34--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81037300.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3736 (3,6K) [application/x-not-regular-file]
# Guardando como: “decoys.F81037300.picked.1”
#
#      0K ...                                                   100%  797M=0s
#
# 2023-03-12 16:24:35 (797 MB/s) - “decoys.F81037300.picked.1” guardado [3736/3736]
#
# --2023-03-12 16:24:35--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81037302.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4179 (4,1K) [application/x-not-regular-file]
# Guardando como: “decoys.F81037302.picked.1”
#
#      0K ....                                                  100% 65,0M=0s
#
# 2023-03-12 16:24:36 (65,0 MB/s) - “decoys.F81037302.picked.1” guardado [4179/4179]
#
# --2023-03-12 16:24:36--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81037500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3721 (3,6K) [application/x-not-regular-file]
# Guardando como: “decoys.F81037500.picked.1”
#
#      0K ...                                                   100% 1,13G=0s
#
# 2023-03-12 16:24:37 (1,13 GB/s) - “decoys.F81037500.picked.1” guardado [3721/3721]
#
# --2023-03-12 16:24:37--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81038400.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4828 (4,7K) [application/x-not-regular-file]
# Guardando como: “decoys.F81038400.picked.1”
#
#      0K ....                                                  100% 20,0M=0s
#
# 2023-03-12 16:24:38 (20,0 MB/s) - “decoys.F81038400.picked.1” guardado [4828/4828]
#
# --2023-03-12 16:24:38--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81038500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4381 (4,3K) [application/x-not-regular-file]
# Guardando como: “decoys.F81038500.picked.1”
#
#      0K ....                                                  100% 42,3M=0s
#
# 2023-03-12 16:24:39 (42,3 MB/s) - “decoys.F81038500.picked.1” guardado [4381/4381]
#
# --2023-03-12 16:24:39--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81040500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4534 (4,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F81040500.picked.1”
#
#      0K ....                                                  100% 90,7M=0s
#
# 2023-03-12 16:24:40 (90,7 MB/s) - “decoys.F81040500.picked.1” guardado [4534/4534]
#
# --2023-03-12 16:24:40--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81040700.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4240 (4,1K) [application/x-not-regular-file]
# Guardando como: “decoys.F81040700.picked.1”
#
#      0K ....                                                  100% 64,0M=0s
#
# 2023-03-12 16:24:40 (64,0 MB/s) - “decoys.F81040700.picked.1” guardado [4240/4240]
#
# --2023-03-12 16:24:40--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81042500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4095 (4,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F81042500.picked.1”
#
#      0K ...                                                   100% 77,2M=0s
#
# 2023-03-12 16:24:41 (77,2 MB/s) - “decoys.F81042500.picked.1” guardado [4095/4095]
#
# --2023-03-12 16:24:41--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81043800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4378 (4,3K) [application/x-not-regular-file]
# Guardando como: “decoys.F81043800.picked.1”
#
#      0K ....                                                  100% 50,5M=0s
#
# 2023-03-12 16:24:42 (50,5 MB/s) - “decoys.F81043800.picked.1” guardado [4378/4378]
#
# --2023-03-12 16:24:42--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81044600.picked
# ...
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4205 (4,1K) [application/x-not-regular-file]
# Guardando como: “decoys.F92014800.picked.1”
#
#      0K ....                                                  100% 74,7M=0s
#
# 2023-03-12 16:31:06 (74,7 MB/s) - “decoys.F92014800.picked.1” guardado [4205/4205]
#
# --2023-03-12 16:31:06--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92016000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4580 (4,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F92016000.picked.1”
#
#      0K ....                                                  100% 67,5M=0s
#
# 2023-03-12 16:31:07 (67,5 MB/s) - “decoys.F92016000.picked.1” guardado [4580/4580]
#
# --2023-03-12 16:31:07--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92018800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3954 (3,9K) [application/x-not-regular-file]
# Guardando como: “decoys.F92018800.picked.2”
#
#      0K ...                                                   100% 83,1M=0s
#
# 2023-03-12 16:31:07 (83,1 MB/s) - “decoys.F92018800.picked.2” guardado [3954/3954]
#
# --2023-03-12 16:31:07--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92019400.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 5022 (4,9K) [application/x-not-regular-file]
# Guardando como: “decoys.F92019400.picked.1”
#
#      0K ....                                                  100% 70,6M=0s
#
# 2023-03-12 16:31:08 (70,6 MB/s) - “decoys.F92019400.picked.1” guardado [5022/5022]
#
# --2023-03-12 16:31:08--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92020100.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4790 (4,7K) [application/x-not-regular-file]
# Guardando como: “decoys.F92020100.picked.1”
#
#      0K ....                                                  100% 2,34M=0,002s
#
# 2023-03-12 16:31:09 (2,34 MB/s) - “decoys.F92020100.picked.1” guardado [4790/4790]
#
# --2023-03-12 16:31:09--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92020700.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4243 (4,1K) [application/x-not-regular-file]
# Guardando como: “decoys.F92020700.picked.1”
#
#      0K ....                                                  100% 25,4M=0s
#
# 2023-03-12 16:31:10 (25,4 MB/s) - “decoys.F92020700.picked.1” guardado [4243/4243]
#
# --2023-03-12 16:31:10--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92021100.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3994 (3,9K) [application/x-not-regular-file]
# Guardando como: “decoys.F92021100.picked.1”
#
#      0K ...                                                   100% 51,8M=0s
#
# 2023-03-12 16:31:11 (51,8 MB/s) - “decoys.F92021100.picked.1” guardado [3994/3994]
#
# --2023-03-12 16:31:11--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92021200.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3703 (3,6K) [application/x-not-regular-file]
# Guardando como: “decoys.F92021200.picked.2”
#
#      0K ...                                                   100% 1,24G=0s
#
# 2023-03-12 16:31:12 (1,24 GB/s) - “decoys.F92021200.picked.2” guardado [3703/3703]
#
# --2023-03-12 16:31:12--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92021800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3881 (3,8K) [application/x-not-regular-file]
# Guardando como: “decoys.F92021800.picked.1”
#
#      0K ...                                                   100% 58,1M=0s
#
# 2023-03-12 16:31:12 (58,1 MB/s) - “decoys.F92021800.picked.1” guardado [3881/3881]
#
# --2023-03-12 16:31:12--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92022300.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4100 (4,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F92022300.picked.1”
#
#      0K ....                                                  100% 67,6M=0s
#
# 2023-03-12 16:31:13 (67,6 MB/s) - “decoys.F92022300.picked.1” guardado [4100/4100]
#
# --2023-03-12 16:31:13--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92022400.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3002 (2,9K) [application/x-not-regular-file]
# Guardando como: “decoys.F92022400.picked.1”
#
#      0K ..                                                    100% 1,01G=0s
#
# 2023-03-12 16:31:14 (1,01 GB/s) - “decoys.F92022400.picked.1” guardado [3002/3002]
#
# --2023-03-12 16:31:14--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92024500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3312 (3,2K) [application/x-not-regular-file]
# Guardando como: “decoys.F92024500.picked.1”
#
#      0K ...                                                   100%  602M=0s
#
# 2023-03-12 16:31:15 (602 MB/s) - “decoys.F92024500.picked.1” guardado [3312/3312]
#
# --2023-03-12 16:31:15--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92024800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3927 (3,8K) [application/x-not-regular-file]
# Guardando como: “decoys.F92024800.picked.1”
#
#      0K ...                                                   100% 62,1M=0s
#
# 2023-03-12 16:31:16 (62,1 MB/s) - “decoys.F92024800.picked.1” guardado [3927/3927]
#
# --2023-03-12 16:31:16--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92025100.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3808 (3,7K) [application/x-not-regular-file]
# Guardando como: “decoys.F92025100.picked.2”
#
#      0K ...                                                   100% 77,8M=0s
#
# 2023-03-12 16:31:17 (77,8 MB/s) - “decoys.F92025100.picked.2” guardado [3808/3808]
#
# --2023-03-12 16:31:17--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92025200.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4079 (4,0K) [application/x-not-regular-file]
# Guardando como: “decoys.F92025200.picked.1”
#
#      0K ...                                                   100% 1,51M=0,003s
#
# 2023-03-12 16:31:18 (1,51 MB/s) - “decoys.F92025200.picked.1” guardado [4079/4079]
#
# --2023-03-12 16:31:18--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92030300.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3466 (3,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F92030300.picked.1”
#
#      0K ...                                                   100%  793M=0s
#
# 2023-03-12 16:31:18 (793 MB/s) - “decoys.F92030300.picked.1” guardado [3466/3466]
#
# --2023-03-12 16:31:18--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92030400.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3307 (3,2K) [application/x-not-regular-file]
# Guardando como: “decoys.F92030400.picked.1”
#
#      0K ...                                                   100% 1,10G=0s
#
# 2023-03-12 16:31:19 (1,10 GB/s) - “decoys.F92030400.picked.1” guardado [3307/3307]
#
# --2023-03-12 16:31:19--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92030600.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4611 (4,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F92030600.picked.1”
#
#      0K ....                                                  100% 66,6M=0s
#
# 2023-03-12 16:31:20 (66,6 MB/s) - “decoys.F92030600.picked.1” guardado [4611/4611]
#
# --2023-03-12 16:31:20--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92030800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4541 (4,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F92030800.picked.1”
#
#      0K ....                                                  100% 77,7M=0s
#
# 2023-03-12 16:31:21 (77,7 MB/s) - “decoys.F92030800.picked.1” guardado [4541/4541]
#
# --2023-03-12 16:31:21--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92031900.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4409 (4,3K) [application/x-not-regular-file]
# Guardando como: “decoys.F92031900.picked.2”
#
#      0K ....                                                  100% 72,2M=0s
#
# 2023-03-12 16:31:22 (72,2 MB/s) - “decoys.F92031900.picked.2” guardado [4409/4409]
#
# --2023-03-12 16:31:22--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92034500.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3462 (3,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F92034500.picked.1”
#
#      0K ...                                                   100% 1,24G=0s
#
# 2023-03-12 16:31:23 (1,24 GB/s) - “decoys.F92034500.picked.1” guardado [3462/3462]
#
# --2023-03-12 16:31:23--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92034800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3360 (3,3K) [application/x-not-regular-file]
# Guardando como: “decoys.F92034800.picked.1”
#
#      0K ...                                                   100% 1,35G=0s
#
# 2023-03-12 16:31:23 (1,35 GB/s) - “decoys.F92034800.picked.1” guardado [3360/3360]
#
# --2023-03-12 16:31:23--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92034900.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4018 (3,9K) [application/x-not-regular-file]
# Guardando como: “decoys.F92034900.picked.1”
#
#      0K ...                                                   100% 86,5M=0s
#
# 2023-03-12 16:31:24 (86,5 MB/s) - “decoys.F92034900.picked.1” guardado [4018/4018]
#
# --2023-03-12 16:31:24--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92035000.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4210 (4,1K) [application/x-not-regular-file]
# Guardando como: “decoys.F92035000.picked.1”
#
#      0K ....                                                  100% 65,5M=0s
#
# 2023-03-12 16:31:25 (65,5 MB/s) - “decoys.F92035000.picked.1” guardado [4210/4210]
#
# --2023-03-12 16:31:25--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92035300.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3579 (3,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F92035300.picked.1”
#
#      0K ...                                                   100%  636M=0s
#
# 2023-03-12 16:31:26 (636 MB/s) - “decoys.F92035300.picked.1” guardado [3579/3579]
#
# --2023-03-12 16:31:26--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92035700.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3495 (3,4K) [application/x-not-regular-file]
# Guardando como: “decoys.F92035700.picked.1”
#
#      0K ...                                                   100%  844M=0s
#
# 2023-03-12 16:31:27 (844 MB/s) - “decoys.F92035700.picked.1” guardado [3495/3495]
#
# --2023-03-12 16:31:27--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92036800.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 4584 (4,5K) [application/x-not-regular-file]
# Guardando como: “decoys.F92036800.picked.1”
#
#      0K ....                                                  100% 28,6M=0s
#
# 2023-03-12 16:31:28 (28,6 MB/s) - “decoys.F92036800.picked.1” guardado [4584/4584]
#
# --2023-03-12 16:31:28--  https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92037300.picked
# Resolviendo dude.docking.org (dude.docking.org)... 169.230.26.169
# Conectando con dude.docking.org (dude.docking.org)[169.230.26.169]:443... conectado.
# Petición HTTP enviada, esperando respuesta... 200 OK
# Longitud: 3986 (3,9K) [application/x-not-regular-file]
# Guardando como: “decoys.F92037300.picked.1”
#
#      0K ...                                                   100% 82,2M=0s
#
# 2023-03-12 16:31:29 (82,2 MB/s) - “decoys.F92037300.picked.1” guardado [3986/3986]

# %%
# El numero de moleculas a generar y luego largar el docking es demasiado grande, por lo que para esta prueba piloto
# seleccionaré un subconjunto de ligandos: 50 ligandos activos y 2500 decoys, seleccionados de manera aleatoria

picked_seleccionados_al_azar= [random.choice(picked_limpios_completo) for numero_ligandos in range(50)]
picked_seleccionados_al_azar
# Out:
# ['https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81030700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81044700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82025900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92013300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92005400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91103500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91110400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91001100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91011500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81048600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81108800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92009600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92007100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92009600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91074800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81003600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91064200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91076700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82027800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91059400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91033400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81036300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81017400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91105000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91023200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92034800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82013100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91027100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82026500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91049300.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91034900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91038500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91087500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91001700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91018200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91064200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81069800.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F92012100.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91095000.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81047700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81076700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91007900.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82025600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91107200.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91001700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81012500.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F81073600.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F82029700.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91001400.picked',
#  'https://dude.docking.org//targets/cdk2/dudgen_clustered/search/decoys.F91049000.picked']

# %%
#Abrir los archivos .picked para extraer ligandos, y obtener una lista de los compuestos activos para la quinasa que se 
# encuentran en la primera linea
ligandos_activos_smile = []
ligandos_activos_ID = []
for picked in picked_seleccionados_al_azar:
    picked = picked.replace('https://dude.docking.org//targets/cdk2/dudgen_clustered/search/','')
    with open(picked, 'r') as contenido:
        for p,row in enumerate(contenido):
            if p==0:
                ligandos_activos_smile.append(row.split('\t')[1])
                ligandos_activos_ID.append(row.split('\t')[2])

# %%
#Extraccion de los smiles de los decoys desde cada archivo .picked
decoys = [picked_file.replace('https://dude.docking.org//targets/cdk2/dudgen_clustered/search/','') for picked_file in picked_seleccionados_al_azar]
smiles_decoys = []
for decoy in decoys:
    with open(decoy, 'r') as decoys_smiles:
        for p,row in enumerate(decoys_smiles):
            if p!=0:
                smiles_decoys.append(row)

# %%
#generar las conformaciones desde los smiles utilizando openbabel como generador de estructuras 3D
def conformeros3D(lista):
    '''Generar estructuras 3D a partir de smiles en una lista utilizando openbabel'''
    decoys_smile = []
    for picked in decoys:
        with open(picked, 'r') as picked_file, open('smiles_fail.txt', 'a') as smile_fail,open('lista_completa.txt', 'a') as nombres:
            for p, smile in enumerate(picked_file): # ej: COc1ccc(-c2cc(=O)c3c(O)cc(O)cc3o2)cc1  ZINC ID
                    ID_ZINC = smile.strip().split('\t')[1] # Modificar de acuerdo al separador utilizado
                    ID_sdf_zinc = '-O'+ID_ZINC+'.sdf'
                    print(smile.strip().split('\t')[0])
                    fails=0
                    smile = '-:'+smile.strip()
                    try:
                        procesamiento_obabel = subprocess.run(['obabel', '-:',smile, '-osdf', ID_sdf_zinc, '--gen3D'], stdout = subprocess.PIPE,stderr=subprocess.STDOUT, text=True, timeout= 60)
                        for line in procesamiento_obabel.stdout:
                            fails +=1
                        if fails > 21:
                            print(f'La molécula {ID_ZINC} tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = {p}')   
                            smile_fail.write(smile.strip().split('\t')[0]+','+'error quimico'+'\n')
                        else:
                            print(f'La molecula {ID_ZINC} fue correctamente procesada con Openbabel, verificar en el archivo, n = {p}')
                    except subprocess.TimeoutExpired:
                        print(f'La molecula {ID_ZINC} no corrió adecuadamente y el proceso fue detenido abruptamente, n = {p}')
                        nombres.write(ID_ZINC+','+'error de ejecución'+'\n')

# %%
conformeros3D(smiles_decoys)
# Out:
# ligand
# La molécula NC(=O)c2nn(c1ccc(S(N)(=O)=O)cc1)c4c2CCc3n[nH]cc34 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 0
# CCOc1ccc(c(c1)[N+](=O)[O-])N[C@@H]2[C@H]([C@@H]([C@@H](CO2)O)O)O
# La molecula C03898650 fue correctamente procesada con Openbabel, verificar en el archivo, n = 1
# CCOc1ccc(c(c1)[N+](=O)[O-])N[C@@H]2[C@@H]([C@H]([C@@H](CO2)O)O)O
# La molecula C03999711 fue correctamente procesada con Openbabel, verificar en el archivo, n = 2
# CC(=O)N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1Oc2ccc(cc2)C=O)CO)O)O
# La molecula C04043193 fue correctamente procesada con Openbabel, verificar en el archivo, n = 3
# c1c(c(=O)[nH]c(=O)n1[C@@H]2[C@@H]([C@@H]([C@H](O2)CO)O)O)Br
# La molecula C04342943 fue correctamente procesada con Openbabel, verificar en el archivo, n = 4
# c1cc(ccc1Cn2c(=S)n(cn2)N)Cn3c(=S)n(cn3)N
# La molecula C04618417 fue correctamente procesada con Openbabel, verificar en el archivo, n = 5
# c1c(c(=O)[nH]c(=O)n1[C@H]2[C@H]([C@@H]([C@@H](O2)CO)O)O)CCC(F)F
# La molecula C05208112 fue correctamente procesada con Openbabel, verificar en el archivo, n = 6
# COC(=O)C[C@H]1C(=O)N2C(=C([C@@H](C(=C2S1)C(=O)N)c3cccs3)C#N)N
# La molecula C03764203 fue correctamente procesada con Openbabel, verificar en el archivo, n = 7
# c1cc(oc1)CNc2ccn(c(=O)n2)[C@H]3[C@H]([C@@H]([C@@H](O3)CO)O)O
# La molecula C05496482 fue correctamente procesada con Openbabel, verificar en el archivo, n = 8
# Cn1c(=O)c(c(nc1OC)N[C@H]2[C@H]([C@@H]([C@@H](CO2)O)O)O)Cl
# La molecula C05760741 fue correctamente procesada con Openbabel, verificar en el archivo, n = 9
# COc1cc(ccc1O[C@@H]2[C@H]([C@@H]([C@@H]([C@@H](O2)CO)O)O)O)C=O
# La molecula C00488469 fue correctamente procesada con Openbabel, verificar en el archivo, n = 10
# C=C1c2ccccc2C(=O)N1CC(=O)OCc3nc(nc(n3)N)N
# La molecula C11580937 fue correctamente procesada con Openbabel, verificar en el archivo, n = 11
# CC(=O)N[C@H]1[C@@H]([C@H]([C@H](O[C@@H]1Oc2ccccc2C=O)CO)O)O
# La molecula C13382195 fue correctamente procesada con Openbabel, verificar en el archivo, n = 12
# c1cn(c(=O)[nH]c1=O)[C@H]2C[C@@H]([C@H](O2)COP(=S)(O)O)O
# La molecula C13549194 fue correctamente procesada con Openbabel, verificar en el archivo, n = 13
# CC(C)CNc1[nH]c(=O)c2c(n1)n(cn2)[C@H]3C[C@@H]([C@H](O3)CO)O
# La molecula C15657736 fue correctamente procesada con Openbabel, verificar en el archivo, n = 14
# Cc1cc(n(c(=S)c1C#N)[C@H]2[C@@H]([C@H]([C@@H]([C@H](O2)CO)O)O)O)C
# La molecula C16958780 fue correctamente procesada con Openbabel, verificar en el archivo, n = 15
# C1Cc2c(sc(c2C(=O)N)NC(=O)C(=O)N3CCN(CC3)CCO)C1
# La molecula C20573601 fue correctamente procesada con Openbabel, verificar en el archivo, n = 16
# c1cc(sc1)Cn2c(nnn2)SCc3nc(nc(n3)N)N
# La molecula C24507118 fue correctamente procesada con Openbabel, verificar en el archivo, n = 17
# Cc1cc(nc(n1)SCC(=O)c2c(n(c(=O)n(c2=O)C)C)N)N
# La molecula C31745579 fue correctamente procesada con Openbabel, verificar en el archivo, n = 18
# c1ccc2c(c1)cc(c(=O)o2)C(=O)O[C@@H]3[C@@H]([C@H](O[C@H]([C@H]3O)O)CO)O
# La molecula C32603120 fue correctamente procesada con Openbabel, verificar en el archivo, n = 19
# CC(=O)N[C@@H]1[C@H]([C@@H]([C@@H](O[C@@H]1Oc2ccc(cc2)C=O)CO)O)O
# La molecula C33737312 fue correctamente procesada con Openbabel, verificar en el archivo, n = 20
# c1c(c(=O)[nH]c(=O)n1[C@@H]2[C@@H]([C@@H]([C@@H](O2)CO)O)O)/C=C/Br
# La molecula C33938237 fue correctamente procesada con Openbabel, verificar en el archivo, n = 21
# c1cc(c(cc1[N+](=O)[O-])S(=O)(=O)NC2CCOCC2)NN
# La molecula C36320080 fue correctamente procesada con Openbabel, verificar en el archivo, n = 22
# COCCn1c(c(c(=O)[nH]c1=O)N[C@@H]2CCS(=O)(=O)C2)N
# La molecula C37486791 fue correctamente procesada con Openbabel, verificar en el archivo, n = 23
# c1c(cn[nH]1)S(=O)(=O)N2CCC[C@H](C2)CNS(=O)(=O)N
# La molecula C37840732 fue correctamente procesada con Openbabel, verificar en el archivo, n = 24
# c1cc(=O)[nH]cc1C(=O)N2CCC[C@H](C2)CNS(=O)(=O)N
# La molecula C37841914 fue correctamente procesada con Openbabel, verificar en el archivo, n = 25
# C=C[C@H]1[C@@H](OC=C2C1=CCOC2=O)O[C@H]3[C@@H]([C@H]([C@@H]([C@H](O3)CO)O)O)O
# La molecula C04098340 fue correctamente procesada con Openbabel, verificar en el archivo, n = 26
# CCOc1ccc(c(c1)[N+](=O)[O-])N[C@@H]2[C@@H]([C@@H]([C@@H]([C@@H](O2)C)O)O)O
# La molecula C03898630 fue correctamente procesada con Openbabel, verificar en el archivo, n = 27
# CC1=C[C@@H](N=N1)[C@@H]2NN[C@@H](N2N)SCC(=O)N3CCOCC3
# La molecula C38748324 fue correctamente procesada con Openbabel, verificar en el archivo, n = 28
# CN1[C@@H](C(=C(N(C1=O)C)[O-])C(=O)CSc2[nH]c(=O)ccn2)[NH3+]
# La molecula C39610979 fue correctamente procesada con Openbabel, verificar en el archivo, n = 29
# CN1[C@H](C(=C(N(C1=O)C)[O-])C(=O)CSc2[nH]c(=O)ccn2)[NH3+]
# La molecula C39610980 fue correctamente procesada con Openbabel, verificar en el archivo, n = 30
# c1cc(ccc1CS(=O)(=O)N2CCN(CC2)S(=O)(=O)N)N
# La molecula C40348076 fue correctamente procesada con Openbabel, verificar en el archivo, n = 31
# c1ccc(c(c1)[N-]S(=O)(=O)N2CC[NH2+]CC2)S(=O)(=O)N
# La molecula C40862268 fue correctamente procesada con Openbabel, verificar en el archivo, n = 32
# CC(C)CNc1[nH]c(=O)c2c(n1)n(cn2)[C@H]3C[C@H]([C@@H](O3)CO)O
# La molecula C43163804 fue correctamente procesada con Openbabel, verificar en el archivo, n = 33
# C=C[C@@H]1[C@@H](OC=C2C1=CCOC2=O)O[C@H]3[C@H]([C@@H]([C@@H]([C@H](O3)CO)O)O)O
# La molecula C43764179 fue correctamente procesada con Openbabel, verificar en el archivo, n = 34
# CC(=O)[C@H]1C=C2C=CC(=C[C@@H]2OC1=O)O[C@H]3[C@@H]([C@H]([C@H]([C@@H](O3)CO)O)O)O
# La molecula C44166773 fue correctamente procesada con Openbabel, verificar en el archivo, n = 35
# CC(=O)N[C@@H]1[C@H]([C@H]([C@H](O[C@H]1Oc2ccc(cc2)C=O)CO)O)O
# La molecula C44168714 fue correctamente procesada con Openbabel, verificar en el archivo, n = 36
# CC(=O)c1cc2ccc(cc2oc1=O)O[C@H]3[C@H]([C@H](O[C@H]([C@@H]3O)O)CO)O
# La molecula C44171477 fue correctamente procesada con Openbabel, verificar en el archivo, n = 37
# C[C@@]1(CCS(=O)(=O)C1)NS(=O)(=O)c2cnc(nc2)NN
# La molecula C44934408 fue correctamente procesada con Openbabel, verificar en el archivo, n = 38
# CC[C@H](/C(=N/O)/N)NS(=O)(=O)C1CCS(=O)(=O)CC1
# La molecula C50351753 fue correctamente procesada con Openbabel, verificar en el archivo, n = 39
# CC[C@@](C)(/C(=N/O)/N)NS(=O)(=O)C1CCS(=O)(=O)CC1
# La molecula C50351765 fue correctamente procesada con Openbabel, verificar en el archivo, n = 40
# Cn1cnnc1CNS(=O)(=O)c2cc(cnc2NN)Br
# La molecula C50421087 fue correctamente procesada con Openbabel, verificar en el archivo, n = 41
# C1CS(=O)(=O)C[C@H]1CNC(=O)C2(CCOCC2)/C(=N\O)/N
# La molecula C50604384 fue correctamente procesada con Openbabel, verificar en el archivo, n = 42
# C1CO[C@@H](CN1CC(=O)NC(=O)NCC(F)(F)F)C(=O)N
# La molecula C51106659 fue correctamente procesada con Openbabel, verificar en el archivo, n = 43
# CC1CCC2(CC1)C(=O)N(C(=O)N2)CC(=O)NCCS(=O)(=O)N
# La molecula C53773488 fue correctamente procesada con Openbabel, verificar en el archivo, n = 44
# C[C@H](CNS(=O)(=O)C1CCS(=O)(=O)CC1)/C(=N/O)/N
# La molecula C54156163 fue correctamente procesada con Openbabel, verificar en el archivo, n = 45
# c1ccc(cc1)/C=C/C=N/NC(=O)CN2[C@@H]3[C@H](NC(=O)N3)NC2=O
# La molecula C59092474 fue correctamente procesada con Openbabel, verificar en el archivo, n = 46
# C1CCC2(C1)C(=O)N(C(=O)N2)CC(=O)NNC(=O)NC3CC3
# La molecula C64428214 fue correctamente procesada con Openbabel, verificar en el archivo, n = 47
# C[C@H]1[C@@H]2CS[C@H](N=C2C(=O)O1)CNC(=O)/C(=N\O)/c3csc(n3)N
# La molecula C65734329 fue correctamente procesada con Openbabel, verificar en el archivo, n = 48
# C[C@H]1[C@@H]2CS[C@@H](N=C2C(=O)O1)CNC(=O)/C(=N\O)/c3csc(n3)N
# La molecula C65734332 fue correctamente procesada con Openbabel, verificar en el archivo, n = 49
# Cc1nc(cs1)C(=O)N[C@@H]2CCCc3c2cc(c(=O)[nH]3)C(=O)N
# La molecula C66899225 fue correctamente procesada con Openbabel, verificar en el archivo, n = 50
# ligand
# La molécula O=C(Nc1cccnc1)Nc2cn[nH]c2c5nc4cc(CN3CCOCC3)ccc4[nH]5 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 0
# CC1=C([C@]2(c3ccccc3N(C2=O)CC(=O)N)C(=C(O1)N)C#N)C(=O)OCC=C
# La molecula C02231151 fue correctamente procesada con Openbabel, verificar en el archivo, n = 1
# c1cc(cnc1)c2nnc(n2N)SCC(=O)NN3C(=O)C4(CCCCC4)NC3=O
# La molecula C03442448 fue correctamente procesada con Openbabel, verificar en el archivo, n = 2
# C[C@@]1(C(=O)N(C(=O)N1)CC(=O)Nc2ccc(cc2)C(=O)N)c3ccc(cc3)[N+](=O)[O-]
# La molecula C08753017 fue correctamente procesada con Openbabel, verificar en el archivo, n = 3
# COc1ccc(cc1)Oc2coc3cc(ccc3c2=O)O[C@@H]4[C@@H]([C@@H]([C@@H]([C@@H](O4)CO)O)O)O
# La molecula C08844374 fue correctamente procesada con Openbabel, verificar en el archivo, n = 4
# CC(C)n1c(c(c(=O)[nH]c1=O)[C@H]2c3ccc(cc3Oc4c2c(=O)n(c(=O)[nH]4)C(C)C)O)O
# La molecula C09488342 fue correctamente procesada con Openbabel, verificar en el archivo, n = 5
# c1ccc(cc1)C[C@@H](C(=O)NNC(=O)c2c3ccccc3c(=O)[nH]n2)NC(=O)c4ccco4
# La molecula C09703780 fue correctamente procesada con Openbabel, verificar en el archivo, n = 6
# C[C@@H](C(=O)NC(=O)NC)OC(=O)CCNC(=O)NC12CC3CC(C1)CC(C3)C2
# La molecula C11440504 fue correctamente procesada con Openbabel, verificar en el archivo, n = 7
# COc1ccc(cc1)Oc2coc3cc(ccc3c2=O)O[C@H]4[C@H]([C@@H]([C@@H]([C@H](O4)CO)O)O)O
# La molecula C11666973 fue correctamente procesada con Openbabel, verificar en el archivo, n = 8
# C[C@@H](C(=O)Nc1c(ccs1)C(=O)N)Sc2nnnn2c3ccc(cc3)O
# La molecula C12892299 fue correctamente procesada con Openbabel, verificar en el archivo, n = 9
# Cc1ccc(cc1)S(=O)(=O)OC[C@@H]2[C@H]([C@@H]([C@@H](O2)n3cnc4c3ncnc4N)O)O
# La molecula C04822295 fue correctamente procesada con Openbabel, verificar en el archivo, n = 10
# Cc1ccccc1C(=O)NNC(=O)CSc2ccc(cc2[N+](=O)[O-])C(=O)N
# La molecula C15692214 fue correctamente procesada con Openbabel, verificar en el archivo, n = 11
# CNC(=O)c1ccccc1NC(=O)CSc2ccc(cc2[N+](=O)[O-])C(=O)N
# La molecula C19209044 fue correctamente procesada con Openbabel, verificar en el archivo, n = 12
# C[C@@H]1[C@@H]([C@H](n2c(ncn2)N1)c3ccc(c(c3)OC)OCC(=O)N)C(=O)Nc4ccccc4
# La molecula C20803419 fue correctamente procesada con Openbabel, verificar en el archivo, n = 13
# C[C@@H]1[C@@H]([C@@H](n2c(ncn2)N1)c3ccc(c(c3)OC)OCC(=O)N)C(=O)Nc4ccccc4
# La molecula C20803423 fue correctamente procesada con Openbabel, verificar en el archivo, n = 14
# Cc1ccc(cc1)S(=O)(=O)OC[C@@H]2[C@@H]([C@H]([C@@H](O2)n3cnc4c3ncnc4N)O)O
# La molecula C22067032 fue correctamente procesada con Openbabel, verificar en el archivo, n = 15
# Cc1c2c(c(sc2nc(n1)C)C(=O)O[C@H](C)C(=O)Nc3c4c(nc[nH]4)ncn3)N
# La molecula C23076886 fue correctamente procesada con Openbabel, verificar en el archivo, n = 16
# Cc1c2c(c(sc2nc(n1)C)C(=O)O[C@@H](C)C(=O)Nc3c4c(nc[nH]4)ncn3)N
# La molecula C23076888 fue correctamente procesada con Openbabel, verificar en el archivo, n = 17
# C[C@@H](C(=O)Nc1ccc(cc1)NC(=O)NCc2ccco2)NC(=O)c3ccco3
# La molecula C25656366 fue correctamente procesada con Openbabel, verificar en el archivo, n = 18
# CCCS(=O)(=O)Nc1ccc(n(c1=O)CC(=O)N[C@H]2CCc3c(sc(n3)N)C2)C
# La molecula C26960173 fue correctamente procesada con Openbabel, verificar en el archivo, n = 19
# Cc1c2c(cc(nc2on1)c3ccco3)C(=O)Nc4nc(cs4)c5cc([nH]c5)C(=O)N
# La molecula C30984077 fue correctamente procesada con Openbabel, verificar en el archivo, n = 20
# CCOc1cc(cc(c1O)Br)/C=N\NC(=O)CCc2c(=O)[nH]c(=O)[nH]n2
# La molecula C31906020 fue correctamente procesada con Openbabel, verificar en el archivo, n = 21
# Cc1ccc(cc1)S(=O)(=O)O[C@H]2[C@H]([C@@H](O[C@@H]2n3cnc4c3ncnc4N)CO)O
# La molecula C35395411 fue correctamente procesada con Openbabel, verificar en el archivo, n = 22
# Cc1c(c(=O)[nH]c(=O)[nH]1)/C=N\NC(=O)[C@@H](C)Cc2c(nc([nH]c2=O)c3ccccc3)C
# La molecula C35993638 fue correctamente procesada con Openbabel, verificar en el archivo, n = 23
# CC1=C([C@H](C(=C(O1)N)C#N)c2cc(c(cc2Cl)OCC(=O)N)OC)C(=O)OC
# La molecula C00814145 fue correctamente procesada con Openbabel, verificar en el archivo, n = 24
# CC1=C([C@@H](C(=C(O1)N)C#N)c2cc(c(cc2Cl)OCC(=O)N)OC)C(=O)OC
# La molecula C00814147 fue correctamente procesada con Openbabel, verificar en el archivo, n = 25
# CC(C)Cn1c(c(c(=O)n(c1=O)C)C(=O)COC(=O)c2ccc(cc2O)O)N
# La molecula C06080921 fue correctamente procesada con Openbabel, verificar en el archivo, n = 26
# Cc1cc(no1)NC(=O)CSC2=NN[C@H](N2c3ccccc3)Cc4cc(=O)[nH]c(=O)[nH]4
# La molecula C39361610 fue correctamente procesada con Openbabel, verificar en el archivo, n = 27
# CN(C)c1ccc(cc1C(=O)NCC(=O)Nc2ccc3c(c2)[nH]c(=O)[nH]3)[N+](=O)[O-]
# La molecula C39558636 fue correctamente procesada con Openbabel, verificar en el archivo, n = 28
# CCn1c2ccccc2n(c1=O)CCC(=O)NCC(=O)Nc3ccc4c(c3)[nH]c(=O)[nH]4
# La molecula C39558977 fue correctamente procesada con Openbabel, verificar en el archivo, n = 29
# C[C@H]1C[C@]2(CC(C1)(C)C)C(=O)N(C(=O)N2)CC(=O)OCC(=O)Nc3c(ccs3)C(=O)N
# La molecula C22001321 fue correctamente procesada con Openbabel, verificar en el archivo, n = 30
# C[C@H]1C[C@@]2(CC(C1)(C)C)C(=O)N(C(=O)N2)CC(=O)OCC(=O)Nc3c(ccs3)C(=O)N
# La molecula C22001309 fue correctamente procesada con Openbabel, verificar en el archivo, n = 31
# Cc1c(c(=O)[nH]c(n1)S[C@H](C)C(=O)NC(=O)NC(C)(C)C)CCC(=O)O
# La molecula C13451071 fue correctamente procesada con Openbabel, verificar en el archivo, n = 32
# CC(C)C(=O)Nc1[nH]c(=O)c2c(n1)n(c(n2)OCc3ccccc3)[C@H]4C[C@@H]([C@H](O4)CO)O
# La molecula C43771685 fue correctamente procesada con Openbabel, verificar en el archivo, n = 33
# Cc1c(cco1)c2nnc(n2N)SCC(=O)NN3C(=O)[C@](NC3=O)(C)c4ccccc4
# La molecula C45267017 fue correctamente procesada con Openbabel, verificar en el archivo, n = 34
# CC(C)(C)NS(=O)(=O)c1ccccc1CNC(=O)N2CCO[C@H](C2)C(=O)N
# La molecula C51713303 fue correctamente procesada con Openbabel, verificar en el archivo, n = 35
# Cc1ccc(cc1[N+](=O)[O-])NC(=O)[C@@H]2CC(=O)Nc3c2c(nc(n3)N4CCCC4)N
# La molecula C19974115 fue correctamente procesada con Openbabel, verificar en el archivo, n = 36
# C[NH+](C)[C@H](CNC(=O)NNC(=O)c1c(cn(n1)c2ccccc2)[O-])c3ccco3
# La molecula C54919882 fue correctamente procesada con Openbabel, verificar en el archivo, n = 37
# CCCCn1c(c(c(=O)[nH]c1=O)N(CC(C)C)C(=O)c2ccc([nH]c2=O)C)N
# La molecula C58038616 fue correctamente procesada con Openbabel, verificar en el archivo, n = 38
# CCC(C)(C)C1CCC2(CC1)C(=O)N(C(=O)N2)CC(=O)Nc3cnn(c3)CC(=O)N
# La molecula C47235011 fue correctamente procesada con Openbabel, verificar en el archivo, n = 39
# C[C@H]1[C@H]([C@@H](n2c(ncn2)N1)c3ccc(c(c3)OC)OCC(=O)N)C(=O)Nc4ccccc4
# La molecula C59669476 fue correctamente procesada con Openbabel, verificar en el archivo, n = 40
# C[C@H](C(=O)NNC(=O)C1CCC1)Sc2nnc(n2N)c3cccc(c3)[N+](=O)[O-]
# La molecula C59882810 fue correctamente procesada con Openbabel, verificar en el archivo, n = 41
# COCCCN1C(=O)[C@H]2[C@@H](N[C@@]3([C@@H]2C1=O)c4cc(ccc4NC3=O)Cl)CC(=O)N
# La molécula C20548992 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 42
# CNS(=O)(=O)Cc1cccc(c1)CNC(=O)c2cc(cc(c2N)[N+](=O)[O-])F
# La molecula C64534955 fue correctamente procesada con Openbabel, verificar en el archivo, n = 43
# COc1cc(cc(c1O)OC)[C@@H]2C/C(=C/3\C(=O)NC(=O)N(C3=O)Cc4ccccc4)/NN2
# La molecula C64788507 fue correctamente procesada con Openbabel, verificar en el archivo, n = 44
# COc1cc(cc(c1O)OC)[C@H]2C/C(=C/3\C(=O)NC(=O)N(C3=O)Cc4ccccc4)/NN2
# La molecula C64788511 fue correctamente procesada con Openbabel, verificar en el archivo, n = 45
# CC(C)(C)NS(=O)(=O)c1ccc(o1)C(=O)NNC(=O)NC[C@@H]2CCCO2
# La molecula C65146163 fue correctamente procesada con Openbabel, verificar en el archivo, n = 46
# Cc1cc(c(o1)C)[C@@H](C)NC(=O)NNc2ccc(cn2)S(=O)(=O)NC(C)C
# La molecula C65499076 fue correctamente procesada con Openbabel, verificar en el archivo, n = 47
# CC[C@@]1(C(=O)N(C(=O)N1)NC(=O)CNc2ccc(c(c2)C)C(=O)NC(C)C)C
# La molecula C66470856 fue correctamente procesada con Openbabel, verificar en el archivo, n = 48
# Cc1cccc(c1)OC[C@H](CNC(=O)C(=O)Nc2ccc3c(c2)NC(=O)CO3)O
# La molecula C67444032 fue correctamente procesada con Openbabel, verificar en el archivo, n = 49
# Cc1cc([nH]c(=O)c1CNC(=O)NC[C@H](COc2ccc3c(c2)OCO3)O)C
# La molecula C67590756 fue correctamente procesada con Openbabel, verificar en el archivo, n = 50
# ligand
# La molécula COc5ccc(c3n[nH]c4c2cccc(NC(=O)Cc1ccc(N)cc1)c2c(=O)c34)cc5 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 0
# C[C@@]12CC[C@H]([C@@]([C@H]1Cc3c(nc(s3)NC)[C@H]2CC(=O)NCc4cccs4)(C)CO)O
# La molécula C03841007 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 1
# COC(=O)NC(C(F)(F)F)(C(F)(F)F)Nc1c(c2c(s1)CCCC2)C(=O)N
# La molecula C00978333 fue correctamente procesada con Openbabel, verificar en el archivo, n = 2
# CC(C)Oc1ccc(cc1)C(=O)NC(=S)Nc2c(c3c(s2)CCC3)C(=O)N
# La molecula C06263063 fue correctamente procesada con Openbabel, verificar en el archivo, n = 3
# Cc1ccccc1NC(=S)NNC(=O)CNC(=O)C23CC4CC(C2)CC(C4)C3
# La molecula C05700436 fue correctamente procesada con Openbabel, verificar en el archivo, n = 4
# Cc1cccc(c1)OCC(=O)NC(=S)Nc2c(c3c(s2)CCCC3)C(=O)N
# La molecula C08320826 fue correctamente procesada con Openbabel, verificar en el archivo, n = 5
# c1ccnc(c1)/C=C/c2cccc(c2)NC(=O)C[C@H](c3ccc(cc3)Cl)NC(=O)N
# La molecula C08346238 fue correctamente procesada con Openbabel, verificar en el archivo, n = 6
# C[C@@H]1CCC[C@H]([C@@H]1C)NC(=S)NNC(=O)CNC(=O)c2ccccc2Cl
# La molecula C08418740 fue correctamente procesada con Openbabel, verificar en el archivo, n = 7
# CC(C)(C#Cc1ccc(s1)C(=O)NCCCNC(=O)c2ccc(s2)C#CC(C)(C)O)O
# La molecula C02859205 fue correctamente procesada con Openbabel, verificar en el archivo, n = 8
# Cc1c(sc(c1C(=O)N)NC(=S)NC(=O)COc2cccc3c2cccc3)C
# La molecula C12499441 fue correctamente procesada con Openbabel, verificar en el archivo, n = 9
# Cc1ccc(c(c1)OCC(=O)NC(=S)Nc2c(c(c(s2)C)C)C(=O)N)C
# La molecula C12499608 fue correctamente procesada con Openbabel, verificar en el archivo, n = 10
# Cc1c(sc(c1C(=O)N)NC(=S)NC(=O)/C=C/c2ccc(cc2)OC)C
# La molecula C12500087 fue correctamente procesada con Openbabel, verificar en el archivo, n = 11
# Cc1c(sc(c1C(=O)N)NC(=S)NC(=O)COc2ccccc2Cl)C
# La molecula C12500347 fue correctamente procesada con Openbabel, verificar en el archivo, n = 12
# Cc1c(c(sc1C(=O)N/N=C/c2cc(c(c(c2)Br)O)Br)N)C#N
# La molecula C15018641 fue correctamente procesada con Openbabel, verificar en el archivo, n = 13
# c1ccc(cc1)C2=C([C@H](NC(=S)N2)c3ccc(cc3)OCC(=O)N)C(=O)c4ccccc4
# La molecula C01126696 fue correctamente procesada con Openbabel, verificar en el archivo, n = 14
# Cc1ccccc1NC(=O)C2=C(NC(=C([C@@H]2c3cccs3)C#N)SCC(=O)N)C
# La molecula C04019913 fue correctamente procesada con Openbabel, verificar en el archivo, n = 15
# Cc1ccccc1NC(=O)C2=C(NC(=C([C@@H]2c3ccccc3Cl)C#N)SCC(=O)N)C
# La molecula C01196773 fue correctamente procesada con Openbabel, verificar en el archivo, n = 16
# CNC(=O)NC(=O)[C@@H](c1ccccc1)OC(=O)c2cc(ccc2N)Br
# La molecula C21741995 fue correctamente procesada con Openbabel, verificar en el archivo, n = 17
# Cc1cccc(c1NC(=O)/C(=N\NC(=S)N)/[C@H](C)C(=O)c2ccc(cc2)Cl)C
# La molecula C17191854 fue correctamente procesada con Openbabel, verificar en el archivo, n = 18
# CC[C@@]1(CC2=C(CO1)S[C@@H]3C2=C([N-]C(=N3)SCC(=O)Nc4ccc(cc4)Cl)[NH3+])C
# La molecula C34789289 fue correctamente procesada con Openbabel, verificar en el archivo, n = 19
# CC(C)(C)c1ccc(cc1)C(=O)NNC(=O)CNC(=O)NCc2ccc(cc2)F
# La molecula C14347881 fue correctamente procesada con Openbabel, verificar en el archivo, n = 20
# CC[C@H](c1ccccc1)C(=O)N(C)[C@@H](c2c(cc(cc2O)O)O)C(=O)NC(C)(C)C
# La molecula C36527329 fue correctamente procesada con Openbabel, verificar en el archivo, n = 21
# CCCN([C@@H](c1ccc(cc1)O)C(=O)NC(C)(C)C)C(=O)c2c(cccc2O)O
# La molecula C36570930 fue correctamente procesada con Openbabel, verificar en el archivo, n = 22
# CCCN([C@@H](c1ccccc1O)C(=O)NC(C)(C)C)C(=O)c2cccc(c2O)O
# La molecula C36571282 fue correctamente procesada con Openbabel, verificar en el archivo, n = 23
# Cc1cc(c(cc1Cl)OC)NC(=O)CSC2=C(C3(CCCCC3)C(=C(N2)N)C#N)C#N
# La molecula C39335357 fue correctamente procesada con Openbabel, verificar en el archivo, n = 24
# c1ccc2c(c1)C[NH+]3[C@@H](CC(=C3N2)Cl)C(=O)N(c4ccccc4O)c5ccccc5O
# La molecula C39545413 fue correctamente procesada con Openbabel, verificar en el archivo, n = 25
# C[C@]12CC[C@](C1(C)C)(C[C@H]2O)C(=O)NCCCNC(=O)[C@@]34CC[C@@](C3(C)C)([C@H](C4)O)C
# La molecula C08533998 fue correctamente procesada con Openbabel, verificar en el archivo, n = 26
# C[C@]12C[C@H](CC(C1)(C)C)N(C2)c3c(c(ncn3)NNC(=O)c4ccccc4Br)N
# La molécula C40735114 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 27
# C[C@@H]1CCC[C@@H]([C@@H]1C)NC(=S)NNC(=O)CNC(=O)c2ccc(cc2F)F
# La molecula C42759343 fue correctamente procesada con Openbabel, verificar en el archivo, n = 28
# C[C@H]1CCC[C@H]([C@@H]1C)NC(=S)NNC(=O)CNC(=O)c2ccc(cc2F)F
# La molecula C42759351 fue correctamente procesada con Openbabel, verificar en el archivo, n = 29
# c1ccc2c(c1)-c3ccccc3C2COC(=O)N[C@@H](CCO)c4ccc(c(c4)O)O
# La molecula C44198012 fue correctamente procesada con Openbabel, verificar en el archivo, n = 30
# c1ccc(c(c1)OCCCC(=O)Nc2ccc(cc2)NC(=O)N)Br
# La molecula C45079151 fue correctamente procesada con Openbabel, verificar en el archivo, n = 31
# C[C@@H]1CCc2c(sc3c2c(nc(n3)SCC(=O)N(CCC(=O)N)c4ccccc4)N)C1
# La molecula C45555403 fue correctamente procesada con Openbabel, verificar en el archivo, n = 32
# C[C@H]1CCCC[C@@]12C(=O)N(C(=O)N2)CC(=O)Nc3cc(c(c(c3)Cl)N)Cl
# La molecula C45629601 fue correctamente procesada con Openbabel, verificar en el archivo, n = 33
# Cc1ccccc1[C@H](CC(=O)NCc2ccc(o2)c3ccc(cc3)Br)NC(=O)N
# La molecula C46673644 fue correctamente procesada con Openbabel, verificar en el archivo, n = 34
# c1ccc(cc1)C(=NNC(=O)C[C@H](c2cccs2)NC(=O)N)c3ccccc3
# La molecula C11405504 fue correctamente procesada con Openbabel, verificar en el archivo, n = 35
# C1CCC(C1)NC(=O)CCNC(=O)NNC(=O)CC23CC4CC(C2)CC(C4)C3
# La molecula C54751840 fue correctamente procesada con Openbabel, verificar en el archivo, n = 36
# C[C@@H](Cc1ccc(cc1)O)NC(=O)Nc2ccc(cc2)S(=O)(=O)NC(C)C
# La molecula C56574766 fue correctamente procesada con Openbabel, verificar en el archivo, n = 37
# c1ccc2cc(c(cc2c1)C(=O)NNC(=O)c3ccc4c(c3)NC(=O)CS4)O
# La molecula C57028380 fue correctamente procesada con Openbabel, verificar en el archivo, n = 38
# C[C@@H]([C@H]1C[C@@H]([C@@]2(N1)c3cccc(c3NC2=O)Cl)C(=O)Nc4cc(ccc4OC)Cl)O
# La molecula C57142871 fue correctamente procesada con Openbabel, verificar en el archivo, n = 39
# C[C@H]([C@H]1C[C@@H]([C@@]2(N1)c3cccc(c3NC2=O)Cl)C(=O)Nc4cc(ccc4OC)Cl)O
# La molecula C13592204 fue correctamente procesada con Openbabel, verificar en el archivo, n = 40
# CCCNc1ccc(cc1NS(=O)(=O)c2c(c(cc(c2C)C)C)C)S(=O)(=O)N
# La molecula C26540782 fue correctamente procesada con Openbabel, verificar en el archivo, n = 41
# c1ccc(cc1)[C@@H](CCC(=O)N/N=C\c2cc(c(cc2O)O)I)O
# La molecula C58887293 fue correctamente procesada con Openbabel, verificar en el archivo, n = 42
# Cc1cc(ccc1Br)C(=O)CSc2nc([nH]n2)N/N=C(\C)/c3ccc(cc3)N
# La molecula C59309563 fue correctamente procesada con Openbabel, verificar en el archivo, n = 43
# C/C(=N\NC(=O)CNC(=O)C(c1ccccc1)c2ccccc2)/c3cc(ccc3O)O
# La molecula C15133323 fue correctamente procesada con Openbabel, verificar en el archivo, n = 44
# Cc1cc(ccc1N2[C@@H](N[C@@H](N2)CC(C)C)Cc3c([nH]c(=O)[nH]c3=O)C)Cl
# La molecula C65531809 fue correctamente procesada con Openbabel, verificar en el archivo, n = 45
# Cc1ccccc1[C@@H](CC(=O)N[C@@H](C#N)c2ccc(cc2)C(C)(C)C)NC(=O)N
# La molecula C66396556 fue correctamente procesada con Openbabel, verificar en el archivo, n = 46
# Cc1ccccc1[C@H](CC(=O)N[C@@H](C#N)c2ccc(cc2)C(C)(C)C)NC(=O)N
# La molecula C66396557 fue correctamente procesada con Openbabel, verificar en el archivo, n = 47
# C[C@H]1C[C@@H](CC(C1)(C)C)CC(=O)NNC(=S)Nc2cccc(c2)NC(=O)C
# La molecula C67193419 fue correctamente procesada con Openbabel, verificar en el archivo, n = 48
# C[C@@H]1CCC[C@H]([C@@H]1C)NC(=S)NNC(=O)CNC(=O)c2cc(cc(c2)F)F
# La molecula C67463606 fue correctamente procesada con Openbabel, verificar en el archivo, n = 49
# c1ccc2cc(ccc2c1)[C@H](CNC(=O)NCCNc3cccc(c3C#N)F)O
# La molecula C67627565 fue correctamente procesada con Openbabel, verificar en el archivo, n = 50
# ligand
# La molécula C[NH+]5CCN(CCOc4cc(F)c(C(=O)c2c(N)nc3ccc(C(=O)c1c(Cl)cccc1Cl)cn23)c(F)c4)CC5 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 0
# c1cc(cc(c1)Br)OC[C@H](C[NH+]2CCN(CC2)S(=O)(=O)c3cc(ccc3Cl)C(F)(F)F)O
# La molecula C02651171 fue correctamente procesada con Openbabel, verificar en el archivo, n = 1
# CCC(C)(C)n1c(nnn1)[C@@H](c2cc3c(cc(cc3[nH]c2=O)C)C)[NH+](Cc4ccccc4)Cc5cccs5
# La molecula C06149032 fue correctamente procesada con Openbabel, verificar en el archivo, n = 2
# CCC(C)(C)n1c(nnn1)[C@@H](c2cc3cc(cc(c3[nH]c2=O)C)C)[NH+](Cc4ccccc4)Cc5cccs5
# La molecula C06149113 fue correctamente procesada con Openbabel, verificar en el archivo, n = 3
# CCC(C)(C)n1c(nnn1)[C@@H](c2cc3cc(ccc3[nH]c2=O)OCC)[NH+]4CCN(CC4)c5cc(ccc5C)C
# La molecula C06077575 fue correctamente procesada con Openbabel, verificar en el archivo, n = 4
# CCC(C)(C)n1c(nnn1)[C@H](c2cc3cc(ccc3[nH]c2=O)OCC)[NH+]4CCN(CC4)c5cc(ccc5C)C
# La molecula C06077754 fue correctamente procesada con Openbabel, verificar en el archivo, n = 5
# Cc1ccc2c(c1)cc(c(=O)[nH]2)[C@@H](c3nnnn3C4CCCCC4)[NH+]5CCN(CC5)c6nc7ccccc7s6
# La molecula C00907470 fue correctamente procesada con Openbabel, verificar en el archivo, n = 6
# CC(C)CN1[C@H]([C@@H](c2ccccc2C1=O)C(=O)NCCC[NH+](Cc3ccco3)C4CCCC4)c5cccs5
# La molecula C09433320 fue correctamente procesada con Openbabel, verificar en el archivo, n = 7
# CC(C)CN1[C@H]([C@H](c2ccccc2C1=O)C(=O)NCCC[NH+](Cc3ccco3)C4CCCC4)c5cccs5
# La molecula C09433322 fue correctamente procesada con Openbabel, verificar en el archivo, n = 8
# CCOC(=O)c1c(n(c2c1c(c(cc2)OC)NC(=O)C[NH+]3CCn4c5ccc(cc5c6c4[C@@H]3CCC6)C)C)C
# La molecula C02449566 fue correctamente procesada con Openbabel, verificar en el archivo, n = 9
# CC(C)[NH+](CCNC(=O)CCc1nnc2n1c3ccccc3c(=O)n2Cc4ccc(cc4)F)Cc5ccco5
# La molecula C09831442 fue correctamente procesada con Openbabel, verificar en el archivo, n = 10
# Cc1c(c2ccccc2n1Cc3ccc(cc3Cl)Cl)C[NH2+]CCSc4nnnn4c5ccccc5
# La molecula C10315666 fue correctamente procesada con Openbabel, verificar en el archivo, n = 11
# CN(C)c1ccc(cc1)[C@H]2[C@@H]3[C@H](C(=O)N(C3=O)c4ccc5c(c4)OCCO5)[C@@]([NH2+]2)(c6ccccc6)C(=O)OC
# La molecula C12498019 fue correctamente procesada con Openbabel, verificar en el archivo, n = 12
# CN(C)c1ccc(cc1)[C@H]2[C@@H]3[C@H](C(=O)N(C3=O)c4ccc5c(c4)OCCO5)[C@]([NH2+]2)(c6ccccc6)C(=O)OC
# La molecula C12498021 fue correctamente procesada con Openbabel, verificar en el archivo, n = 13
# CC[C@H](c1nnnn1CCc2ccccc2)[NH+](Cc3ccc(cc3)F)Cc4cc5ccc(c(c5[nH]c4=O)C)C
# La molecula C13065138 fue correctamente procesada con Openbabel, verificar en el archivo, n = 14
# Cc1ccc2cc(c(=O)[nH]c2c1)[C@H](c3nnnn3C4CCCCC4)[NH+](Cc5ccccc5)Cc6cccs6
# La molecula C06410001 fue correctamente procesada con Openbabel, verificar en el archivo, n = 15
# CC(C)CCn1c(=O)c2ccccc2n3c1nnc3C[NH+]4CCC(CC4)C(c5ccccc5)(c6ccccc6)O
# La molecula C13146152 fue correctamente procesada con Openbabel, verificar en el archivo, n = 16
# CC[C@@H](c1nnnn1Cc2ccc(cc2)F)[NH+](CCc3ccccc3)Cc4cc5cc(cc(c5[nH]c4=O)C)C
# La molecula C13495845 fue correctamente procesada con Openbabel, verificar en el archivo, n = 17
# Cc1cccc(c1C)N2CC[NH+](CC2)[C@@H](c3cc4c(cc(cc4[nH]c3=O)C)C)c5nnnn5Cc6ccccc6
# La molecula C06442868 fue correctamente procesada con Openbabel, verificar en el archivo, n = 18
# CC[NH+](CC)CCCN1[C@@H](/C(=C(/c2ccc3c(c2)C[C@H](O3)C)\O)/C(=O)C1=O)c4ccc(cc4)Br
# La molecula C09311979 fue correctamente procesada con Openbabel, verificar en el archivo, n = 19
# CCC[C@]1([C@@H]2[C@@H]([C@H]([NH2+]1)c3ccc(cc3OC)OC)C(=O)N(C2=O)c4ccc5c(c4)OCCO5)C(=O)OCC
# La molecula C12497968 fue correctamente procesada con Openbabel, verificar en el archivo, n = 20
# Cc1ccc(s1)c2ccc(c(n2)N3CCC(CC3)[NH+]4CCC(CC4)O)C(=O)NC[C@H]5C[C@H]6C=C[C@@H]5C67CC7
# La molecula C19955551 fue correctamente procesada con Openbabel, verificar en el archivo, n = 21
# Cc1ccc(cc1)/C=C/c2c(c(no2)C)S(=O)(=O)N3CCC(CC3)C(=O)NCC[NH+](C)C4CCCCC4
# La molecula C21090373 fue correctamente procesada con Openbabel, verificar en el archivo, n = 22
# CC[NH+]1CCN(CC1)c2ccc(cc2NC(=O)c3cc(ccc3N4CCC(CC4)C)[N+](=O)[O-])C(=O)OCC
# La molecula C30828310 fue correctamente procesada con Openbabel, verificar en el archivo, n = 23
# C[NH+](C)[C@H](CNC(=O)[C@@H]1Cc2ccccc2CN1S(=O)(=O)c3ccc(cc3)Cl)c4ccc(cc4)OC
# La molecula C32960887 fue correctamente procesada con Openbabel, verificar en el archivo, n = 24
# Cc1ccccc1C(=O)N2CC[NH+](CC2)CCN(CC3=CC[C@H]4C[C@@H]3C4(C)C)C(=O)Nc5ccc(cc5)Cl
# La molecula C35097080 fue correctamente procesada con Openbabel, verificar en el archivo, n = 25
# Cc1cccc(c1)CO[C@]2(C[C@@H]3[C@H]([C@H](C2)OCc4cccc(c4)Cl)OC(O3)(C)C)C(=O)NCC[NH+](C)C
# La molecula C35591777 fue correctamente procesada con Openbabel, verificar en el archivo, n = 26
# CCN1C(=C([C@@H](NC1=O)c2ccc(c(c2)Cl)Cl)C(=O)OCC)C[NH+]3CCCN(CC3)C(=O)C(C)C
# La molecula C35642029 fue correctamente procesada con Openbabel, verificar en el archivo, n = 27
# CCN1C(=C([C@H](NC1=O)c2ccc(c(c2)Cl)Cl)C(=O)OCC)C[NH+]3CCCN(CC3)C(=O)C4CC4
# La molecula C35642035 fue correctamente procesada con Openbabel, verificar en el archivo, n = 28
# CCN1C(=C([C@@H](NC1=O)c2ccc(cc2)OC)C(=O)OCC)C[NH+]3CCCN(CC3)C(=O)c4cccs4
# La molecula C35646539 fue correctamente procesada con Openbabel, verificar en el archivo, n = 29
# Cc1ccc(s1)C[NH+](Cc2ccc(o2)C(c3ccc(cc3)OC)(c4ccc(cc4)OC)O)C[C@@H]5CCCO5
# La molecula C35745398 fue correctamente procesada con Openbabel, verificar en el archivo, n = 30
# c1ccc(c(c1)C(=O)N2CCCN(CC2)c3[nH]c(=O)cc(n3)C[NH+]4CCN(CC4)c5ccccc5F)Cl
# La molecula C35926300 fue correctamente procesada con Openbabel, verificar en el archivo, n = 31
# CC[C@@H](c1ccccc1)C(=O)N2CCN(CC2)c3[nH]c(=O)cc(n3)C[NH+]4CCN(CC4)Cc5ccc(cc5)F
# La molecula C35926667 fue correctamente procesada con Openbabel, verificar en el archivo, n = 32
# CCN1C(=C([C@@H](NC1=O)c2ccc(cc2)C(C)C)C(=O)OCC)C[NH+]3CCCN(CC3)C(=O)C4CCCC4
# La molecula C36013832 fue correctamente procesada con Openbabel, verificar en el archivo, n = 33
# CCN1C(=C([C@H](NC1=O)c2ccc(cc2)Cl)C(=O)OCC)C[NH+]3CCCN(CC3)C(=O)c4cccs4
# La molecula C36013871 fue correctamente procesada con Openbabel, verificar en el archivo, n = 34
# CC(C)c1ccc(cc1)OC[C@H]2c3ccsc3CCN2C(=O)CN(CC[NH+]4CCCC4)C(=O)NC(C)C
# La molecula C36122163 fue correctamente procesada con Openbabel, verificar en el archivo, n = 35
# Cc1ccccc1n2c3c(c(n2)C(C)(C)C)[C@H](SCC(=O)N3CC(=O)NCC[NH+](C)C)c4ccsc4
# La molecula C37264027 fue correctamente procesada con Openbabel, verificar en el archivo, n = 36
# CCOc1ccc(cc1OC)[C@H]2c3c(c4ccccc4[nH]3)C[C@@H]5N2C(=O)CN(C5=O)C6CC[NH+](CC6)Cc7ccccc7
# La molecula C01318672 fue correctamente procesada con Openbabel, verificar en el archivo, n = 37
# C[C@H]([C@@H](c1cccs1)N2CC[NH+](CC2)Cc3ccccc3)NC(=O)c4cc(c(cc4[N+](=O)[O-])OC)OC
# La molécula C38596018 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 38
# C[C@H]([C@H](c1cccs1)N2CC[NH+](CC2)Cc3ccccc3)NC(=O)c4cc(c(cc4[N+](=O)[O-])OC)OC
# La molécula C38596020 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 39
# Cc1ccc(c(c1F)C(=O)N2C[C@@H](C3(C2)CC[NH2+]CC3)C(=O)N[C@@H]4CCC[C@H]4OCc5ccccc5)Cl
# La molecula C39609039 fue correctamente procesada con Openbabel, verificar en el archivo, n = 40
# Cc1ccccc1OCC(=O)c2ccc3c(c2)N(C(=O)CO3)Cc4ccc(o4)C(=O)NCC[NH+]5CCCCC5
# La molecula C40410690 fue correctamente procesada con Openbabel, verificar en el archivo, n = 41
# CC[C@@H](C)[C@H]1C(=O)N(C2([NH2+]1)CCN(CC2)S(=O)(=O)c3cccc(c3)C(F)(F)F)Cc4ccc(cc4)F
# La molécula C36024455 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 42
# CC[C@H](C)[C@H]1C(=O)N(C2([NH2+]1)CCN(CC2)S(=O)(=O)c3ccc(cc3)C)CCc4ccc(c(c4)OC)OC
# La molécula C36028117 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 43
# Cc1cccc(n1)CCCOCCc2cc3c(cc2OC)[C@@H]4C(=C(N=[NH+]4)c5ccc(cc5)c6ccc(cc6)O)C3
# La molecula C52636936 fue correctamente procesada con Openbabel, verificar en el archivo, n = 44
# COc1ccc(cc1)/C=N/n2cc([nH+]c2/N=C/c3cc(cc(c3O)Br)Br)c4ccccc4
# La molecula C01821179 fue correctamente procesada con Openbabel, verificar en el archivo, n = 45
# CCCOC(=O)c1ccc(cc1)Oc2c(oc3c(c2=O)ccc(c3CN4CCN(CC4)c5cccc[nH+]5)O)C
# La molecula C41585982 fue correctamente procesada con Openbabel, verificar en el archivo, n = 46
# COc1ccc(cc1OC)[C@@H](C(=O)NC2CCCCC2)N(Cc3ccco3)C(=O)CC4=c5ccccc5=[NH+]C4
# La molecula C63205565 fue correctamente procesada con Openbabel, verificar en el archivo, n = 47
# CC(=O)[C@@H]1CC[C@H]2[C@@]1(CC[C@@H]3[C@@H]2CCC4=C/C(=N/OCC(=O)NCC[C@@H]5C=c6ccccc6=[NH+]5)/CC[C@]34C)C
# La molecula C63351383 no corrió adecuadamente y el proceso fue detenido abruptamente, n = 48
# CC(C)CCNC(=O)c1ccccc1N2C(=O)[C@@H]3CC4=c5ccccc5=[NH+][C@@H]4[C@@H](N3C2=O)c6ccc(cc6)F
# La molécula C63375837 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 49
# Cc1ccc(c(c1)C)NC(=O)CS[C@@H]2N=N[C@@H](O2)[C@H](CC3=c4ccccc4=[NH+]C3)NC(=O)OC(C)(C)C
# La molécula C63426767 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 50
# ligand
# La molécula COc1ccc6c(c1)n(CCC[NH+]2CCC(O)CC2)c7c4ccc3ccn(C)c3c4c5c(=O)[nH]c(=O)c5c67 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 0
# Cc1cccc2c1NC(=O)[C@]23[C@H]([C@@]4(c5ccccc5NC4=O)[C@H]6[NH+]3CCC6)C(=O)c7cccc(c7)[N+](=O)[O-]
# La molécula C09123840 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 1
# c1cc(oc1)Cn2c3c(c(=O)[nH]c2=O)C([NH+]=C(N3)c4ccc(cc4)F)(C(F)(F)F)C(F)(F)F
# La molecula C09312867 fue correctamente procesada con Openbabel, verificar en el archivo, n = 2
# c1ccc2c(c1)[C@@]3([C@H]([C@@H]4CCC[NH+]4[C@@]35c6cc(ccc6NC5=O)F)C(=O)c7cccc(c7)[N+](=O)[O-])C(=O)N2
# La molécula C09329440 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 3
# Cc1ccc2c(c1)[C@@]3(C(=O)N2)[C@]4(c5ccccc5NC4=O)[C@@H]([C@@H]6[NH+]3CCC6)C(=O)c7cccc(c7)[N+](=O)[O-]
# La molécula C09357622 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 4
# C[NH+]1CCc2c(sc3c2C(=O)N[C@@H](N3)c4ccccc4OC(=O)c5cc(c(c(c5)OC)OC)OC)C1
# La molecula C13596117 fue correctamente procesada con Openbabel, verificar en el archivo, n = 5
# Cc1cccc2c1NC(=O)[C@@]23[C@@H]([C@@]4(c5ccccc5NC4=O)[C@H]6[NH+]3CCC6)C(=O)c7cccc(c7)[N+](=O)[O-]
# La molecula C16011521 fue correctamente procesada con Openbabel, verificar en el archivo, n = 6
# Cc1ccc2c(c1)[C@]3(C(=O)N2)[C@@]4(c5ccccc5NC4=O)[C@@H]([C@@H]6[NH+]3CCC6)C(=O)c7cccc(c7)[N+](=O)[O-]
# La molecula C16020777 fue correctamente procesada con Openbabel, verificar en el archivo, n = 7
# c1cc(ccc1C[NH+]2CCC(CC2)CNS(=O)(=O)c3ccc(s3)c4ccc(=O)[nH]n4)Cl
# La molecula C20984961 fue correctamente procesada con Openbabel, verificar en el archivo, n = 8
# c1ccc(cc1)c2csc3c2c(nc(n3)SCC(=O)N)N4CC[NH+](CC4)CC(=O)N5CCCCC5
# La molecula C34774715 fue correctamente procesada con Openbabel, verificar en el archivo, n = 9
# Cc1cc(c(o1)C(F)(F)F)C(=O)N2C[C@H](C3(C2)CC[NH2+]CC3)C(=O)NC[C@H](C)Oc4ccc(cc4)F
# La molecula C39596382 fue correctamente procesada con Openbabel, verificar en el archivo, n = 10
# Cc1ccc(cc1C)CCNC(=O)[C@@H]2CN(CC23CC[NH2+]CC3)C(=O)[C@@H]4COc5ccccc5O4
# La molecula C39609320 fue correctamente procesada con Openbabel, verificar en el archivo, n = 11
# c1ccc2c(c1)OC[C@@H](O2)C(=O)N3C[C@H](C4(C3)CC[NH2+]CC4)C(=O)NCc5ccc(c(c5)Cl)Cl
# La molecula C39609766 fue correctamente procesada con Openbabel, verificar en el archivo, n = 12
# CCn1c(c(c(n1)C)Br)C(=O)N2C[C@@H](C3(C2)CC[NH2+]CC3)C(=O)N[C@@H]4CCC[C@@H]([C@@H]4C)C
# La molecula C39637429 fue correctamente procesada con Openbabel, verificar en el archivo, n = 13
# CCOc1ccccc1CNC(=O)[C@H]2CN(CC23CC[NH2+]CC3)C(=O)c4ccc(o4)c5ccccc5
# La molecula C39638742 fue correctamente procesada con Openbabel, verificar en el archivo, n = 14
# COc1cc(cc(c1)OC)CCNC(=O)[C@@H]2CN(CC23CC[NH2+]CC3)C(=O)c4csc5c4cccc5
# La molecula C39653136 fue correctamente procesada con Openbabel, verificar en el archivo, n = 15
# Cc1ccsc1C(=O)N2C[C@H](C3(C2)CC[NH2+]CC3)C(=O)NC[C@H](c4ccccc4)N5CCOCC5
# La molecula C39664482 fue correctamente procesada con Openbabel, verificar en el archivo, n = 16
# Cc1ccccc1CC(=O)N2C[C@@H](C3(C2)CC[NH2+]CC3)C(=O)NC[C@H](c4ccccc4)N5CCOCC5
# La molecula C39664489 fue correctamente procesada con Openbabel, verificar en el archivo, n = 17
# C[C@@H](CNC(=O)[C@@H]1CN(CC12CC[NH2+]CC2)C(=O)c3csc4c3cccc4)Oc5ccc(cc5)OC
# La molecula C39665804 fue correctamente procesada con Openbabel, verificar en el archivo, n = 18
# Cc1ccc(cc1)O[C@H](C)CNC(=O)[C@@H]2CN(CC23CC[NH2+]CC3)C(=O)c4cc(oc4C(F)(F)F)C
# La molecula C39666213 fue correctamente procesada con Openbabel, verificar en el archivo, n = 19
# C[C@H](CNC(=O)[C@H]1CN(CC12CC[NH2+]CC2)C(=O)c3ccc4ccccc4n3)Oc5ccccc5Cl
# La molecula C39666636 fue correctamente procesada con Openbabel, verificar en el archivo, n = 20
# Cc1ccc(c(c1)C)CCNC(=O)[C@@H]2CN(CC23CC[NH2+]CC3)C(=O)[C@@H]4COc5ccccc5O4
# La molecula C39667130 fue correctamente procesada con Openbabel, verificar en el archivo, n = 21
# Cc1ccc(c(c1)C)CCNC(=O)[C@H]2CN(CC23CC[NH2+]CC3)C(=O)[C@@H]4COc5ccccc5O4
# La molecula C39667131 fue correctamente procesada con Openbabel, verificar en el archivo, n = 22
# Cc1ccc2nc(cn2c1)CNC(=O)[C@@H]3CN(CC34CC[NH2+]CC4)C(=O)Cc5ccc(cc5)Cl
# La molecula C39670470 fue correctamente procesada con Openbabel, verificar en el archivo, n = 23
# c1ccc(cc1)Sc2c(cccn2)C(=O)N3C[C@H](C4(C3)CC[NH2+]CC4)C(=O)NCCc5ccco5
# La molecula C39671021 fue correctamente procesada con Openbabel, verificar en el archivo, n = 24
# c1ccc(cc1)c2ccc(o2)C(=O)N3C[C@H](C4(C3)CC[NH2+]CC4)C(=O)NCc5ccc(cc5)OC(F)F
# La molecula C39673401 fue correctamente procesada con Openbabel, verificar en el archivo, n = 25
# c1ccc2c(c1)ccc(n2)C(=O)N3C[C@H](C4(C3)CC[NH2+]CC4)C(=O)NCc5ccc(cc5)OC(F)F
# La molecula C39673419 fue correctamente procesada con Openbabel, verificar en el archivo, n = 26
# Cc1ccsc1CNC(=O)[C@@H]2CN(CC23CC[NH2+]CC3)C(=O)c4cccnc4Oc5ccccc5
# La molecula C39677270 fue correctamente procesada con Openbabel, verificar en el archivo, n = 27
# C[C@@H](c1ccncc1)NC(=O)[C@H]2CN(CC23CC[NH2+]CC3)C(=O)c4ccc(o4)c5ccccc5F
# La molecula C39681125 fue correctamente procesada con Openbabel, verificar en el archivo, n = 28
# c1ccc(c(c1)c2ccc(o2)C(=O)N3C[C@@H](C4(C3)CC[NH2+]CC4)C(=O)NCCOc5cccc(c5)F)F
# La molecula C39685463 fue correctamente procesada con Openbabel, verificar en el archivo, n = 29
# Cc1ccc(cc1)Oc2c(cccn2)C(=O)N3C[C@H](C4(C3)CC[NH2+]CC4)C(=O)N[C@H](C)Cc5ccccc5F
# La molecula C39687097 fue correctamente procesada con Openbabel, verificar en el archivo, n = 30
# Cc1cc(c(o1)C(F)(F)F)C(=O)N2C[C@H](C3(C2)CC[NH2+]CC3)C(=O)NCCOc4ccc(cc4)F
# La molecula C39688303 fue correctamente procesada con Openbabel, verificar en el archivo, n = 31
# Cc1c(cccc1OC(=O)C)C(=O)N2C[C@H](C3(C2)CC[NH2+]CC3)C(=O)N[C@@H](C)Cc4ccc(cc4)F
# La molecula C39688619 fue correctamente procesada con Openbabel, verificar en el archivo, n = 32
# Cc1c(cccc1OC(=O)C)C(=O)N2C[C@H](C3(C2)CC[NH2+]CC3)C(=O)N[C@H](C)Cc4ccc(cc4)F
# La molecula C39688621 fue correctamente procesada con Openbabel, verificar en el archivo, n = 33
# C[C@@H](C(=O)N1C[C@H](C2(C1)CC[NH2+]CC2)C(=O)NCc3cccc(c3)n4cccc4)Oc5ccccc5
# La molecula C39694102 fue correctamente procesada con Openbabel, verificar en el archivo, n = 34
# CCOc1cccc(c1)C(=O)N2C[C@H](C3(C2)CC[NH2+]CC3)C(=O)NCc4cccc(c4)n5cccc5
# La molecula C39694203 fue correctamente procesada con Openbabel, verificar en el archivo, n = 35
# CCc1ccc(cc1)[C@H](C)NC(=O)[C@H]2CN(CC23CC[NH2+]CC3)C(=O)COc4cccc5c4oc(=O)cc5C
# La molecula C39696245 fue correctamente procesada con Openbabel, verificar en el archivo, n = 36
# CC(C)c1nc(no1)c2ccc(c(c2)F)N3CCC[C@@H](C3)C(=O)N4CCC(CC4)(C(=O)N)[NH+]5CCCCC5
# La molecula C40876938 fue correctamente procesada con Openbabel, verificar en el archivo, n = 37
# Cc1ccc(c(c1)C)c2ccc(nn2)N3CCC(CC3)C(=O)N4CCC(CC4)(C(=O)N)[NH+]5CCCCC5
# La molecula C40920653 fue correctamente procesada con Openbabel, verificar en el archivo, n = 38
# CC[NH+]1CCN(CC1)CCNC(=O)[C@H]2CCCN(C2)c3[nH]c(=O)c4c(n3)c(cs4)c5ccccc5
# La molecula C49421233 fue correctamente procesada con Openbabel, verificar en el archivo, n = 39
# Cc1ccc(cc1)CNC(=O)[C@H](C)NC(=O)[C@@H]2CC3=c4ccccc4=[NH+][C@@H]3[C@@H]5N2C(=O)c6c5cccc6
# La molécula C63383452 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 40
# CCCNC(=O)[C@H](Cc1ccccc1)NC(=O)[C@@H]2CC3=c4ccccc4=[NH+][C@@H]3[C@H]5N2C(=O)c6c5cccc6
# La molécula C63384363 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 41
# c1ccc2=[NH+]CC(=c2c1)C[C@H]3[C@@H]4[C@@H](C(=O)N(C4=O)c5ccc(cc5)F)[C@]6(N3)c7cc(ccc7NC6=O)F
# La molécula C63479921 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 42
# COc1cccc(c1)N2C(=O)[C@@H]3[C@H](N[C@]4([C@@H]3C2=O)c5cc(ccc5NC4=O)F)CC6=c7ccccc7=[NH+]C6
# La molecula C63479934 fue correctamente procesada con Openbabel, verificar en el archivo, n = 43
# COc1cccc(c1)N2C(=O)[C@@H]3[C@@H](N[C@@]4([C@@H]3C2=O)c5cc(ccc5NC4=O)F)CC6=c7ccccc7=[NH+]C6
# La molécula C63479935 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 44
# Cc1ccc2=[NH+]CC(=c2c1)CCNC(=O)CCC(=O)N3CCS[C@H]4[C@H]3[C@@H](NN4c5ccccc5)C
# La molecula C63666772 fue correctamente procesada con Openbabel, verificar en el archivo, n = 45
# CN(C)c1ccc(cc1)[C@@H](CNC(=O)/C=C\2/CS[C@H](N2)N3CCCC3=O)C4=c5ccccc5=[NH+]C4
# La molecula C63830545 fue correctamente procesada con Openbabel, verificar en el archivo, n = 46
# c1ccc2=[NH+]CC(=c2c1)[C@H](CNC(=O)CCN3C(=O)C4(CCCC4)NC3=O)c5ccccc5Cl
# La molecula C63830790 fue correctamente procesada con Openbabel, verificar en el archivo, n = 47
# C[C@@H]1Nc2ccccc2N1CCC(=O)N3CCC4(CC3)C[C@@H]4C(=O)NCCC5=c6ccccc6=[NH+]C5
# La molecula C64152495 fue correctamente procesada con Openbabel, verificar en el archivo, n = 48
# COc1cccc(c1)N2C(=O)[C@H]3[C@H](N[C@@]4([C@@H]3C2=O)c5cc(ccc5NC4=O)F)CC6=c7ccccc7=[NH+]C6
# La molécula C63479932 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 49
# c1ccc(cc1)Cn2c(=O)c3ccc(cc3[nH]c2=O)[C@@H]4[NH+]=C(NO4)c5cccc(c5)Br
# La molecula C64870236 fue correctamente procesada con Openbabel, verificar en el archivo, n = 50
# ligand
# La molécula CC[C@H](CO)Nc3nc(NCc1ccccc1)n2ncc(C(C)C)c2[nH+]3 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 0
# Cc1ccc2cc(c([nH+]c2c1C)NCCNC(=S)NCCCOC)C#N
# La molecula C04937118 fue correctamente procesada con Openbabel, verificar en el archivo, n = 1
# C/C(=N/NC(=O)NC(C)(C)C)/CC[NH2+]CCSC(=O)c1ccccc1
# La molecula C05052194 fue correctamente procesada con Openbabel, verificar en el archivo, n = 2
# CCCC(=O)N(CCCCCC[NH3+])[C@@H](C)c1[nH]c(=O)c2ccccc2n1
# La molecula C04382828 fue correctamente procesada con Openbabel, verificar en el archivo, n = 3
# CCC/[NH+]=C(\N)/SCC(=O)N(CCC)CC(=O)Nc1ccccc1C
# La molecula C29494406 fue correctamente procesada con Openbabel, verificar en el archivo, n = 4
# CCOC(=O)/C(=[NH+]/Nc1cc(ccc1Cl)Cl)/NCCO
# La molecula C05591994 fue correctamente procesada con Openbabel, verificar en el archivo, n = 5
# COC(=O)[C@@H]1C[C@H]2CCCC[C@@H]2[NH+]1CC(=O)Nc3c(ccs3)C(=O)N
# La molecula C41624461 fue correctamente procesada con Openbabel, verificar en el archivo, n = 6
# CC(C)[NH+](CCNC(=O)NNC(=O)CCSc1ccc(cc1)F)C(C)C
# La molecula C43064644 fue correctamente procesada con Openbabel, verificar en el archivo, n = 7
# CC[C@H](C)NC(=O)c1cccc(c1)CNC(=O)NC[C@H](C)[NH+](CC)CC
# La molecula C46279712 fue correctamente procesada con Openbabel, verificar en el archivo, n = 8
# C=CCc1ccccc1OC[C@H](Cn2c3ccccc3[nH+]c2NCCO)O
# La molecula C46342305 fue correctamente procesada con Openbabel, verificar en el archivo, n = 9
# C[C@@H]1C[C@H](C[NH+](C1)CCNC(=O)Nc2ccc(cc2)NC(=O)OC)C
# La molecula C46421939 fue correctamente procesada con Openbabel, verificar en el archivo, n = 10
# CC(C)[C@@H](CNC(=O)NNC(=O)c1ccccc1F)[NH+](CC=C)CC=C
# La molecula C46905775 fue correctamente procesada con Openbabel, verificar en el archivo, n = 11
# CC(C)[C@@H](CNC(=O)NNC(=O)c1ccc(cc1)F)[NH+](CC=C)CC=C
# La molecula C46905837 fue correctamente procesada con Openbabel, verificar en el archivo, n = 12
# CCC(CC)(CNC(=O)NNC(=O)CCSc1ccc(cc1)F)[NH+](C)C
# La molecula C46950428 fue correctamente procesada con Openbabel, verificar en el archivo, n = 13
# CC[C@H](C)[C@H](c1nc(no1)c2ccccc2)NC(=O)CCCCC[NH3+]
# La molécula C04355530 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 14
# CCCCCCCCNC(=O)c1cc(coc1=[NH2+])C(=O)c2cc(ccc2O)C
# La molecula C03350568 fue correctamente procesada con Openbabel, verificar en el archivo, n = 15
# CC[C@@H](C)NC(=O)c1ccc(cc1)NC(=O)NCCC[NH+](C)CC(F)(F)F
# La molecula C54479474 fue correctamente procesada con Openbabel, verificar en el archivo, n = 16
# C[C@@H]1C[C@H](C[NH+](C1)C(C)(C)CNC(=O)NNC(=O)OC(C)(C)C)C
# La molecula C54727007 fue correctamente procesada con Openbabel, verificar en el archivo, n = 17
# CC(C)[C@H](CNC(=O)Nc1cc(c[nH]c1=O)C(F)(F)F)[NH+](CC=C)CC=C
# La molecula C63162068 fue correctamente procesada con Openbabel, verificar en el archivo, n = 18
# CCC(CC)[NH+](CCOC)CC(=O)Nc1c(c2c(s1)CCCC2)C(=O)N
# La molecula C64806210 fue correctamente procesada con Openbabel, verificar en el archivo, n = 19
# CC[NH+](CC)Cc1ccc(cc1)C(=O)NNC(=O)NCCC(C)C
# La molecula C65133920 fue correctamente procesada con Openbabel, verificar en el archivo, n = 20
# CC1CC[NH+](CC1)[C@@H](C)CNC(=O)Nc2ccc(cc2)NC(=O)c3ccco3
# La molecula C65360131 fue correctamente procesada con Openbabel, verificar en el archivo, n = 21
# Cc1ccc(cc1)NC(=O)NCCNc2[nH+]c(cc(n2)N(C)C)C
# La molecula C65365285 fue correctamente procesada con Openbabel, verificar en el archivo, n = 22
# C[C@@H](c1ccc(c(c1)OC)OCCO)[NH2+]Cc2c[nH]nc2c3ccc(cc3)F
# La molecula C65933126 fue correctamente procesada con Openbabel, verificar en el archivo, n = 23
# CC[C@@H](C)NC(=O)[C@@H](C)NC(=O)NC[C@H](CC)[NH+]1CCc2ccccc2C1
# La molecula C65988965 fue correctamente procesada con Openbabel, verificar en el archivo, n = 24
# CCCCCCOc1ccc(cc1)NC(=O)C[C@@H]2C(=O)NCC[NH2+]2
# La molecula C66152755 fue correctamente procesada con Openbabel, verificar en el archivo, n = 25
# c1ccc(cc1)CC[NH2+]CC(=O)Nc2cccc(c2)C(=O)NCc3ccco3
# La molecula C66213058 fue correctamente procesada con Openbabel, verificar en el archivo, n = 26
# c1cc(cc(c1)NC(=O)C[NH2+]CCC2=CCCCC2)C(=O)NC[C@H]3CCCO3
# La molecula C66214462 fue correctamente procesada con Openbabel, verificar en el archivo, n = 27
# COc1ccc(cc1)CCNC(=[NH2+])NC[C@H](c2cccs2)N3CCOCC3
# La molecula C66242281 fue correctamente procesada con Openbabel, verificar en el archivo, n = 28
# Cc1cccc(c1)OC[C@@H](CNC(=O)NC[C@H](c2cccs2)[NH+](C)C)O
# La molecula C66327028 fue correctamente procesada con Openbabel, verificar en el archivo, n = 29
# CC[NH+](CC)[C@@H](CC(C)C)CNC(=O)Nc1cc(c[nH]c1=O)C(F)(F)F
# La molecula C66402792 fue correctamente procesada con Openbabel, verificar en el archivo, n = 30
# CC(C)c1ccc(cc1)[C@H](CNCc2[nH]cc[nH+]2)NC(=O)OC(C)(C)C
# La molecula C66593800 fue correctamente procesada con Openbabel, verificar en el archivo, n = 31
# CCCC[NH+]1CCCC[C@H]1CNC(=O)NCCC(=O)N[C@@H](C)CC
# La molecula C66597539 fue correctamente procesada con Openbabel, verificar en el archivo, n = 32
# Cc1cc(ccc1C(=O)NC(C)C)NC(=O)NCCc2cn3c([nH+]2)CCCC3
# La molecula C66682310 fue correctamente procesada con Openbabel, verificar en el archivo, n = 33
# CCC(CC)(CNC(=O)CCCC[C@@H]1[C@H]2[C@@H](CS1)NC(=O)N2)[NH+](C)C
# La molecula C67163484 fue correctamente procesada con Openbabel, verificar en el archivo, n = 34
# CCC(CC)(CNC(=O)CCCC[C@H]1[C@H]2[C@@H](CS1)NC(=O)N2)[NH+](C)C
# La molecula C67163485 fue correctamente procesada con Openbabel, verificar en el archivo, n = 35
# C[NH+](CCNC(=O)CCCC[C@@H]1[C@@H]2[C@@H](CS1)NC(=O)N2)C3CCCCC3
# La molecula C67237555 fue correctamente procesada con Openbabel, verificar en el archivo, n = 36
# C[C@H]1CCCC[NH+]1CCCCNC(=O)NNC(=O)CCC2CCCCC2
# La molecula C67390126 fue correctamente procesada con Openbabel, verificar en el archivo, n = 37
# C[NH+](CCCNC(=O)NNC(=O)CCC1CCCCC1)CC(F)(F)F
# La molecula C67390736 fue correctamente procesada con Openbabel, verificar en el archivo, n = 38
# C[C@@H](CNC(=O)NCc1cccc(c1)C(=O)NC(C)C)C[NH+]2CCCCC2
# La molecula C67407800 fue correctamente procesada con Openbabel, verificar en el archivo, n = 39
# C[C@H]1CCC[C@](C1)(CNC(=O)NNC(=O)CCC(C)C)[NH+](C)C
# La molecula C67408030 fue correctamente procesada con Openbabel, verificar en el archivo, n = 40
# CC(C)[NH+](C)CCCCNC(=O)NNC(=O)CCC1CCCCC1
# La molecula C67410131 fue correctamente procesada con Openbabel, verificar en el archivo, n = 41
# Cc1ccc(c(c1)Cl)NC(=O)CCNC(=O)N[C@H](C)CC[NH+](C)C
# La molecula C67412452 fue correctamente procesada con Openbabel, verificar en el archivo, n = 42
# CC[NH+](CCNC(=O)NCCC(=O)Nc1ccc(cc1Cl)C)C(C)C
# ...
# CCCOc1ccc(cc1)C2=NN=C3[C@H]2[C@H](C(=C(O3)N)C#N)c4ccc(cc4)OCC(=O)N
# La molecula C09350731 fue correctamente procesada con Openbabel, verificar en el archivo, n = 47
# CCCn1c2ccc(cc2[nH]c1=O)[C@H]3N[C@@H](ON3)[C@@H](C(C)C)NS(=O)(=O)c4ccccc4
# La molécula C64891186 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 48
# CCCn1c2ccc(cc2[nH]c1=O)[C@H]3N[C@H](ON3)[C@@H](C(C)C)NS(=O)(=O)c4ccccc4
# La molecula C64891188 fue correctamente procesada con Openbabel, verificar en el archivo, n = 49
# c1ccc(c(c1)c2cc(n[nH]2)C(=O)Nc3c(c4c(s3)CCCC4)C(=O)NC[C@@H]5CCCO5)O
# La molecula C08845503 fue correctamente procesada con Openbabel, verificar en el archivo, n = 50
# ligand
# La molécula O=C(Nc2n[nH]c3cc(c1ccsc1)ccc23)C4CC4 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 0
# CC(C)Sc1nnc(n1N)c2ccc(cc2)Cl
# La molecula C01393195 fue correctamente procesada con Openbabel, verificar en el archivo, n = 1
# CCCc1nc2c(c3c(s2)CC[C@H](C3)C)c(=O)n1N
# La molecula C00522659 fue correctamente procesada con Openbabel, verificar en el archivo, n = 2
# COc1ccc2c(c1)OC(=C([C@@H]2c3ccccc3)C#N)N
# La molecula C05514501 fue correctamente procesada con Openbabel, verificar en el archivo, n = 3
# Cc1ccc(c(c1)C)NC(=O)N[C@@H](C)c2ccncc2
# La molecula C06715177 fue correctamente procesada con Openbabel, verificar en el archivo, n = 4
# c1cc(c(cc1Cl)N)N2CCN(CC2)c3nccs3
# La molecula C19266059 fue correctamente procesada con Openbabel, verificar en el archivo, n = 5
# C[C@H]1CCCC[C@H]1NC(=O)[C@@H]2CNc3ccccc3O2
# La molecula C19433870 fue correctamente procesada con Openbabel, verificar en el archivo, n = 6
# CC(C)Cc1cc2c3ccccc3oc(=O)c2c(n1)N
# La molecula C19447518 fue correctamente procesada con Openbabel, verificar en el archivo, n = 7
# CCN1C[C@H](Oc2c1cc(cc2)c3csc(n3)N)C
# La molecula C19760157 fue correctamente procesada con Openbabel, verificar en el archivo, n = 8
# CCc1cc2c(ncnc2s1)Oc3ccc(cc3)N
# La molecula C20335825 fue correctamente procesada con Openbabel, verificar en el archivo, n = 9
# CC(C)(C(=O)N/N=C/c1c(cccc1Cl)Cl)O
# La molecula C32578414 fue correctamente procesada con Openbabel, verificar en el archivo, n = 10
# Cc1c(n(c2c1c(nc(n2)C)N)[C@@H](C)c3ccccc3)C
# La molecula C34157617 fue correctamente procesada con Openbabel, verificar en el archivo, n = 11
# CC1(C[C@](c2cccc(c2O1)Cl)(C(=O)OC)N)C
# La molecula C36142396 fue correctamente procesada con Openbabel, verificar en el archivo, n = 12
# CC(C)c1cc2c(c(c1)N)O[C@@H](CC2=O)c3ccncc3
# La molecula C36142714 fue correctamente procesada con Openbabel, verificar en el archivo, n = 13
# Cc1cc(c(o1)C)c2c(c(on2)N)c3ccc(cc3)F
# La molecula C36936814 fue correctamente procesada con Openbabel, verificar en el archivo, n = 14
# C[C@@H]1CCCCN1c2ccc(c(n2)OC(C)(C)C)N
# La molecula C37066272 fue correctamente procesada con Openbabel, verificar en el archivo, n = 15
# C[C@H]1C[C@@H](CC(C1)(C)C)Oc2ccc(c(n2)OC)N
# La molecula C37077435 fue correctamente procesada con Openbabel, verificar en el archivo, n = 16
# Cc1ccc2nc(cn2c1)CSc3ccc(cn3)N
# La molecula C37191438 fue correctamente procesada con Openbabel, verificar en el archivo, n = 17
# Cc1ccc(cc1NC(=O)c2ccc(o2)Cl)C#CCO
# La molecula C37549242 fue correctamente procesada con Openbabel, verificar en el archivo, n = 18
# c1ccc2c(c1)c(ncn2)Oc3ccc(cc3N)Cl
# La molecula C37715794 fue correctamente procesada con Openbabel, verificar en el archivo, n = 19
# c1cc(c(cc1c2nc(no2)C3CCCC3)N)Cl
# La molecula C37756576 fue correctamente procesada con Openbabel, verificar en el archivo, n = 20
# Cc1cc(ccc1O[C@H](C)c2nnc(s2)N)Cl
# La molecula C00615738 fue correctamente procesada con Openbabel, verificar en el archivo, n = 21
# CCSc1nc(c2c3c(sc2n1)CN(CC3)C)N
# La molecula C20357484 fue correctamente procesada con Openbabel, verificar en el archivo, n = 22
# C[C@H](c1ccc(cc1)O)N(C)C(=O)c2ccccc2O
# La molecula C38089915 fue correctamente procesada con Openbabel, verificar en el archivo, n = 23
# Cc1cc2n(n1)S[C@H](N2)Nc3ccc(c(c3)Cl)F
# La molecula C13132468 fue correctamente procesada con Openbabel, verificar en el archivo, n = 24
# CCO[C@H]1C[C@]2(CC[C@@H](C2)c3ccccc3O)N(C1)O
# La molecula C39505153 fue correctamente procesada con Openbabel, verificar en el archivo, n = 25
# C[C@]1\2CC[C@](C1(C)C)(C/C2=N\O)C(=O)NC(C)(C)C
# La molecula C33960346 fue correctamente procesada con Openbabel, verificar en el archivo, n = 26
# Cc1c(nnc(c1CN)Oc2ccccc2Cl)C
# La molecula C40290614 fue correctamente procesada con Openbabel, verificar en el archivo, n = 27
# Cc1ccc(c(c1)N)Oc2c3ccccc3ncc2C#N
# La molecula C41078952 fue correctamente procesada con Openbabel, verificar en el archivo, n = 28
# Cc1cccc(c1N)c2nnc(n2C3CCCCC3)C
# La molecula C42039300 fue correctamente procesada con Openbabel, verificar en el archivo, n = 29
# c1ccc(c(c1)N)Oc2c(cc3c(n2)CCCC3)C#N
# La molecula C43409730 fue correctamente procesada con Openbabel, verificar en el archivo, n = 30
# Cc1ccc(cc1)c2cc(n(n2)c3cc(ccn3)C)N
# La molecula C43671660 fue correctamente procesada con Openbabel, verificar en el archivo, n = 31
# C[C@H](c1cnn(c1)C)Nc2cccc3c2cccc3O
# La molecula C44498216 fue correctamente procesada con Openbabel, verificar en el archivo, n = 32
# CC[C@@H]1CCCC[C@@H]1n2c(c(c3c2ncnc3N)C)C
# La molecula C49121808 fue correctamente procesada con Openbabel, verificar en el archivo, n = 33
# C[C@H](c1ccccc1NC2CCC3(CC2)OCCO3)O
# La molecula C49542446 fue correctamente procesada con Openbabel, verificar en el archivo, n = 34
# CNc1nc2c(s1)[C@@H](CC(=O)N2)c3ccc(cc3)Cl
# La molecula C49545611 fue correctamente procesada con Openbabel, verificar en el archivo, n = 35
# CCn1cc(cc1C(=O)N(C)c2ccc(cc2C)C)N
# La molecula C49977350 fue correctamente procesada con Openbabel, verificar en el archivo, n = 36
# c1c(c(cc(c1F)F)N)c2nnc(o2)C3CCCCC3
# La molecula C50309538 fue correctamente procesada con Openbabel, verificar en el archivo, n = 37
# CN(C)c1ccc(cc1)c2nc3c(c(n2)N)CCCC3
# La molecula C50867096 fue correctamente procesada con Openbabel, verificar en el archivo, n = 38
# Cc1c(n(c2c1c(ncn2)N)[C@H](C)C3CCCCC3)C
# La molecula C52341960 fue correctamente procesada con Openbabel, verificar en el archivo, n = 39
# Cc1cc(nc(n1)Cl)N[C@]2(CCC[C@H](C2)C)CO
# La molecula C53128540 fue correctamente procesada con Openbabel, verificar en el archivo, n = 40
# CC(C)(C)c1nc(n(n1)C)c2cc(ccc2N)Cl
# La molecula C54698653 fue correctamente procesada con Openbabel, verificar en el archivo, n = 41
# Cc1ccc(o1)[C@]2(NN=C(S2)c3ccccc3O)C
# La molecula C00341742 fue correctamente procesada con Openbabel, verificar en el archivo, n = 42
# Cc1c(c(n(n1)Cc2ccc(o2)[C@@H]3C[C@@H]3C)N)Cl
# La molecula C43667419 fue correctamente procesada con Openbabel, verificar en el archivo, n = 43
# Cc1c(c(n(n1)Cc2ccc(o2)[C@H]3C[C@@H]3C)N)Cl
# La molecula C43667421 fue correctamente procesada con Openbabel, verificar en el archivo, n = 44
# Cc1ccc(cc1C)c2c(noc2N)C3CCOCC3
# La molecula C61681335 fue correctamente procesada con Openbabel, verificar en el archivo, n = 45
# CCN(c1ccc(cc1)F)c2c(c(ncn2)Cl)N
# La molecula C62364230 fue correctamente procesada con Openbabel, verificar en el archivo, n = 46
# c1ccc2c(c1)CCC[C@H]2Oc3c(c(ncn3)Cl)N
# La molecula C62365009 fue correctamente procesada con Openbabel, verificar en el archivo, n = 47
# c1cc(c(cc1F)Cl)c2c(noc2N)c3ccoc3
# La molecula C62609821 fue correctamente procesada con Openbabel, verificar en el archivo, n = 48
# c1ccc(cc1)C(=O)C[C@H]2C(=Nc3ccccc3N2)O
# La molecula C01251161 fue correctamente procesada con Openbabel, verificar en el archivo, n = 49
# c1cc(ccc1c2ccc(nc2)c3nc(sn3)N)F
# La molecula C67173817 fue correctamente procesada con Openbabel, verificar en el archivo, n = 50
# ligand
# La molécula COC(=O)[C@@]1(O)C[C@H]5O[C@]1(C)n7c2ccccc2c8c3CNC(=O)c3c6c4ccccc4n5c6c78 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 0
# c1ccc2c(c1)CCN2S(=O)(=O)c3cc(ccc3Cl)C(=O)N4C(=O)c5cccc(c5C4=O)N
# La molecula C03373628 fue correctamente procesada con Openbabel, verificar en el archivo, n = 1
# Cc1cc2c(c(=O)n1C[C@@H]3CCCO3)[C@@H](C(=C(O2)N)C#N)c4cc(ccc4OC)Br
# La molecula C09237637 fue correctamente procesada con Openbabel, verificar en el archivo, n = 2
# C[C@@H]1CC(N2c3c1cc(cc3[C@]4(C2=O)c5c(c6ccccc6oc5=O)OC(=C4C#N)N)OC)(C)C
# La molecula C01114700 fue correctamente procesada con Openbabel, verificar en el archivo, n = 3
# c1ccc(cc1)c2c(c3ccccc3[nH]2)C(=O)CN4C(=O)[C@@]5(CCOc6c5cccc6)NC4=O
# La molecula C09782034 fue correctamente procesada con Openbabel, verificar en el archivo, n = 4
# CCOc1cc2c3c(c1)[C@@]4(c5c(nn(c5OC(=C4C#N)N)c6ccccc6)C)C(=O)N3C(C=C2C)(C)C
# La molecula C01049621 fue correctamente procesada con Openbabel, verificar en el archivo, n = 5
# Cc1cc2c(c(=O)n1C[C@H]3CCCO3)[C@H](C(=C(O2)N)C#N)c4cc(ccc4Br)OC
# La molecula C11690690 fue correctamente procesada con Openbabel, verificar en el archivo, n = 6
# CC1(CC2=C([C@H](C(=C(N2c3ccc(cc3)OC)N)C#N)c4ccc(cc4)[N+](=O)[O-])C(=O)C1)C
# La molecula C01056978 fue correctamente procesada con Openbabel, verificar en el archivo, n = 7
# CC1(CC2=C([C@H](C(=C(N2c3ccc(cc3)OC)N)C#N)c4cccc(c4)[N+](=O)[O-])C(=O)C1)C
# La molecula C01057128 fue correctamente procesada con Openbabel, verificar en el archivo, n = 8
# CCc1ccc(s1)[C@@H]2C(=C(N(C3=C2C(=O)CC(C3)(C)C)c4ccccc4[N+](=O)[O-])N)C#N
# La molecula C06284094 fue correctamente procesada con Openbabel, verificar en el archivo, n = 9
# Cc1ccc(cc1N)n2c(cn3c2nc4c3c(=O)n(c(=O)n4C)C)c5ccc(cc5)Cl
# La molecula C09210833 fue correctamente procesada con Openbabel, verificar en el archivo, n = 10
# COc1cc(ccc1O)[C@@H]2[C@@H]3CC=C[C@@H]3c4cc(ccc4N2)S(=O)(=O)N5CCOCC5
# La molecula C14459054 fue correctamente procesada con Openbabel, verificar en el archivo, n = 11
# C[C@H](C(=O)NC(=O)NC)Sc1nc2c(c3c(s2)CCCC3)c(=O)n1c4ccccc4F
# La molecula C11055701 fue correctamente procesada con Openbabel, verificar en el archivo, n = 12
# COc1ccccc1[C@H]2C(=C(OC3=C2S(=O)(=O)N(c4c3cccc4)Cc5ccc(cc5)F)N)C#N
# La molecula C20558430 fue correctamente procesada con Openbabel, verificar en el archivo, n = 13
# CC1=C([C@H](C2=C(N1)CC(CC2=O)(C)C)c3cc(c(c(c3)OC)O)OC)C(=O)N4CCCCC4
# La molecula C01459516 fue correctamente procesada con Openbabel, verificar en el archivo, n = 14
# c1ccc(cc1)CN2CC=C3[C@H](C2)[C@H](C(C(=C3C#N)N)(C#N)C#N)c4ccc(cc4[N+](=O)[O-])Cl
# La molecula C09144774 fue correctamente procesada con Openbabel, verificar en el archivo, n = 15
# Cc1cc(=O)c(nn1c2ccccc2Cl)C(=O)NNC(=O)c3cc4c(s3)CCCCC4
# La molecula C21971016 fue correctamente procesada con Openbabel, verificar en el archivo, n = 16
# C[C@@H]1CCCC[C@]12C(=O)N(C(=O)N2)CC(=O)N3c4ccccc4NC(=O)C[C@@H]3C(F)(F)F
# La molecula C22240228 fue correctamente procesada con Openbabel, verificar en el archivo, n = 17
# Cc1cc(c(c(c1C)S(=O)(=O)N2CCN(CC2)Cc3nc(c4c(c(sc4n3)C)C)N)C)C
# La molecula C12567754 fue correctamente procesada con Openbabel, verificar en el archivo, n = 18
# Cc1cc(c(s1)C)[C@@H]2C(=C(N(C3=C2C(=O)CC(C3)(C)C)c4ccc(cc4Cl)[N+](=O)[O-])N)C#N
# La molecula C25782571 fue correctamente procesada con Openbabel, verificar en el archivo, n = 19
# CC(C)(C)OC(=O)N1CC=C2[C@@H](C1)[C@H](C(C(=C2C#N)N)(C#N)C#N)c3cc(ccc3F)Br
# La molecula C09113433 fue correctamente procesada con Openbabel, verificar en el archivo, n = 20
# CN(Cc1ccc(cc1)Br)c2c(ncnc2N)C#Cc3ccc(nc3)N4CCOCC4
# La molecula C13475459 fue correctamente procesada con Openbabel, verificar en el archivo, n = 21
# Cc1cc(c(s1)SC)[C@@H]2C(=C(N(C3=C2C(=O)CCC3)c4ccc(cc4Cl)[N+](=O)[O-])N)C#N
# La molecula C27550429 fue correctamente procesada con Openbabel, verificar en el archivo, n = 22
# Cc1cc(c(s1)SC)[C@@H]2C(=C(N(C3=C2C(=O)CC(C3)(C)C)c4ccc(cc4)[N+](=O)[O-])N)C#N
# La molecula C27550694 fue correctamente procesada con Openbabel, verificar en el archivo, n = 23
# Cc1ccc(c(c1)C)NC(=O)NC(=O)[C@@H](C)Sc2nc3c(c(c(s3)C)C)c(=O)n2C
# La molecula C29341438 fue correctamente procesada con Openbabel, verificar en el archivo, n = 24
# CC1CCC(CC1)N2C(=O)c3c(c4cc(ccc4n3C[C@]2(C)C(=O)NC5CCCC5)F)NC(=O)C
# La molecula C21866487 fue correctamente procesada con Openbabel, verificar en el archivo, n = 25
# CC[C@]1(C(=O)N(C(=O)N1)CC(=O)N2c3ccccc3NC(=O)C[C@@H]2C)c4ccc(cc4)F
# La molecula C08902064 fue correctamente procesada con Openbabel, verificar en el archivo, n = 26
# CC1([C@H]2C[C@H]([C@@]3([C@@H]([C@]2(C(=O)C[C@H]1O)C)CC[C@@]4([C@@]35[C@@H](O5)C(=O)O[C@H]4c6ccoc6)C)C)O)C
# La molécula C03978918 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 27
# CC1([C@@H]([C@]2([C@@H]3CC[C@]4([C@@H](O[C@@H](CC4=C3C[C@@H]([C@H]1O)C2=O)O)c5ccoc5)C)C)CC(=O)OC)C
# La molecula C03978301 no corrió adecuadamente y el proceso fue detenido abruptamente, n = 28
# c1ccc(cc1)C2=NN=C[C@@H]2[C@@H]3[C@@H]4[C@@H](N(N=C4c5ccco5)c6ccccc6)OC(=C3C#N)N
# La molécula C39237777 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 29
# CC1=C2[C@@H](C(=C(O[C@@H]2N=N1)N)C#N)c3cn(nc3c4ccccc4)Cc5ccc(cc5)Br
# La molecula C39273138 fue correctamente procesada con Openbabel, verificar en el archivo, n = 30
# CC1=C2[C@H](C(=C(O[C@@H]2N=N1)N)C#N)c3cn(nc3c4ccccc4)Cc5ccc(cc5)Br
# La molecula C39273139 fue correctamente procesada con Openbabel, verificar en el archivo, n = 31
# CCOn1c2c(c3c(c1=O)cc(cn3)I)N[C@H](CC2=O)c4ccccc4O
# La molecula C39449492 fue correctamente procesada con Openbabel, verificar en el archivo, n = 32
# CC(C)S(=O)(=O)C1=C[C@H]2CN3[C@@H](C[C@@H]2C=C1c4ccccc4O)CO[P@@](=O)(N3)SC
# La molecula C39468306 fue correctamente procesada con Openbabel, verificar en el archivo, n = 33
# CC1=NC(=O)[C@H]2C(=C1)OC(=C([C@@]23c4ccccc4N(C3=O)Cc5cccc(c5)Cl)C#N)N
# La molécula C39918935 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 34
# CCn1c(cc2c(c1=O)[C@]3(c4ccccc4N(C3=O)Cc5ccccc5Cl)C(=C(O2)N)C#N)C
# La molecula C39918981 fue correctamente procesada con Openbabel, verificar en el archivo, n = 35
# CC1(Cc2c(sc3c2c(=O)n(c(n3)N/N=C\c4ccc(cc4)O)c5ccccc5)CO1)C
# La molecula C39949540 fue correctamente procesada con Openbabel, verificar en el archivo, n = 36
# Cc1c\2c(oc1C(=O)N3CCCc4c3cccc4)CCC/C2=N\NC(=O)c5ccc(cc5)O
# La molecula C40812079 fue correctamente procesada con Openbabel, verificar en el archivo, n = 37
# C[C@]12CC(=O)Nc3c1c(ccc3)N(C2)Cc4ccc5cc6c(cc5n4)C[C@]7(C6)c8cccnc8NC7=O
# La molecula C49066518 fue correctamente procesada con Openbabel, verificar en el archivo, n = 38
# C[C@@H]1C[C@@H](n2c(nc(n2)C(=O)Nc3c(c4c(s3)C[C@@H](CC4)C(C)(C)C)C#N)N1)C(F)F
# La molecula C08676894 fue correctamente procesada con Openbabel, verificar en el archivo, n = 39
# Cc1cc(c(cc1C)Br)N2C(=O)/C(=C\Nc3c(c4c(s3)CCC4)C#N)/C(=O)NC2=O
# La molecula C16267915 fue correctamente procesada con Openbabel, verificar en el archivo, n = 40
# CN1c2ccc(cc2[C@]3(C1=O)c4c(c5ccccc5oc4=O)OC(=C3C#N)N)Br
# La molecula C59293280 fue correctamente procesada con Openbabel, verificar en el archivo, n = 41
# c1ccc2c(c1)/C(=N/S(=O)(=O)c3ccc(cc3)Br)/C=C4[C@]2(OCCN4CCO)O
# La molécula C13149258 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 42
# C[C@@H]1C(=C(NN1c2ccc(cc2)F)C)/C=C/C(=O)N3CCC(CC3)n4c5ccccc5[nH]c4=O
# La molecula C39936308 fue correctamente procesada con Openbabel, verificar en el archivo, n = 43
# CCN1c2ccc(cc2[C@]3(C1=O)[C@H]4C(=NN=C4OC(=C3C#N)N)c5ccccc5)Br
# La molecula C01075158 fue correctamente procesada con Openbabel, verificar en el archivo, n = 44
# CN1CCC2=c3ccccc3=[NH+][C@@H]2[C@@H]1c4c([nH]c(=O)n(c4=O)c5ccc(cc5)Br)[O-]
# La molecula C63375422 fue correctamente procesada con Openbabel, verificar en el archivo, n = 45
# CC1=NN([C@H]2[C@@H]1[C@@H]([C@@H]3C(=NC(=O)NC3=O)N2)c4c(cccc4Cl)Cl)c5ccccc5
# La molécula C63448210 tuvo un error de procesamiento con Openbabel, verificar en el archivo, n = 46
# COc1ccc(cc1)n2c(=O)c(c(nc2SC)[O-])[C@@H]3[C@@H]4C(=c5cc(ccc5=[NH+]4)Cl)CCN3
# La molecula C63492853 fue correctamente procesada con Openbabel, verificar en el archivo, n = 47
# COc1ccc(cc1)n2c(=O)c(c(nc2SC)[O-])[C@H]3[C@@H]4C(=c5cc(ccc5=[NH+]4)Cl)CCN3
# La molecula C63492855 fue correctamente procesada con Openbabel, verificar en el archivo, n = 48
# COc1ccc(cc1)n2c(=O)c(c(nc2SC)[O-])[C@H]3[C@H]4C(=c5cc(ccc5=[NH+]4)Cl)CCN3
# La molecula C63492859 fue correctamente procesada con Openbabel, verificar en el archivo, n = 49
# CC1=C2[C@H](CC(=O)N[C@H]2N(N1)c3ccc(nn3)Cl)[C@@H]4C=NN=C4c5ccc(cc5)Cl
# La molecula C63825310 fue correctamente procesada con Openbabel, verificar en el archivo, n = 50

# %%
# 47 Moleculas fallaron en generar conformaciones

# %%
def OBMolMinimize(molecule, formato_input, formato_out,steps = 2500,):
        '''Función que minimiza una molecula con Steepest. Descendent y el campo de fuerza mmff94
        default: steps = 2500, e = 1e-6f'''
        counter = 0
        obConversion = openbabel.OBConversion()
        obConversion.SetInAndOutFormats(formato_input, formato_out)
        mol = openbabel.OBMol()
        forcefield = openbabel.OBForceField.FindForceField("MMFF94")
        notatend = obConversion.ReadFile(mol, molecule)
        while notatend:
                counter+= 1
                name = molecule.strip().replace('.sdf', '')+'_mmff94.sdf'
                forcefield.Setup(mol)
                print(f'Minimizando {name}')
                forcefield.SteepestDescent(steps)
                forcefield.GetCoordinates(mol)
                obConversion.WriteFile(mol,name)
                mol = openbabel.OBMol()
                notatend = obConversion.Read(mol)

# %%
os.system('ls *.sdf > decoys_activos.txt')
# Out:
# 0

# %%
#Minimizacion de ligandos con openbabel utilizando el campo de fuerza MMFF94
with open('decoys_activos.txt', 'r') as decoys_a_minimizar:
    for molecula in decoys_a_minimizar:
        OBMolMinimize(molecula.strip(), 'sdf', 'sdf')
# Out:
# Minimizando C00081935_mmff94.sdf
# Minimizando C00108508_mmff94.sdf
# Minimizando C00148967_mmff94.sdf
# Minimizando C00178327_mmff94.sdf
# Minimizando C00182388_mmff94.sdf
# Minimizando C00187765_mmff94.sdf
# Minimizando C00187774_mmff94.sdf
# Minimizando C00206216_mmff94.sdf
# Minimizando C00238482_mmff94.sdf
# Minimizando C00269208_mmff94.sdf
# Minimizando C00307448_mmff94.sdf
# Minimizando C00309138_mmff94.sdf
# Minimizando C00331467_mmff94.sdf
# Minimizando C00341742_mmff94.sdf
# Minimizando C00421464_mmff94.sdf
# Minimizando C00488469_mmff94.sdf
# Minimizando C00497841_mmff94.sdf
# Minimizando C00522659_mmff94.sdf
# Minimizando C00556105_mmff94.sdf
# Minimizando C00614064_mmff94.sdf
# Minimizando C00615738_mmff94.sdf
# Minimizando C00643851_mmff94.sdf
# Minimizando C00651667_mmff94.sdf
# Minimizando C00651669_mmff94.sdf
# Minimizando C00663827_mmff94.sdf
# Minimizando C00708291_mmff94.sdf
# Minimizando C00709762_mmff94.sdf
# Minimizando C00755735_mmff94.sdf
# Minimizando C00803894_mmff94.sdf
# Minimizando C00814145_mmff94.sdf
# Minimizando C00814147_mmff94.sdf
# Minimizando C00832969_mmff94.sdf
# Minimizando C00858714_mmff94.sdf
# Minimizando C00891532_mmff94.sdf
# Minimizando C00896864_mmff94.sdf
# Minimizando C00907470_mmff94.sdf
# Minimizando C00955867_mmff94.sdf
# Minimizando C00958975_mmff94.sdf
# Minimizando C00978333_mmff94.sdf
# Minimizando C01029483_mmff94.sdf
# Minimizando C01040131_mmff94.sdf
# Minimizando C01049621_mmff94.sdf
# Minimizando C01051741_mmff94.sdf
# Minimizando C01056978_mmff94.sdf
# Minimizando C01057128_mmff94.sdf
# Minimizando C01060233_mmff94.sdf
# Minimizando C01060815_mmff94.sdf
# Minimizando C01062030_mmff94.sdf
# Minimizando C01075158_mmff94.sdf
# Minimizando C01097613_mmff94.sdf
# Minimizando C01114700_mmff94.sdf
# Minimizando C01117368_mmff94.sdf
# Minimizando C01123205_mmff94.sdf
# Minimizando C01126696_mmff94.sdf
# Minimizando C01153992_mmff94.sdf
# Minimizando C01189518_mmff94.sdf
# Minimizando C01196773_mmff94.sdf
# Minimizando C01251161_mmff94.sdf
# Minimizando C01268783_mmff94.sdf
# Minimizando C01291490_mmff94.sdf
# Minimizando C01312290_mmff94.sdf
# Minimizando C01318672_mmff94.sdf
# Minimizando C01381916_mmff94.sdf
# Minimizando C01393195_mmff94.sdf
# Minimizando C01408997_mmff94.sdf
# Minimizando C01417110_mmff94.sdf
# Minimizando C01435785_mmff94.sdf
# Minimizando C01445045_mmff94.sdf
# Minimizando C01459516_mmff94.sdf
# Minimizando C01611130_mmff94.sdf
# Minimizando C01617710_mmff94.sdf
# Minimizando C01629867_mmff94.sdf
# Minimizando C01739065_mmff94.sdf
# Minimizando C01790668_mmff94.sdf
# Minimizando C01821179_mmff94.sdf
# Minimizando C01840640_mmff94.sdf
# Minimizando C01898640_mmff94.sdf
# Minimizando C01935904_mmff94.sdf
# Minimizando C01973005_mmff94.sdf
# Minimizando C02050094_mmff94.sdf
# Minimizando C02050124_mmff94.sdf
# Minimizando C02058678_mmff94.sdf
# Minimizando C02117354_mmff94.sdf
# Minimizando C02122889_mmff94.sdf
# Minimizando C02129723_mmff94.sdf
# Minimizando C02130313_mmff94.sdf
# Minimizando C02131103_mmff94.sdf
# Minimizando C02134201_mmff94.sdf
# Minimizando C02231151_mmff94.sdf
# Minimizando C02247392_mmff94.sdf
# Minimizando C02288799_mmff94.sdf
# Minimizando C02359085_mmff94.sdf
# Minimizando C02369161_mmff94.sdf
# Minimizando C02394872_mmff94.sdf
# Minimizando C02449566_mmff94.sdf
# Minimizando C02520324_mmff94.sdf
# Minimizando C02537082_mmff94.sdf
# Minimizando C02564245_mmff94.sdf
# Minimizando C02578358_mmff94.sdf
# Minimizando C02601940_mmff94.sdf
# Minimizando C02609910_mmff94.sdf
# Minimizando C02651171_mmff94.sdf
# Minimizando C02654574_mmff94.sdf
# Minimizando C02657973_mmff94.sdf
# Minimizando C02793974_mmff94.sdf
# Minimizando C02794014_mmff94.sdf
# Minimizando C02836575_mmff94.sdf
# Minimizando C02856023_mmff94.sdf
# Minimizando C02859205_mmff94.sdf
# Minimizando C02914525_mmff94.sdf
# Minimizando C02914528_mmff94.sdf
# Minimizando C02915262_mmff94.sdf
# Minimizando C02924854_mmff94.sdf
# Minimizando C03014168_mmff94.sdf
# Minimizando C03060464_mmff94.sdf
# Minimizando C03082600_mmff94.sdf
# Minimizando C03158712_mmff94.sdf
# Minimizando C03204136_mmff94.sdf
# Minimizando C03204833_mmff94.sdf
# Minimizando C03229928_mmff94.sdf
# Minimizando C03259094_mmff94.sdf
# Minimizando C03262289_mmff94.sdf
# Minimizando C03264654_mmff94.sdf
# Minimizando C03277294_mmff94.sdf
# Minimizando C03310951_mmff94.sdf
# Minimizando C03335810_mmff94.sdf
# Minimizando C03350568_mmff94.sdf
# Minimizando C03353879_mmff94.sdf
# Minimizando C03355403_mmff94.sdf
# Minimizando C03373628_mmff94.sdf
# Minimizando C03442448_mmff94.sdf
# Minimizando C03443442_mmff94.sdf
# Minimizando C03448169_mmff94.sdf
# Minimizando C03459221_mmff94.sdf
# Minimizando C03482663_mmff94.sdf
# Minimizando C03496020_mmff94.sdf
# Minimizando C03496022_mmff94.sdf
# Minimizando C03535324_mmff94.sdf
# Minimizando C03548546_mmff94.sdf
# Minimizando C03595232_mmff94.sdf
# Minimizando C03623865_mmff94.sdf
# Minimizando C03670440_mmff94.sdf
# Minimizando C03764203_mmff94.sdf
# Minimizando C03831087_mmff94.sdf
# Minimizando C03831088_mmff94.sdf
# Minimizando C03841007_mmff94.sdf
# Minimizando C03841031_mmff94.sdf
# Minimizando C03841702_mmff94.sdf
# Minimizando C03886579_mmff94.sdf
# Minimizando C03898630_mmff94.sdf
# Minimizando C03898650_mmff94.sdf
# Minimizando C03938480_mmff94.sdf
# Minimizando C03978918_mmff94.sdf
# Minimizando C03999711_mmff94.sdf
# Minimizando C04010938_mmff94.sdf
# Minimizando C04016857_mmff94.sdf
# Minimizando C04017678_mmff94.sdf
# Minimizando C04019913_mmff94.sdf
# Minimizando C04026792_mmff94.sdf
# Minimizando C04032923_mmff94.sdf
# Minimizando C04043193_mmff94.sdf
# Minimizando C04061361_mmff94.sdf
# Minimizando C04087267_mmff94.sdf
# Minimizando C04088602_mmff94.sdf
# Minimizando C04098340_mmff94.sdf
# Minimizando C04119297_mmff94.sdf
# Minimizando C04126730_mmff94.sdf
# Minimizando C04126880_mmff94.sdf
# Minimizando C04150861_mmff94.sdf
# Minimizando C04150870_mmff94.sdf
# Minimizando C04161776_mmff94.sdf
# Minimizando C04163238_mmff94.sdf
# Minimizando C04183821_mmff94.sdf
# Minimizando C04205613_mmff94.sdf
# Minimizando C04236620_mmff94.sdf
# Minimizando C04244999_mmff94.sdf
# Minimizando C04249381_mmff94.sdf
# Minimizando C04264444_mmff94.sdf
# Minimizando C04272991_mmff94.sdf
# Minimizando C04276919_mmff94.sdf
# Minimizando C04284928_mmff94.sdf
# Minimizando C04285058_mmff94.sdf
# Minimizando C04294261_mmff94.sdf
# Minimizando C04294262_mmff94.sdf
# Minimizando C04308488_mmff94.sdf
# Minimizando C04342943_mmff94.sdf
# Minimizando C04355490_mmff94.sdf
# Minimizando C04355530_mmff94.sdf
# Minimizando C04365982_mmff94.sdf
# Minimizando C04382828_mmff94.sdf
# Minimizando C04426851_mmff94.sdf
# Minimizando C04429538_mmff94.sdf
# Minimizando C04429584_mmff94.sdf
# Minimizando C04453492_mmff94.sdf
# Minimizando C04453495_mmff94.sdf
# Minimizando C04469809_mmff94.sdf
# Minimizando C04469991_mmff94.sdf
# Minimizando C04471226_mmff94.sdf
# Minimizando C04477951_mmff94.sdf
# Minimizando C04481441_mmff94.sdf
# Minimizando C04488911_mmff94.sdf
# Minimizando C04525120_mmff94.sdf
# Minimizando C04577072_mmff94.sdf
# Minimizando C04577311_mmff94.sdf
# Minimizando C04618417_mmff94.sdf
# Minimizando C04724666_mmff94.sdf
# Minimizando C04774107_mmff94.sdf
# Minimizando C04774206_mmff94.sdf
# Minimizando C04785795_mmff94.sdf
# Minimizando C04795590_mmff94.sdf
# Minimizando C04805538_mmff94.sdf
# Minimizando C04822295_mmff94.sdf
# Minimizando C04832010_mmff94.sdf
# Minimizando C04834703_mmff94.sdf
# Minimizando C04847544_mmff94.sdf
# Minimizando C04847811_mmff94.sdf
# Minimizando C04855377_mmff94.sdf
# Minimizando C04855959_mmff94.sdf
# Minimizando C04872732_mmff94.sdf
# Minimizando C04889908_mmff94.sdf
# Minimizando C04889937_mmff94.sdf
# Minimizando C04913422_mmff94.sdf
# Minimizando C04936314_mmff94.sdf
# Minimizando C04937118_mmff94.sdf
# Minimizando C04989146_mmff94.sdf
# Minimizando C05000301_mmff94.sdf
# Minimizando C05029762_mmff94.sdf
# Minimizando C05052194_mmff94.sdf
# Minimizando C05092345_mmff94.sdf
# Minimizando C05208112_mmff94.sdf
# Minimizando C05210573_mmff94.sdf
# Minimizando C05261920_mmff94.sdf
# Minimizando C05276371_mmff94.sdf
# Minimizando C05287981_mmff94.sdf
# Minimizando C05295468_mmff94.sdf
# Minimizando C05385323_mmff94.sdf
# Minimizando C05417453_mmff94.sdf
# Minimizando C05457635_mmff94.sdf
# Minimizando C05496482_mmff94.sdf
# Minimizando C05514501_mmff94.sdf
# Minimizando C05514559_mmff94.sdf
# Minimizando C05528371_mmff94.sdf
# Minimizando C05568056_mmff94.sdf
# Minimizando C05576438_mmff94.sdf
# Minimizando C05577851_mmff94.sdf
# Minimizando C05591994_mmff94.sdf
# Minimizando C05661217_mmff94.sdf
# Minimizando C05670488_mmff94.sdf
# Minimizando C05697590_mmff94.sdf
# Minimizando C05700436_mmff94.sdf
# Minimizando C05716242_mmff94.sdf
# Minimizando C05760741_mmff94.sdf
# Minimizando C05783466_mmff94.sdf
# Minimizando C05788403_mmff94.sdf
# Minimizando C05993663_mmff94.sdf
# Minimizando C06068005_mmff94.sdf
# Minimizando C06075275_mmff94.sdf
# Minimizando C06077575_mmff94.sdf
# Minimizando C06077754_mmff94.sdf
# Minimizando C06080921_mmff94.sdf
# Minimizando C06104747_mmff94.sdf
# Minimizando C06149032_mmff94.sdf
# Minimizando C06149113_mmff94.sdf
# Minimizando C06190140_mmff94.sdf
# Minimizando C06263063_mmff94.sdf
# Minimizando C06268455_mmff94.sdf
# Minimizando C06281550_mmff94.sdf
# Minimizando C06281789_mmff94.sdf
# Minimizando C06281900_mmff94.sdf
# Minimizando C06282143_mmff94.sdf
# Minimizando C06283269_mmff94.sdf
# Minimizando C06284094_mmff94.sdf
# Minimizando C06300630_mmff94.sdf
# Minimizando C06300822_mmff94.sdf
# Minimizando C06410001_mmff94.sdf
# Minimizando C06442868_mmff94.sdf
# Minimizando C06445135_mmff94.sdf
# Minimizando C06490155_mmff94.sdf
# Minimizando C06509943_mmff94.sdf
# Minimizando C06530416_mmff94.sdf
# Minimizando C06546066_mmff94.sdf
# Minimizando C06564182_mmff94.sdf
# Minimizando C06670456_mmff94.sdf
# Minimizando C06680185_mmff94.sdf
# Minimizando C06706838_mmff94.sdf
# Minimizando C06715177_mmff94.sdf
# Minimizando C06720175_mmff94.sdf
# Minimizando C06883122_mmff94.sdf
# Minimizando C06883659_mmff94.sdf
# Minimizando C06894712_mmff94.sdf
# Minimizando C06915752_mmff94.sdf
# Minimizando C06947621_mmff94.sdf
# Minimizando C06949310_mmff94.sdf
# Minimizando C07045295_mmff94.sdf
# Minimizando C07057865_mmff94.sdf
# Minimizando C07082440_mmff94.sdf
# Minimizando C07204497_mmff94.sdf
# Minimizando C07227834_mmff94.sdf
# Minimizando C07246453_mmff94.sdf
# Minimizando C07445587_mmff94.sdf
# Minimizando C07461969_mmff94.sdf
# Minimizando C07535582_mmff94.sdf
# Minimizando C07540810_mmff94.sdf
# Minimizando C07635406_mmff94.sdf
# Minimizando C07780328_mmff94.sdf
# Minimizando C07813408_mmff94.sdf
# Minimizando C07986510_mmff94.sdf
# Minimizando C07989413_mmff94.sdf
# Minimizando C08010089_mmff94.sdf
# Minimizando C08020391_mmff94.sdf
# Minimizando C08020403_mmff94.sdf
# Minimizando C08029880_mmff94.sdf
# Minimizando C08036860_mmff94.sdf
# Minimizando C08079882_mmff94.sdf
# Minimizando C08135517_mmff94.sdf
# Minimizando C08180817_mmff94.sdf
# Minimizando C08226522_mmff94.sdf
# Minimizando C08299069_mmff94.sdf
# Minimizando C08314675_mmff94.sdf
# Minimizando C08320826_mmff94.sdf
# Minimizando C08346238_mmff94.sdf
# Minimizando C08379275_mmff94.sdf
# Minimizando C08418740_mmff94.sdf
# Minimizando C08429685_mmff94.sdf
# Minimizando C08442832_mmff94.sdf
# Minimizando C08468061_mmff94.sdf
# Minimizando C08533998_mmff94.sdf
# Minimizando C08562315_mmff94.sdf
# Minimizando C08569312_mmff94.sdf
# Minimizando C08612406_mmff94.sdf
# Minimizando C08676894_mmff94.sdf
# Minimizando C08685014_mmff94.sdf
# Minimizando C08707791_mmff94.sdf
# Minimizando C08742503_mmff94.sdf
# Minimizando C08746877_mmff94.sdf
# Minimizando C08746878_mmff94.sdf
# Minimizando C08748879_mmff94.sdf
# Minimizando C08753017_mmff94.sdf
# Minimizando C08764404_mmff94.sdf
# Minimizando C08772356_mmff94.sdf
# Minimizando C08788777_mmff94.sdf
# Minimizando C08790150_mmff94.sdf
# Minimizando C08790300_mmff94.sdf
# Minimizando C08838318_mmff94.sdf
# Minimizando C08838319_mmff94.sdf
# Minimizando C08844374_mmff94.sdf
# Minimizando C08845503_mmff94.sdf
# Minimizando C08873418_mmff94.sdf
# Minimizando C08879373_mmff94.sdf
# Minimizando C08886908_mmff94.sdf
# Minimizando C08902064_mmff94.sdf
# Minimizando C08922185_mmff94.sdf
# Minimizando C08922190_mmff94.sdf
# Minimizando C08934136_mmff94.sdf
# Minimizando C08951532_mmff94.sdf
# Minimizando C08951753_mmff94.sdf
# Minimizando C08963260_mmff94.sdf
# Minimizando C08964210_mmff94.sdf
# Minimizando C08994797_mmff94.sdf
# Minimizando C08995709_mmff94.sdf
# Minimizando C09007904_mmff94.sdf
# Minimizando C09008486_mmff94.sdf
# Minimizando C09042442_mmff94.sdf
# Minimizando C09057772_mmff94.sdf
# Minimizando C09079670_mmff94.sdf
# Minimizando C09088144_mmff94.sdf
# Minimizando C09113433_mmff94.sdf
# Minimizando C09123840_mmff94.sdf
# Minimizando C09135739_mmff94.sdf
# Minimizando C09135741_mmff94.sdf
# Minimizando C09135801_mmff94.sdf
# Minimizando C09144774_mmff94.sdf
# Minimizando C09158107_mmff94.sdf
# Minimizando C09194836_mmff94.sdf
# Minimizando C09210833_mmff94.sdf
# Minimizando C09218315_mmff94.sdf
# Minimizando C09237637_mmff94.sdf
# Minimizando C09264595_mmff94.sdf
# Minimizando C09269469_mmff94.sdf
# Minimizando C09272784_mmff94.sdf
# Minimizando C09273510_mmff94.sdf
# Minimizando C09306523_mmff94.sdf
# Minimizando C09311979_mmff94.sdf
# Minimizando C09312200_mmff94.sdf
# Minimizando C09312867_mmff94.sdf
# Minimizando C09315913_mmff94.sdf
# Minimizando C09316031_mmff94.sdf
# Minimizando C09322628_mmff94.sdf
# Minimizando C09328106_mmff94.sdf
# Minimizando C09329440_mmff94.sdf
# Minimizando C09350611_mmff94.sdf
# Minimizando C09350731_mmff94.sdf
# Minimizando C09350732_mmff94.sdf
# Minimizando C09356988_mmff94.sdf
# Minimizando C09357622_mmff94.sdf
# Minimizando C09359707_mmff94.sdf
# Minimizando C09411304_mmff94.sdf
# Minimizando C09412264_mmff94.sdf
# Minimizando C09419267_mmff94.sdf
# Minimizando C09433320_mmff94.sdf
# Minimizando C09433322_mmff94.sdf
# Minimizando C09440734_mmff94.sdf
# Minimizando C09449917_mmff94.sdf
# Minimizando C09452144_mmff94.sdf
# Minimizando C09466397_mmff94.sdf
# Minimizando C09468701_mmff94.sdf
# Minimizando C09488342_mmff94.sdf
# Minimizando C09488744_mmff94.sdf
# Minimizando C09491405_mmff94.sdf
# Minimizando C09494654_mmff94.sdf
# Minimizando C09505376_mmff94.sdf
# Minimizando C09516175_mmff94.sdf
# Minimizando C09518177_mmff94.sdf
# Minimizando C09520352_mmff94.sdf
# Minimizando C09540614_mmff94.sdf
# Minimizando C09560603_mmff94.sdf
# Minimizando C09581512_mmff94.sdf
# Minimizando C09597468_mmff94.sdf
# Minimizando C09600982_mmff94.sdf
# Minimizando C09613424_mmff94.sdf
# Minimizando C09633651_mmff94.sdf
# Minimizando C09663720_mmff94.sdf
# Minimizando C09703780_mmff94.sdf
# Minimizando C09705654_mmff94.sdf
# Minimizando C09739408_mmff94.sdf
# Minimizando C09753732_mmff94.sdf
# Minimizando C09763632_mmff94.sdf
# Minimizando C09782034_mmff94.sdf
# Minimizando C09828926_mmff94.sdf
# Minimizando C09829590_mmff94.sdf
# Minimizando C09831442_mmff94.sdf
# Minimizando C09866911_mmff94.sdf
# Minimizando C09867887_mmff94.sdf
# Minimizando C09873945_mmff94.sdf
# Minimizando C09911734_mmff94.sdf
# Minimizando C09915805_mmff94.sdf
# Minimizando C09951016_mmff94.sdf
# Minimizando C10010970_mmff94.sdf
# Minimizando C10013298_mmff94.sdf
# Minimizando C10040722_mmff94.sdf
# Minimizando C10040916_mmff94.sdf
# Minimizando C10068219_mmff94.sdf
# Minimizando C10080002_mmff94.sdf
# Minimizando C10117309_mmff94.sdf
# Minimizando C10191126_mmff94.sdf
# Minimizando C10209565_mmff94.sdf
# Minimizando C10211225_mmff94.sdf
# Minimizando C10220076_mmff94.sdf
# Minimizando C10315666_mmff94.sdf
# Minimizando C10395782_mmff94.sdf
# Minimizando C10443999_mmff94.sdf
# Minimizando C10536877_mmff94.sdf
# Minimizando C10537541_mmff94.sdf
# Minimizando C10572814_mmff94.sdf
# Minimizando C10624347_mmff94.sdf
# Minimizando C10643774_mmff94.sdf
# Minimizando C10644921_mmff94.sdf
# Minimizando C10667711_mmff94.sdf
# Minimizando C10716060_mmff94.sdf
# Minimizando C10722506_mmff94.sdf
# Minimizando C10840842_mmff94.sdf
# Minimizando C10864526_mmff94.sdf
# Minimizando C10918486_mmff94.sdf
# Minimizando C11011075_mmff94.sdf
# Minimizando C11013146_mmff94.sdf
# Minimizando C11055701_mmff94.sdf
# Minimizando C11134523_mmff94.sdf
# Minimizando C11173695_mmff94.sdf
# Minimizando C11242229_mmff94.sdf
# Minimizando C11338494_mmff94.sdf
# Minimizando C11388713_mmff94.sdf
# Minimizando C11405504_mmff94.sdf
# Minimizando C11432520_mmff94.sdf
# Minimizando C11440504_mmff94.sdf
# Minimizando C11443455_mmff94.sdf
# Minimizando C11568840_mmff94.sdf
# Minimizando C11568843_mmff94.sdf
# Minimizando C11580937_mmff94.sdf
# Minimizando C11592695_mmff94.sdf
# Minimizando C11592703_mmff94.sdf
# Minimizando C11666973_mmff94.sdf
# Minimizando C11690515_mmff94.sdf
# Minimizando C11690690_mmff94.sdf
# Minimizando C11729651_mmff94.sdf
# Minimizando C11737030_mmff94.sdf
# Minimizando C11740142_mmff94.sdf
# Minimizando C11740146_mmff94.sdf
# Minimizando C11898341_mmff94.sdf
# Minimizando C11898493_mmff94.sdf
# Minimizando C11898665_mmff94.sdf
# Minimizando C11937551_mmff94.sdf
# Minimizando C11965234_mmff94.sdf
# Minimizando C11996072_mmff94.sdf
# Minimizando C12130945_mmff94.sdf
# Minimizando C12145921_mmff94.sdf
# Minimizando C12207130_mmff94.sdf
# Minimizando C12207423_mmff94.sdf
# Minimizando C12217807_mmff94.sdf
# Minimizando C12229165_mmff94.sdf
# Minimizando C12296363_mmff94.sdf
# Minimizando C12314075_mmff94.sdf
# Minimizando C12338907_mmff94.sdf
# Minimizando C12349733_mmff94.sdf
# Minimizando C12369933_mmff94.sdf
# Minimizando C12375654_mmff94.sdf
# Minimizando C12382746_mmff94.sdf
# Minimizando C12390840_mmff94.sdf
# Minimizando C12411050_mmff94.sdf
# Minimizando C12417053_mmff94.sdf
# Minimizando C12418205_mmff94.sdf
# Minimizando C12458568_mmff94.sdf
# Minimizando C12494190_mmff94.sdf
# Minimizando C12496675_mmff94.sdf
# Minimizando C12497141_mmff94.sdf
# Minimizando C12497968_mmff94.sdf
# Minimizando C12498019_mmff94.sdf
# Minimizando C12498021_mmff94.sdf
# Minimizando C12498080_mmff94.sdf
# Minimizando C12499441_mmff94.sdf
# Minimizando C12499608_mmff94.sdf
# Minimizando C12500087_mmff94.sdf
# Minimizando C12500347_mmff94.sdf
# Minimizando C12502375_mmff94.sdf
# Minimizando C12530483_mmff94.sdf
# Minimizando C12546563_mmff94.sdf
# Minimizando C12549552_mmff94.sdf
# Minimizando C12553301_mmff94.sdf
# Minimizando C12564251_mmff94.sdf
# Minimizando C12567436_mmff94.sdf
# Minimizando C12567754_mmff94.sdf
# Minimizando C12574038_mmff94.sdf
# Minimizando C12600472_mmff94.sdf
# Minimizando C12601258_mmff94.sdf
# Minimizando C12608366_mmff94.sdf
# Minimizando C12624528_mmff94.sdf
# Minimizando C12635710_mmff94.sdf
# Minimizando C12686686_mmff94.sdf
# Minimizando C12764578_mmff94.sdf
# Minimizando C12799683_mmff94.sdf
# Minimizando C12820565_mmff94.sdf
# Minimizando C12850468_mmff94.sdf
# Minimizando C12872682_mmff94.sdf
# Minimizando C12877936_mmff94.sdf
# Minimizando C12881775_mmff94.sdf
# Minimizando C12881935_mmff94.sdf
# Minimizando C12882492_mmff94.sdf
# Minimizando C12892299_mmff94.sdf
# Minimizando C12902051_mmff94.sdf
# Minimizando C12918446_mmff94.sdf
# Minimizando C12922954_mmff94.sdf
# Minimizando C12923476_mmff94.sdf
# Minimizando C12981648_mmff94.sdf
# Minimizando C13008604_mmff94.sdf
# Minimizando C13012107_mmff94.sdf
# Minimizando C13039739_mmff94.sdf
# Minimizando C13040669_mmff94.sdf
# Minimizando C13052642_mmff94.sdf
# Minimizando C13061797_mmff94.sdf
# Minimizando C13065138_mmff94.sdf
# Minimizando C13071949_mmff94.sdf
# Minimizando C13124279_mmff94.sdf
# Minimizando C13130129_mmff94.sdf
# Minimizando C13131760_mmff94.sdf
# Minimizando C13132468_mmff94.sdf
# Minimizando C13136833_mmff94.sdf
# Minimizando C13146152_mmff94.sdf
# Minimizando C13149258_mmff94.sdf
# Minimizando C13153632_mmff94.sdf
# Minimizando C13175316_mmff94.sdf
# Minimizando C13192242_mmff94.sdf
# Minimizando C13311064_mmff94.sdf
# Minimizando C13345481_mmff94.sdf
# Minimizando C13376294_mmff94.sdf
# Minimizando C13382195_mmff94.sdf
# Minimizando C13393585_mmff94.sdf
# Minimizando C13438221_mmff94.sdf
# Minimizando C13451071_mmff94.sdf
# Minimizando C13451092_mmff94.sdf
# Minimizando C13464789_mmff94.sdf
# Minimizando C13467260_mmff94.sdf
# Minimizando C13475459_mmff94.sdf
# Minimizando C13495845_mmff94.sdf
# Minimizando C13498799_mmff94.sdf
# Minimizando C13498807_mmff94.sdf
# Minimizando C13517346_mmff94.sdf
# Minimizando C13517358_mmff94.sdf
# Minimizando C13524732_mmff94.sdf
# Minimizando C13549194_mmff94.sdf
# Minimizando C13550346_mmff94.sdf
# Minimizando C13551432_mmff94.sdf
# Minimizando C13566258_mmff94.sdf
# Minimizando C13582351_mmff94.sdf
# Minimizando C13591961_mmff94.sdf
# Minimizando C13592204_mmff94.sdf
# Minimizando C13596117_mmff94.sdf
# Minimizando C13638939_mmff94.sdf
# Minimizando C13639574_mmff94.sdf
# Minimizando C13642697_mmff94.sdf
# Minimizando C13642811_mmff94.sdf
# Minimizando C13645344_mmff94.sdf
# Minimizando C13690528_mmff94.sdf
# Minimizando C13694920_mmff94.sdf
# Minimizando C13730630_mmff94.sdf
# Minimizando C13757964_mmff94.sdf
# Minimizando C13783420_mmff94.sdf
# Minimizando C13783422_mmff94.sdf
# Minimizando C13833445_mmff94.sdf
# Minimizando C13896037_mmff94.sdf
# Minimizando C13946306_mmff94.sdf
# Minimizando C14042202_mmff94.sdf
# Minimizando C14074948_mmff94.sdf
# Minimizando C14129515_mmff94.sdf
# Minimizando C14146913_mmff94.sdf
# Minimizando C14158745_mmff94.sdf
# Minimizando C14162048_mmff94.sdf
# Minimizando C14183529_mmff94.sdf
# Minimizando C14184696_mmff94.sdf
# Minimizando C14187470_mmff94.sdf
# Minimizando C14199232_mmff94.sdf
# Minimizando C14237851_mmff94.sdf
# Minimizando C14347881_mmff94.sdf
# Minimizando C14387756_mmff94.sdf
# Minimizando C14455983_mmff94.sdf
# Minimizando C14456276_mmff94.sdf
# Minimizando C14458252_mmff94.sdf
# Minimizando C14459054_mmff94.sdf
# Minimizando C14461131_mmff94.sdf
# Minimizando C14466613_mmff94.sdf
# Minimizando C14467776_mmff94.sdf
# Minimizando C14471646_mmff94.sdf
# Minimizando C14477062_mmff94.sdf
# Minimizando C14477604_mmff94.sdf
# Minimizando C14480129_mmff94.sdf
# Minimizando C14510558_mmff94.sdf
# Minimizando C14535030_mmff94.sdf
# Minimizando C14545603_mmff94.sdf
# Minimizando C14548385_mmff94.sdf
# Minimizando C14550981_mmff94.sdf
# Minimizando C14550984_mmff94.sdf
# Minimizando C14551937_mmff94.sdf
# Minimizando C14586363_mmff94.sdf
# Minimizando C14599640_mmff94.sdf
# Minimizando C14607739_mmff94.sdf
# Minimizando C14663717_mmff94.sdf
# Minimizando C14669868_mmff94.sdf
# Minimizando C14720645_mmff94.sdf
# Minimizando C14748698_mmff94.sdf
# Minimizando C14880856_mmff94.sdf
# Minimizando C14882221_mmff94.sdf
# Minimizando C15018641_mmff94.sdf
# Minimizando C15081146_mmff94.sdf
# Minimizando C15081148_mmff94.sdf
# Minimizando C15085078_mmff94.sdf
# Minimizando C15086313_mmff94.sdf
# Minimizando C15133323_mmff94.sdf
# Minimizando C15181132_mmff94.sdf
# Minimizando C15206336_mmff94.sdf
# Minimizando C15519169_mmff94.sdf
# Minimizando C15573238_mmff94.sdf
# Minimizando C15657736_mmff94.sdf
# Minimizando C15686453_mmff94.sdf
# Minimizando C15692214_mmff94.sdf
# Minimizando C15746587_mmff94.sdf
# Minimizando C15791027_mmff94.sdf
# Minimizando C15799356_mmff94.sdf
# Minimizando C15806170_mmff94.sdf
# Minimizando C15840433_mmff94.sdf
# Minimizando C15879980_mmff94.sdf
# Minimizando C15919773_mmff94.sdf
# Minimizando C15938388_mmff94.sdf
# Minimizando C15945373_mmff94.sdf
# Minimizando C15945433_mmff94.sdf
# Minimizando C15972615_mmff94.sdf
# Minimizando C16011521_mmff94.sdf
# Minimizando C16020777_mmff94.sdf
# Minimizando C16072601_mmff94.sdf
# Minimizando C16109615_mmff94.sdf
# Minimizando C16133516_mmff94.sdf
# Minimizando C16267915_mmff94.sdf
# Minimizando C16426212_mmff94.sdf
# Minimizando C16429502_mmff94.sdf
# Minimizando C16552117_mmff94.sdf
# Minimizando C16671882_mmff94.sdf
# Minimizando C16673718_mmff94.sdf
# Minimizando C16677530_mmff94.sdf
# Minimizando C16678042_mmff94.sdf
# Minimizando C16688426_mmff94.sdf
# Minimizando C16689962_mmff94.sdf
# Minimizando C16689965_mmff94.sdf
# Minimizando C16769406_mmff94.sdf
# Minimizando C16845795_mmff94.sdf
# Minimizando C16857004_mmff94.sdf
# Minimizando C16906489_mmff94.sdf
# Minimizando C16906872_mmff94.sdf
# Minimizando C16958780_mmff94.sdf
# Minimizando C16969335_mmff94.sdf
# Minimizando C16969627_mmff94.sdf
# Minimizando C17004567_mmff94.sdf
# Minimizando C17042487_mmff94.sdf
# Minimizando C17043953_mmff94.sdf
# Minimizando C17059949_mmff94.sdf
# Minimizando C17068808_mmff94.sdf
# Minimizando C17157357_mmff94.sdf
# Minimizando C17191854_mmff94.sdf
# Minimizando C17303846_mmff94.sdf
# Minimizando C17306238_mmff94.sdf
# Minimizando C17306872_mmff94.sdf
# Minimizando C17355880_mmff94.sdf
# Minimizando C17642895_mmff94.sdf
# Minimizando C17958656_mmff94.sdf
# Minimizando C18101974_mmff94.sdf
# Minimizando C18104808_mmff94.sdf
# Minimizando C18115372_mmff94.sdf
# Minimizando C18196521_mmff94.sdf
# Minimizando C18205462_mmff94.sdf
# Minimizando C18276277_mmff94.sdf
# Minimizando C18322948_mmff94.sdf
# Minimizando C18581227_mmff94.sdf
# Minimizando C18935580_mmff94.sdf
# Minimizando C18939433_mmff94.sdf
# Minimizando C18951478_mmff94.sdf
# Minimizando C19078913_mmff94.sdf
# Minimizando C19080818_mmff94.sdf
# Minimizando C19112881_mmff94.sdf
# Minimizando C19209044_mmff94.sdf
# Minimizando C19212057_mmff94.sdf
# Minimizando C19230877_mmff94.sdf
# Minimizando C19266059_mmff94.sdf
# Minimizando C19296798_mmff94.sdf
# Minimizando C19312446_mmff94.sdf
# Minimizando C19354078_mmff94.sdf
# Minimizando C19354486_mmff94.sdf
# Minimizando C19433870_mmff94.sdf
# Minimizando C19447518_mmff94.sdf
# Minimizando C19563054_mmff94.sdf
# Minimizando C19568306_mmff94.sdf
# Minimizando C19572476_mmff94.sdf
# Minimizando C19597252_mmff94.sdf
# Minimizando C19638197_mmff94.sdf
# Minimizando C19639895_mmff94.sdf
# Minimizando C19702463_mmff94.sdf
# Minimizando C19732749_mmff94.sdf
# Minimizando C19742381_mmff94.sdf
# Minimizando C19760157_mmff94.sdf
# Minimizando C19791832_mmff94.sdf
# Minimizando C19812108_mmff94.sdf
# Minimizando C19837540_mmff94.sdf
# Minimizando C19893729_mmff94.sdf
# Minimizando C19897767_mmff94.sdf
# Minimizando C19955551_mmff94.sdf
# Minimizando C19959922_mmff94.sdf
# Minimizando C19974064_mmff94.sdf
# Minimizando C19974115_mmff94.sdf
# Minimizando C20028270_mmff94.sdf
# Minimizando C20046191_mmff94.sdf
# Minimizando C20054557_mmff94.sdf
# Minimizando C20115283_mmff94.sdf
# Minimizando C20137939_mmff94.sdf
# Minimizando C20206562_mmff94.sdf
# Minimizando C20207552_mmff94.sdf
# Minimizando C20207696_mmff94.sdf
# Minimizando C20207936_mmff94.sdf
# Minimizando C20219018_mmff94.sdf
# Minimizando C20220642_mmff94.sdf
# Minimizando C20231203_mmff94.sdf
# Minimizando C20235846_mmff94.sdf
# Minimizando C20235865_mmff94.sdf
# Minimizando C20262635_mmff94.sdf
# Minimizando C20262883_mmff94.sdf
# Minimizando C20266245_mmff94.sdf
# Minimizando C20270878_mmff94.sdf
# Minimizando C20275497_mmff94.sdf
# Minimizando C20321228_mmff94.sdf
# Minimizando C20335825_mmff94.sdf
# Minimizando C20337483_mmff94.sdf
# Minimizando C20356666_mmff94.sdf
# Minimizando C20357484_mmff94.sdf
# Minimizando C20362459_mmff94.sdf
# Minimizando C20468155_mmff94.sdf
# Minimizando C20504794_mmff94.sdf
# Minimizando C20534233_mmff94.sdf
# Minimizando C20536787_mmff94.sdf
# Minimizando C20548992_mmff94.sdf
# Minimizando C20558430_mmff94.sdf
# Minimizando C20573601_mmff94.sdf
# Minimizando C20575032_mmff94.sdf
# Minimizando C20607197_mmff94.sdf
# Minimizando C20611539_mmff94.sdf
# Minimizando C20673346_mmff94.sdf
# Minimizando C20676290_mmff94.sdf
# Minimizando C20686734_mmff94.sdf
# Minimizando C20701775_mmff94.sdf
# Minimizando C20716368_mmff94.sdf
# Minimizando C20729800_mmff94.sdf
# Minimizando C20748710_mmff94.sdf
# Minimizando C20758890_mmff94.sdf
# Minimizando C20764549_mmff94.sdf
# Minimizando C20764648_mmff94.sdf
# Minimizando C20785940_mmff94.sdf
# Minimizando C20799913_mmff94.sdf
# Minimizando C20803419_mmff94.sdf
# Minimizando C20803423_mmff94.sdf
# Minimizando C20833112_mmff94.sdf
# Minimizando C20837840_mmff94.sdf
# Minimizando C20984961_mmff94.sdf
# Minimizando C20986814_mmff94.sdf
# Minimizando C21040731_mmff94.sdf
# Minimizando C21040895_mmff94.sdf
# Minimizando C21050550_mmff94.sdf
# Minimizando C21077545_mmff94.sdf
# Minimizando C21080080_mmff94.sdf
# Minimizando C21090373_mmff94.sdf
# Minimizando C21141407_mmff94.sdf
# Minimizando C21242905_mmff94.sdf
# Minimizando C21247500_mmff94.sdf
# Minimizando C21263418_mmff94.sdf
# Minimizando C21294961_mmff94.sdf
# Minimizando C21320041_mmff94.sdf
# Minimizando C21503610_mmff94.sdf
# Minimizando C21605469_mmff94.sdf
# Minimizando C21648059_mmff94.sdf
# Minimizando C21741995_mmff94.sdf
# Minimizando C21744711_mmff94.sdf
# Minimizando C21775519_mmff94.sdf
# Minimizando C21813386_mmff94.sdf
# Minimizando C21814588_mmff94.sdf
# Minimizando C21866487_mmff94.sdf
# Minimizando C21877509_mmff94.sdf
# Minimizando C21971016_mmff94.sdf
# Minimizando C21971022_mmff94.sdf
# Minimizando C21971025_mmff94.sdf
# Minimizando C22001309_mmff94.sdf
# Minimizando C22001321_mmff94.sdf
# Minimizando C22018699_mmff94.sdf
# Minimizando C22032905_mmff94.sdf
# Minimizando C22058406_mmff94.sdf
# Minimizando C22067032_mmff94.sdf
# Minimizando C22079669_mmff94.sdf
# Minimizando C22146312_mmff94.sdf
# Minimizando C22157164_mmff94.sdf
# Minimizando C22240228_mmff94.sdf
# Minimizando C22299812_mmff94.sdf
# Minimizando C22325186_mmff94.sdf
# Minimizando C22464484_mmff94.sdf
# Minimizando C22577385_mmff94.sdf
# Minimizando C22602691_mmff94.sdf
# Minimizando C22782588_mmff94.sdf
# Minimizando C22787872_mmff94.sdf
# Minimizando C22792016_mmff94.sdf
# Minimizando C22808222_mmff94.sdf
# Minimizando C22918525_mmff94.sdf
# Minimizando C22922299_mmff94.sdf
# Minimizando C22937077_mmff94.sdf
# Minimizando C22958751_mmff94.sdf
# Minimizando C23076886_mmff94.sdf
# Minimizando C23076888_mmff94.sdf
# Minimizando C23133230_mmff94.sdf
# Minimizando C23271422_mmff94.sdf
# Minimizando C23332312_mmff94.sdf
# Minimizando C23372411_mmff94.sdf
# Minimizando C23606924_mmff94.sdf
# Minimizando C23606983_mmff94.sdf
# Minimizando C23630705_mmff94.sdf
# Minimizando C23667578_mmff94.sdf
# Minimizando C24097286_mmff94.sdf
# Minimizando C24152432_mmff94.sdf
# Minimizando C24215700_mmff94.sdf
# Minimizando C24228190_mmff94.sdf
# Minimizando C24257523_mmff94.sdf
# Minimizando C24270365_mmff94.sdf
# Minimizando C24437508_mmff94.sdf
# Minimizando C24437523_mmff94.sdf
# Minimizando C24507118_mmff94.sdf
# Minimizando C24736747_mmff94.sdf
# Minimizando C24892510_mmff94.sdf
# Minimizando C24950816_mmff94.sdf
# Minimizando C24962704_mmff94.sdf
# Minimizando C25102214_mmff94.sdf
# Minimizando C25124294_mmff94.sdf
# Minimizando C25336441_mmff94.sdf
# Minimizando C25353816_mmff94.sdf
# Minimizando C25533073_mmff94.sdf
# Minimizando C25539829_mmff94.sdf
# Minimizando C25597544_mmff94.sdf
# Minimizando C25607371_mmff94.sdf
# Minimizando C25656366_mmff94.sdf
# Minimizando C25747991_mmff94.sdf
# Minimizando C25782571_mmff94.sdf
# Minimizando C26058448_mmff94.sdf
# Minimizando C26272823_mmff94.sdf
# Minimizando C26458158_mmff94.sdf
# Minimizando C26540782_mmff94.sdf
# Minimizando C26647301_mmff94.sdf
# Minimizando C26647878_mmff94.sdf
# Minimizando C26786650_mmff94.sdf
# Minimizando C26804708_mmff94.sdf
# Minimizando C26960173_mmff94.sdf
# Minimizando C27308261_mmff94.sdf
# Minimizando C27333456_mmff94.sdf
# Minimizando C27376335_mmff94.sdf
# Minimizando C27499185_mmff94.sdf
# Minimizando C27533498_mmff94.sdf
# Minimizando C27550020_mmff94.sdf
# Minimizando C27550429_mmff94.sdf
# Minimizando C27550694_mmff94.sdf
# Minimizando C27553089_mmff94.sdf
# Minimizando C27556331_mmff94.sdf
# Minimizando C27557873_mmff94.sdf
# Minimizando C27664401_mmff94.sdf
# Minimizando C27664403_mmff94.sdf
# Minimizando C27836023_mmff94.sdf
# Minimizando C28053345_mmff94.sdf
# Minimizando C28103568_mmff94.sdf
# Minimizando C28198883_mmff94.sdf
# Minimizando C28510273_mmff94.sdf
# Minimizando C28535047_mmff94.sdf
# Minimizando C28572899_mmff94.sdf
# Minimizando C28619987_mmff94.sdf
# Minimizando C28851428_mmff94.sdf
# Minimizando C28994847_mmff94.sdf
# Minimizando C29341438_mmff94.sdf
# Minimizando C29494406_mmff94.sdf
# Minimizando C29499932_mmff94.sdf
# Minimizando C29529003_mmff94.sdf
# Minimizando C29568415_mmff94.sdf
# Minimizando C29603514_mmff94.sdf
# Minimizando C29650468_mmff94.sdf
# Minimizando C29699489_mmff94.sdf
# Minimizando C29699494_mmff94.sdf
# Minimizando C30026599_mmff94.sdf
# Minimizando C30343323_mmff94.sdf
# Minimizando C30431813_mmff94.sdf
# Minimizando C30538019_mmff94.sdf
# Minimizando C30587499_mmff94.sdf
# Minimizando C30828310_mmff94.sdf
# Minimizando C30984077_mmff94.sdf
# Minimizando C31157853_mmff94.sdf
# Minimizando C31454032_mmff94.sdf
# Minimizando C31625139_mmff94.sdf
# Minimizando C31625156_mmff94.sdf
# Minimizando C31745579_mmff94.sdf
# Minimizando C31813413_mmff94.sdf
# Minimizando C31813992_mmff94.sdf
# Minimizando C31814648_mmff94.sdf
# Minimizando C31906020_mmff94.sdf
# Minimizando C31931992_mmff94.sdf
# Minimizando C31934133_mmff94.sdf
# Minimizando C31934545_mmff94.sdf
# Minimizando C31947373_mmff94.sdf
# Minimizando C32091133_mmff94.sdf
# Minimizando C32091138_mmff94.sdf
# Minimizando C32103565_mmff94.sdf
# Minimizando C32118801_mmff94.sdf
# Minimizando C32209899_mmff94.sdf
# Minimizando C32442700_mmff94.sdf
# Minimizando C32578414_mmff94.sdf
# Minimizando C32581043_mmff94.sdf
# Minimizando C32603120_mmff94.sdf
# Minimizando C32605479_mmff94.sdf
# Minimizando C32610508_mmff94.sdf
# Minimizando C32646366_mmff94.sdf
# Minimizando C32960887_mmff94.sdf
# Minimizando C32964323_mmff94.sdf
# Minimizando C32964445_mmff94.sdf
# Minimizando C32964468_mmff94.sdf
# Minimizando C32983149_mmff94.sdf
# Minimizando C32984642_mmff94.sdf
# Minimizando C33021693_mmff94.sdf
# Minimizando C33063187_mmff94.sdf
# Minimizando C33154863_mmff94.sdf
# Minimizando C33271709_mmff94.sdf
# Minimizando C33280089_mmff94.sdf
# Minimizando C33306457_mmff94.sdf
# Minimizando C33310192_mmff94.sdf
# Minimizando C33331895_mmff94.sdf
# Minimizando C33370004_mmff94.sdf
# Minimizando C33400099_mmff94.sdf
# Minimizando C33551422_mmff94.sdf
# Minimizando C33626475_mmff94.sdf
# Minimizando C33737312_mmff94.sdf
# Minimizando C33938237_mmff94.sdf
# Minimizando C33960346_mmff94.sdf
# Minimizando C33997807_mmff94.sdf
# Minimizando C34157617_mmff94.sdf
# Minimizando C34173016_mmff94.sdf
# Minimizando C34207846_mmff94.sdf
# Minimizando C34677379_mmff94.sdf
# Minimizando C34677434_mmff94.sdf
# Minimizando C34677958_mmff94.sdf
# Minimizando C34727035_mmff94.sdf
# Minimizando C34734595_mmff94.sdf
# Minimizando C34734968_mmff94.sdf
# Minimizando C34747919_mmff94.sdf
# Minimizando C34748611_mmff94.sdf
# Minimizando C34748952_mmff94.sdf
# Minimizando C34774715_mmff94.sdf
# Minimizando C34779519_mmff94.sdf
# Minimizando C34785981_mmff94.sdf
# Minimizando C34789289_mmff94.sdf
# Minimizando C34889462_mmff94.sdf
# Minimizando C34889464_mmff94.sdf
# Minimizando C34906329_mmff94.sdf
# Minimizando C34930681_mmff94.sdf
# Minimizando C34974961_mmff94.sdf
# Minimizando C35026151_mmff94.sdf
# Minimizando C35092927_mmff94.sdf
# Minimizando C35097080_mmff94.sdf
# Minimizando C35188030_mmff94.sdf
# Minimizando C35266406_mmff94.sdf
# Minimizando C35271772_mmff94.sdf
# Minimizando C35334680_mmff94.sdf
# Minimizando C35351389_mmff94.sdf
# Minimizando C35379102_mmff94.sdf
# Minimizando C35395411_mmff94.sdf
# Minimizando C35397426_mmff94.sdf
# Minimizando C35397599_mmff94.sdf
# Minimizando C35422610_mmff94.sdf
# Minimizando C35455751_mmff94.sdf
# Minimizando C35481972_mmff94.sdf
# Minimizando C35491156_mmff94.sdf
# Minimizando C35507256_mmff94.sdf
# Minimizando C35564519_mmff94.sdf
# Minimizando C35577438_mmff94.sdf
# Minimizando C35591777_mmff94.sdf
# Minimizando C35620742_mmff94.sdf
# Minimizando C35636770_mmff94.sdf
# Minimizando C35642029_mmff94.sdf
# Minimizando C35642035_mmff94.sdf
# Minimizando C35642731_mmff94.sdf
# Minimizando C35646539_mmff94.sdf
# Minimizando C35655676_mmff94.sdf
# Minimizando C35667355_mmff94.sdf
# Minimizando C35679193_mmff94.sdf
# Minimizando C35685771_mmff94.sdf
# Minimizando C35745398_mmff94.sdf
# Minimizando C35747134_mmff94.sdf
# Minimizando C35834549_mmff94.sdf
# Minimizando C35870221_mmff94.sdf
# Minimizando C35870823_mmff94.sdf
# Minimizando C35908923_mmff94.sdf
# Minimizando C35926286_mmff94.sdf
# Minimizando C35926300_mmff94.sdf
# Minimizando C35926667_mmff94.sdf
# Minimizando C35934598_mmff94.sdf
# Minimizando C35993638_mmff94.sdf
# Minimizando C36001867_mmff94.sdf
# Minimizando C36007292_mmff94.sdf
# Minimizando C36012703_mmff94.sdf
# Minimizando C36013832_mmff94.sdf
# Minimizando C36013871_mmff94.sdf
# Minimizando C36024455_mmff94.sdf
# Minimizando C36028062_mmff94.sdf
# Minimizando C36028065_mmff94.sdf
# Minimizando C36028117_mmff94.sdf
# Minimizando C36122163_mmff94.sdf
# Minimizando C36128651_mmff94.sdf
# Minimizando C36128849_mmff94.sdf
# Minimizando C36142189_mmff94.sdf
# Minimizando C36142282_mmff94.sdf
# Minimizando C36142298_mmff94.sdf
# Minimizando C36142396_mmff94.sdf
# Minimizando C36142714_mmff94.sdf
# Minimizando C36207232_mmff94.sdf
# Minimizando C36213540_mmff94.sdf
# Minimizando C36266772_mmff94.sdf
# Minimizando C36320080_mmff94.sdf
# Minimizando C36322370_mmff94.sdf
# Minimizando C36325083_mmff94.sdf
# Minimizando C36329782_mmff94.sdf
# Minimizando C36371067_mmff94.sdf
# Minimizando C36371068_mmff94.sdf
# Minimizando C36385541_mmff94.sdf
# Minimizando C36490721_mmff94.sdf
# Minimizando C36494146_mmff94.sdf
# Minimizando C36496869_mmff94.sdf
# Minimizando C36500793_mmff94.sdf
# Minimizando C36523162_mmff94.sdf
# Minimizando C36525843_mmff94.sdf
# Minimizando C36527329_mmff94.sdf
# Minimizando C36537543_mmff94.sdf
# Minimizando C36540626_mmff94.sdf
# Minimizando C36556614_mmff94.sdf
# Minimizando C36556616_mmff94.sdf
# Minimizando C36556620_mmff94.sdf
# Minimizando C36556992_mmff94.sdf
# Minimizando C36556995_mmff94.sdf
# Minimizando C36562468_mmff94.sdf
# Minimizando C36570930_mmff94.sdf
# Minimizando C36570936_mmff94.sdf
# Minimizando C36571209_mmff94.sdf
# Minimizando C36571282_mmff94.sdf
# Minimizando C36576039_mmff94.sdf
# Minimizando C36579684_mmff94.sdf
# Minimizando C36586882_mmff94.sdf
# Minimizando C36591932_mmff94.sdf
# Minimizando C36596277_mmff94.sdf
# Minimizando C36597650_mmff94.sdf
# Minimizando C36597664_mmff94.sdf
# Minimizando C36599966_mmff94.sdf
# Minimizando C36599967_mmff94.sdf
# Minimizando C36602764_mmff94.sdf
# Minimizando C36603236_mmff94.sdf
# Minimizando C36603509_mmff94.sdf
# Minimizando C36617105_mmff94.sdf
# Minimizando C36629533_mmff94.sdf
# Minimizando C36644565_mmff94.sdf
# Minimizando C36644566_mmff94.sdf
# Minimizando C36648021_mmff94.sdf
# Minimizando C36702640_mmff94.sdf
# Minimizando C36703225_mmff94.sdf
# Minimizando C36735049_mmff94.sdf
# Minimizando C36747228_mmff94.sdf
# Minimizando C36748656_mmff94.sdf
# Minimizando C36749444_mmff94.sdf
# Minimizando C36800728_mmff94.sdf
# Minimizando C36802142_mmff94.sdf
# Minimizando C36816512_mmff94.sdf
# Minimizando C36861861_mmff94.sdf
# Minimizando C36936814_mmff94.sdf
# Minimizando C37036686_mmff94.sdf
# Minimizando C37054002_mmff94.sdf
# Minimizando C37066272_mmff94.sdf
# Minimizando C37077435_mmff94.sdf
# Minimizando C37082769_mmff94.sdf
# Minimizando C37191438_mmff94.sdf
# Minimizando C37194807_mmff94.sdf
# Minimizando C37263684_mmff94.sdf
# Minimizando C37264027_mmff94.sdf
# Minimizando C37447405_mmff94.sdf
# Minimizando C37486791_mmff94.sdf
# Minimizando C37488229_mmff94.sdf
# Minimizando C37549242_mmff94.sdf
# Minimizando C37556290_mmff94.sdf
# Minimizando C37556295_mmff94.sdf
# Minimizando C37558095_mmff94.sdf
# Minimizando C37622465_mmff94.sdf
# Minimizando C37715794_mmff94.sdf
# Minimizando C37722326_mmff94.sdf
# Minimizando C37756576_mmff94.sdf
# Minimizando C37773671_mmff94.sdf
# Minimizando C37791253_mmff94.sdf
# Minimizando C37840732_mmff94.sdf
# Minimizando C37841914_mmff94.sdf
# Minimizando C37860092_mmff94.sdf
# Minimizando C37895767_mmff94.sdf
# Minimizando C37896769_mmff94.sdf
# Minimizando C37937548_mmff94.sdf
# Minimizando C37976473_mmff94.sdf
# Minimizando C38050100_mmff94.sdf
# Minimizando C38062921_mmff94.sdf
# Minimizando C38089915_mmff94.sdf
# Minimizando C38108554_mmff94.sdf
# Minimizando C38150049_mmff94.sdf
# Minimizando C38187081_mmff94.sdf
# Minimizando C38519846_mmff94.sdf
# Minimizando C38556628_mmff94.sdf
# Minimizando C38588007_mmff94.sdf
# Minimizando C38592681_mmff94.sdf
# Minimizando C38596018_mmff94.sdf
# Minimizando C38596020_mmff94.sdf
# Minimizando C38597572_mmff94.sdf
# Minimizando C38613357_mmff94.sdf
# Minimizando C38688515_mmff94.sdf
# Minimizando C38742154_mmff94.sdf
# Minimizando C38743146_mmff94.sdf
# Minimizando C38744615_mmff94.sdf
# Minimizando C38745218_mmff94.sdf
# Minimizando C38745477_mmff94.sdf
# Minimizando C38748324_mmff94.sdf
# Minimizando C38751997_mmff94.sdf
# Minimizando C38766138_mmff94.sdf
# Minimizando C38791250_mmff94.sdf
# Minimizando C38797081_mmff94.sdf
# Minimizando C38803469_mmff94.sdf
# Minimizando C38828210_mmff94.sdf
# Minimizando C38828211_mmff94.sdf
# Minimizando C38932735_mmff94.sdf
# Minimizando C38964765_mmff94.sdf
# Minimizando C38966346_mmff94.sdf
# Minimizando C38971092_mmff94.sdf
# Minimizando C38975440_mmff94.sdf
# Minimizando C38976336_mmff94.sdf
# Minimizando C39001066_mmff94.sdf
# Minimizando C39024772_mmff94.sdf
# Minimizando C39024827_mmff94.sdf
# Minimizando C39159679_mmff94.sdf
# Minimizando C39205118_mmff94.sdf
# Minimizando C39206320_mmff94.sdf
# Minimizando C39206339_mmff94.sdf
# Minimizando C39237433_mmff94.sdf
# Minimizando C39237777_mmff94.sdf
# Minimizando C39264945_mmff94.sdf
# Minimizando C39265027_mmff94.sdf
# Minimizando C39273138_mmff94.sdf
# Minimizando C39273139_mmff94.sdf
# Minimizando C39289915_mmff94.sdf
# Minimizando C39293150_mmff94.sdf
# Minimizando C39303066_mmff94.sdf
# Minimizando C39324646_mmff94.sdf
# Minimizando C39326969_mmff94.sdf
# Minimizando C39327001_mmff94.sdf
# Minimizando C39327053_mmff94.sdf
# Minimizando C39335357_mmff94.sdf
# Minimizando C39335369_mmff94.sdf
# Minimizando C39336686_mmff94.sdf
# Minimizando C39337489_mmff94.sdf
# Minimizando C39344642_mmff94.sdf
# Minimizando C39358546_mmff94.sdf
# Minimizando C39361610_mmff94.sdf
# Minimizando C39361870_mmff94.sdf
# Minimizando C39362303_mmff94.sdf
# Minimizando C39370426_mmff94.sdf
# Minimizando C39412407_mmff94.sdf
# Minimizando C39438433_mmff94.sdf
# Minimizando C39440502_mmff94.sdf
# Minimizando C39445978_mmff94.sdf
# Minimizando C39449492_mmff94.sdf
# Minimizando C39451504_mmff94.sdf
# Minimizando C39451696_mmff94.sdf
# Minimizando C39462174_mmff94.sdf
# Minimizando C39467231_mmff94.sdf
# Minimizando C39467420_mmff94.sdf
# Minimizando C39467475_mmff94.sdf
# Minimizando C39467577_mmff94.sdf
# Minimizando C39467580_mmff94.sdf
# Minimizando C39468306_mmff94.sdf
# Minimizando C39469516_mmff94.sdf
# Minimizando C39482131_mmff94.sdf
# Minimizando C39505153_mmff94.sdf
# Minimizando C39516296_mmff94.sdf
# Minimizando C39531560_mmff94.sdf
# Minimizando C39532854_mmff94.sdf
# Minimizando C39533482_mmff94.sdf
# Minimizando C39533674_mmff94.sdf
# Minimizando C39545413_mmff94.sdf
# Minimizando C39549110_mmff94.sdf
# Minimizando C39558636_mmff94.sdf
# Minimizando C39558977_mmff94.sdf
# Minimizando C39559747_mmff94.sdf
# Minimizando C39561242_mmff94.sdf
# Minimizando C39575061_mmff94.sdf
# Minimizando C39578338_mmff94.sdf
# Minimizando C39579406_mmff94.sdf
# Minimizando C39594847_mmff94.sdf
# Minimizando C39596382_mmff94.sdf
# Minimizando C39604919_mmff94.sdf
# Minimizando C39605168_mmff94.sdf
# Minimizando C39605208_mmff94.sdf
# Minimizando C39605351_mmff94.sdf
# Minimizando C39605419_mmff94.sdf
# Minimizando C39605469_mmff94.sdf
# Minimizando C39605530_mmff94.sdf
# Minimizando C39607778_mmff94.sdf
# Minimizando C39609039_mmff94.sdf
# Minimizando C39609278_mmff94.sdf
# Minimizando C39609320_mmff94.sdf
# Minimizando C39609766_mmff94.sdf
# Minimizando C39610979_mmff94.sdf
# Minimizando C39610980_mmff94.sdf
# Minimizando C39617704_mmff94.sdf
# Minimizando C39624575_mmff94.sdf
# Minimizando C39625675_mmff94.sdf
# Minimizando C39628645_mmff94.sdf
# Minimizando C39636299_mmff94.sdf
# Minimizando C39637429_mmff94.sdf
# Minimizando C39638248_mmff94.sdf
# Minimizando C39638249_mmff94.sdf
# Minimizando C39638701_mmff94.sdf
# Minimizando C39638742_mmff94.sdf
# Minimizando C39639052_mmff94.sdf
# Minimizando C39639177_mmff94.sdf
# Minimizando C39639383_mmff94.sdf
# Minimizando C39653027_mmff94.sdf
# Minimizando C39653136_mmff94.sdf
# Minimizando C39656095_mmff94.sdf
# Minimizando C39656232_mmff94.sdf
# Minimizando C39657558_mmff94.sdf
# Minimizando C39659263_mmff94.sdf
# Minimizando C39659581_mmff94.sdf
# Minimizando C39659620_mmff94.sdf
# Minimizando C39661792_mmff94.sdf
# Minimizando C39662551_mmff94.sdf
# Minimizando C39662943_mmff94.sdf
# Minimizando C39663193_mmff94.sdf
# Minimizando C39663231_mmff94.sdf
# Minimizando C39663240_mmff94.sdf
# Minimizando C39663241_mmff94.sdf
# Minimizando C39663242_mmff94.sdf
# Minimizando C39663244_mmff94.sdf
# Minimizando C39664131_mmff94.sdf
# Minimizando C39664133_mmff94.sdf
# Minimizando C39664243_mmff94.sdf
# Minimizando C39664482_mmff94.sdf
# Minimizando C39664489_mmff94.sdf
# Minimizando C39665160_mmff94.sdf
# Minimizando C39665804_mmff94.sdf
# Minimizando C39666213_mmff94.sdf
# Minimizando C39666636_mmff94.sdf
# Minimizando C39667130_mmff94.sdf
# Minimizando C39667131_mmff94.sdf
# Minimizando C39669013_mmff94.sdf
# Minimizando C39669608_mmff94.sdf
# Minimizando C39669959_mmff94.sdf
# Minimizando C39670107_mmff94.sdf
# Minimizando C39670122_mmff94.sdf
# Minimizando C39670194_mmff94.sdf
# Minimizando C39670245_mmff94.sdf
# Minimizando C39670251_mmff94.sdf
# Minimizando C39670470_mmff94.sdf
# Minimizando C39670612_mmff94.sdf
# Minimizando C39670787_mmff94.sdf
# Minimizando C39671021_mmff94.sdf
# Minimizando C39671077_mmff94.sdf
# Minimizando C39671278_mmff94.sdf
# Minimizando C39671519_mmff94.sdf
# Minimizando C39671609_mmff94.sdf
# Minimizando C39672551_mmff94.sdf
# Minimizando C39672610_mmff94.sdf
# Minimizando C39672625_mmff94.sdf
# Minimizando C39672890_mmff94.sdf
# Minimizando C39673401_mmff94.sdf
# Minimizando C39673419_mmff94.sdf
# Minimizando C39674064_mmff94.sdf
# Minimizando C39674068_mmff94.sdf
# Minimizando C39674784_mmff94.sdf
# Minimizando C39674785_mmff94.sdf
# Minimizando C39674851_mmff94.sdf
# Minimizando C39675113_mmff94.sdf
# Minimizando C39676252_mmff94.sdf
# Minimizando C39676288_mmff94.sdf
# Minimizando C39676295_mmff94.sdf
# Minimizando C39676320_mmff94.sdf
# Minimizando C39676549_mmff94.sdf
# Minimizando C39677270_mmff94.sdf
# Minimizando C39677450_mmff94.sdf
# Minimizando C39677501_mmff94.sdf
# Minimizando C39680642_mmff94.sdf
# Minimizando C39680643_mmff94.sdf
# Minimizando C39681125_mmff94.sdf
# Minimizando C39681351_mmff94.sdf
# Minimizando C39681949_mmff94.sdf
# Minimizando C39682172_mmff94.sdf
# Minimizando C39683978_mmff94.sdf
# Minimizando C39683998_mmff94.sdf
# Minimizando C39684194_mmff94.sdf
# Minimizando C39684617_mmff94.sdf
# Minimizando C39685463_mmff94.sdf
# Minimizando C39685775_mmff94.sdf
# Minimizando C39685798_mmff94.sdf
# Minimizando C39685899_mmff94.sdf
# Minimizando C39687097_mmff94.sdf
# Minimizando C39688303_mmff94.sdf
# Minimizando C39688619_mmff94.sdf
# Minimizando C39688621_mmff94.sdf
# Minimizando C39689196_mmff94.sdf
# Minimizando C39693433_mmff94.sdf
# Minimizando C39693459_mmff94.sdf
# Minimizando C39693497_mmff94.sdf
# Minimizando C39693502_mmff94.sdf
# Minimizando C39693540_mmff94.sdf
# Minimizando C39693574_mmff94.sdf
# Minimizando C39693577_mmff94.sdf
# Minimizando C39694102_mmff94.sdf
# Minimizando C39694112_mmff94.sdf
# Minimizando C39694113_mmff94.sdf
# Minimizando C39694203_mmff94.sdf
# Minimizando C39694514_mmff94.sdf
# Minimizando C39696245_mmff94.sdf
# Minimizando C39696808_mmff94.sdf
# Minimizando C39698058_mmff94.sdf
# Minimizando C39709417_mmff94.sdf
# Minimizando C39724736_mmff94.sdf
# Minimizando C39726421_mmff94.sdf
# Minimizando C39733258_mmff94.sdf
# Minimizando C39749598_mmff94.sdf
# Minimizando C39751585_mmff94.sdf
# Minimizando C39763551_mmff94.sdf
# Minimizando C39771556_mmff94.sdf
# Minimizando C39782259_mmff94.sdf
# Minimizando C39792459_mmff94.sdf
# Minimizando C39840960_mmff94.sdf
# Minimizando C39841006_mmff94.sdf
# Minimizando C39841012_mmff94.sdf
# Minimizando C39841118_mmff94.sdf
# Minimizando C39899588_mmff94.sdf
# Minimizando C39918935_mmff94.sdf
# Minimizando C39918981_mmff94.sdf
# Minimizando C39927330_mmff94.sdf
# Minimizando C39934495_mmff94.sdf
# Minimizando C39936308_mmff94.sdf
# Minimizando C39938710_mmff94.sdf
# Minimizando C39940569_mmff94.sdf
# Minimizando C39945876_mmff94.sdf
# Minimizando C39946772_mmff94.sdf
# Minimizando C39946773_mmff94.sdf
# Minimizando C39949540_mmff94.sdf
# Minimizando C39955816_mmff94.sdf
# Minimizando C39957276_mmff94.sdf
# Minimizando C39980726_mmff94.sdf
# Minimizando C39992496_mmff94.sdf
# Minimizando C39998772_mmff94.sdf
# Minimizando C39998859_mmff94.sdf
# Minimizando C40011625_mmff94.sdf
# Minimizando C40024827_mmff94.sdf
# Minimizando C40033636_mmff94.sdf
# Minimizando C40034162_mmff94.sdf
# Minimizando C40067797_mmff94.sdf
# Minimizando C40084352_mmff94.sdf
# Minimizando C40091204_mmff94.sdf
# Minimizando C40097217_mmff94.sdf
# Minimizando C40117809_mmff94.sdf
# Minimizando C40144200_mmff94.sdf
# Minimizando C40156283_mmff94.sdf
# Minimizando C40158628_mmff94.sdf
# Minimizando C40234514_mmff94.sdf
# Minimizando C40290614_mmff94.sdf
# Minimizando C40291919_mmff94.sdf
# Minimizando C40291929_mmff94.sdf
# Minimizando C40291930_mmff94.sdf
# Minimizando C40301966_mmff94.sdf
# Minimizando C40302264_mmff94.sdf
# Minimizando C40307515_mmff94.sdf
# Minimizando C40334301_mmff94.sdf
# Minimizando C40334409_mmff94.sdf
# Minimizando C40347175_mmff94.sdf
# Minimizando C40348076_mmff94.sdf
# Minimizando C40363779_mmff94.sdf
# Minimizando C40369228_mmff94.sdf
# Minimizando C40372349_mmff94.sdf
# Minimizando C40376143_mmff94.sdf
# Minimizando C40376483_mmff94.sdf
# Minimizando C40377039_mmff94.sdf
# Minimizando C40377120_mmff94.sdf
# Minimizando C40384373_mmff94.sdf
# Minimizando C40387204_mmff94.sdf
# Minimizando C40388644_mmff94.sdf
# Minimizando C40390427_mmff94.sdf
# Minimizando C40396991_mmff94.sdf
# Minimizando C40399227_mmff94.sdf
# Minimizando C40399747_mmff94.sdf
# Minimizando C40410690_mmff94.sdf
# Minimizando C40464259_mmff94.sdf
# Minimizando C40470882_mmff94.sdf
# Minimizando C40549838_mmff94.sdf
# Minimizando C40674209_mmff94.sdf
# Minimizando C40674210_mmff94.sdf
# Minimizando C40686917_mmff94.sdf
# Minimizando C40713397_mmff94.sdf
# Minimizando C40729220_mmff94.sdf
# Minimizando C40729964_mmff94.sdf
# Minimizando C40733213_mmff94.sdf
# Minimizando C40734560_mmff94.sdf
# Minimizando C40735114_mmff94.sdf
# Minimizando C40744339_mmff94.sdf
# ...
# Minimizando C56862541_mmff94.sdf
# Minimizando C56875361_mmff94.sdf
# Minimizando C57028380_mmff94.sdf
# Minimizando C57037714_mmff94.sdf
# Minimizando C57142871_mmff94.sdf
# Minimizando C57267772_mmff94.sdf
# Minimizando C57292271_mmff94.sdf
# Minimizando C57329577_mmff94.sdf
# Minimizando C57346334_mmff94.sdf
# Minimizando C57395433_mmff94.sdf
# Minimizando C57481622_mmff94.sdf
# Minimizando C57566538_mmff94.sdf
# Minimizando C57663355_mmff94.sdf
# Minimizando C57698798_mmff94.sdf
# Minimizando C57850222_mmff94.sdf
# Minimizando C57952040_mmff94.sdf
# Minimizando C57952048_mmff94.sdf
# Minimizando C58012928_mmff94.sdf
# Minimizando C58012930_mmff94.sdf
# Minimizando C58038616_mmff94.sdf
# Minimizando C58139961_mmff94.sdf
# Minimizando C58156955_mmff94.sdf
# Minimizando C58236959_mmff94.sdf
# Minimizando C58246828_mmff94.sdf
# Minimizando C58289916_mmff94.sdf
# Minimizando C58369306_mmff94.sdf
# Minimizando C58385565_mmff94.sdf
# Minimizando C58386257_mmff94.sdf
# Minimizando C58530864_mmff94.sdf
# Minimizando C58756990_mmff94.sdf
# Minimizando C58775456_mmff94.sdf
# Minimizando C58846951_mmff94.sdf
# Minimizando C58853715_mmff94.sdf
# Minimizando C58880658_mmff94.sdf
# Minimizando C58880695_mmff94.sdf
# Minimizando C58887293_mmff94.sdf
# Minimizando C58900060_mmff94.sdf
# Minimizando C58912583_mmff94.sdf
# Minimizando C58946119_mmff94.sdf
# Minimizando C58949045_mmff94.sdf
# Minimizando C58995024_mmff94.sdf
# Minimizando C59016887_mmff94.sdf
# Minimizando C59016998_mmff94.sdf
# Minimizando C59022158_mmff94.sdf
# Minimizando C59038227_mmff94.sdf
# Minimizando C59087478_mmff94.sdf
# Minimizando C59092474_mmff94.sdf
# Minimizando C59106204_mmff94.sdf
# Minimizando C59152069_mmff94.sdf
# Minimizando C59170143_mmff94.sdf
# Minimizando C59170369_mmff94.sdf
# Minimizando C59280244_mmff94.sdf
# Minimizando C59293280_mmff94.sdf
# Minimizando C59307055_mmff94.sdf
# Minimizando C59309563_mmff94.sdf
# Minimizando C59323962_mmff94.sdf
# Minimizando C59368429_mmff94.sdf
# Minimizando C59373826_mmff94.sdf
# Minimizando C59435031_mmff94.sdf
# Minimizando C59437464_mmff94.sdf
# Minimizando C59503388_mmff94.sdf
# Minimizando C59503589_mmff94.sdf
# Minimizando C59520321_mmff94.sdf
# Minimizando C59669476_mmff94.sdf
# Minimizando C59679004_mmff94.sdf
# Minimizando C59816596_mmff94.sdf
# Minimizando C59825673_mmff94.sdf
# Minimizando C59882810_mmff94.sdf
# Minimizando C59883305_mmff94.sdf
# Minimizando C59890413_mmff94.sdf
# Minimizando C59915206_mmff94.sdf
# Minimizando C59916344_mmff94.sdf
# Minimizando C60042055_mmff94.sdf
# Minimizando C60100722_mmff94.sdf
# Minimizando C60126392_mmff94.sdf
# Minimizando C60132145_mmff94.sdf
# Minimizando C60157633_mmff94.sdf
# Minimizando C60158206_mmff94.sdf
# Minimizando C60208467_mmff94.sdf
# Minimizando C60213639_mmff94.sdf
# Minimizando C60243428_mmff94.sdf
# Minimizando C60370764_mmff94.sdf
# Minimizando C60374718_mmff94.sdf
# Minimizando C60916804_mmff94.sdf
# Minimizando C60992888_mmff94.sdf
# Minimizando C61001960_mmff94.sdf
# Minimizando C61189964_mmff94.sdf
# Minimizando C61320732_mmff94.sdf
# Minimizando C61473905_mmff94.sdf
# Minimizando C61539520_mmff94.sdf
# Minimizando C61592267_mmff94.sdf
# Minimizando C61592445_mmff94.sdf
# Minimizando C61608359_mmff94.sdf
# Minimizando C61619677_mmff94.sdf
# Minimizando C61632408_mmff94.sdf
# Minimizando C61678220_mmff94.sdf
# Minimizando C61681335_mmff94.sdf
# Minimizando C61685438_mmff94.sdf
# Minimizando C61706115_mmff94.sdf
# Minimizando C61706118_mmff94.sdf
# Minimizando C61713326_mmff94.sdf
# Minimizando C61767071_mmff94.sdf
# Minimizando C61770043_mmff94.sdf
# Minimizando C61808910_mmff94.sdf
# Minimizando C61822737_mmff94.sdf
# Minimizando C61832480_mmff94.sdf
# Minimizando C61843556_mmff94.sdf
# Minimizando C61844929_mmff94.sdf
# Minimizando C61856092_mmff94.sdf
# Minimizando C61858981_mmff94.sdf
# Minimizando C61865748_mmff94.sdf
# Minimizando C61911507_mmff94.sdf
# Minimizando C61912374_mmff94.sdf
# Minimizando C61912451_mmff94.sdf
# Minimizando C61998771_mmff94.sdf
# Minimizando C62102096_mmff94.sdf
# Minimizando C62123066_mmff94.sdf
# Minimizando C62235151_mmff94.sdf
# Minimizando C62297419_mmff94.sdf
# Minimizando C62320993_mmff94.sdf
# Minimizando C62364230_mmff94.sdf
# Minimizando C62365009_mmff94.sdf
# Minimizando C62369842_mmff94.sdf
# Minimizando C62462984_mmff94.sdf
# Minimizando C62496733_mmff94.sdf
# Minimizando C62497166_mmff94.sdf
# Minimizando C62497208_mmff94.sdf
# Minimizando C62498220_mmff94.sdf
# Minimizando C62504956_mmff94.sdf
# Minimizando C62609821_mmff94.sdf
# Minimizando C62704714_mmff94.sdf
# Minimizando C62744126_mmff94.sdf
# Minimizando C62744127_mmff94.sdf
# Minimizando C62766428_mmff94.sdf
# Minimizando C62766431_mmff94.sdf
# Minimizando C62789167_mmff94.sdf
# Minimizando C62789194_mmff94.sdf
# Minimizando C62789297_mmff94.sdf
# Minimizando C62812081_mmff94.sdf
# Minimizando C62827846_mmff94.sdf
# Minimizando C62827870_mmff94.sdf
# Minimizando C62828018_mmff94.sdf
# Minimizando C62828359_mmff94.sdf
# Minimizando C62828372_mmff94.sdf
# Minimizando C62846737_mmff94.sdf
# Minimizando C62934713_mmff94.sdf
# Minimizando C62943469_mmff94.sdf
# Minimizando C62960011_mmff94.sdf
# Minimizando C62960563_mmff94.sdf
# Minimizando C63020721_mmff94.sdf
# Minimizando C63090032_mmff94.sdf
# Minimizando C63096950_mmff94.sdf
# Minimizando C63097723_mmff94.sdf
# Minimizando C63102744_mmff94.sdf
# Minimizando C63102958_mmff94.sdf
# Minimizando C63141504_mmff94.sdf
# Minimizando C63147531_mmff94.sdf
# Minimizando C63162068_mmff94.sdf
# Minimizando C63162962_mmff94.sdf
# Minimizando C63182768_mmff94.sdf
# Minimizando C63205565_mmff94.sdf
# Minimizando C63216225_mmff94.sdf
# Minimizando C63230239_mmff94.sdf
# Minimizando C63279469_mmff94.sdf
# Minimizando C63282870_mmff94.sdf
# Minimizando C63296267_mmff94.sdf
# Minimizando C63303079_mmff94.sdf
# Minimizando C63314841_mmff94.sdf
# Minimizando C63317427_mmff94.sdf
# Minimizando C63339561_mmff94.sdf
# Minimizando C63361980_mmff94.sdf
# Minimizando C63362653_mmff94.sdf
# Minimizando C63362778_mmff94.sdf
# Minimizando C63373364_mmff94.sdf
# Minimizando C63373366_mmff94.sdf
# Minimizando C63373370_mmff94.sdf
# Minimizando C63373627_mmff94.sdf
# Minimizando C63374648_mmff94.sdf
# Minimizando C63374752_mmff94.sdf
# Minimizando C63375422_mmff94.sdf
# Minimizando C63375837_mmff94.sdf
# Minimizando C63383452_mmff94.sdf
# Minimizando C63383624_mmff94.sdf
# Minimizando C63384363_mmff94.sdf
# Minimizando C63399333_mmff94.sdf
# Minimizando C63407625_mmff94.sdf
# Minimizando C63426767_mmff94.sdf
# Minimizando C63448210_mmff94.sdf
# Minimizando C63465577_mmff94.sdf
# Minimizando C63473072_mmff94.sdf
# Minimizando C63478742_mmff94.sdf
# Minimizando C63479921_mmff94.sdf
# Minimizando C63479932_mmff94.sdf
# Minimizando C63479934_mmff94.sdf
# Minimizando C63479935_mmff94.sdf
# Minimizando C63492299_mmff94.sdf
# Minimizando C63492853_mmff94.sdf
# Minimizando C63492855_mmff94.sdf
# Minimizando C63492859_mmff94.sdf
# Minimizando C63501973_mmff94.sdf
# Minimizando C63506871_mmff94.sdf
# Minimizando C63529044_mmff94.sdf
# Minimizando C63537948_mmff94.sdf
# Minimizando C63537953_mmff94.sdf
# Minimizando C63537967_mmff94.sdf
# Minimizando C63546948_mmff94.sdf
# Minimizando C63547030_mmff94.sdf
# Minimizando C63547041_mmff94.sdf
# Minimizando C63558260_mmff94.sdf
# Minimizando C63626084_mmff94.sdf
# Minimizando C63641866_mmff94.sdf
# Minimizando C63641868_mmff94.sdf
# Minimizando C63646760_mmff94.sdf
# Minimizando C63663935_mmff94.sdf
# Minimizando C63666745_mmff94.sdf
# Minimizando C63666772_mmff94.sdf
# Minimizando C63679641_mmff94.sdf
# Minimizando C63683817_mmff94.sdf
# Minimizando C63690787_mmff94.sdf
# Minimizando C63690790_mmff94.sdf
# Minimizando C63709318_mmff94.sdf
# Minimizando C63709753_mmff94.sdf
# Minimizando C63737644_mmff94.sdf
# Minimizando C63803866_mmff94.sdf
# Minimizando C63807620_mmff94.sdf
# Minimizando C63818916_mmff94.sdf
# Minimizando C63825310_mmff94.sdf
# Minimizando C63825314_mmff94.sdf
# Minimizando C63830545_mmff94.sdf
# Minimizando C63830600_mmff94.sdf
# Minimizando C63830790_mmff94.sdf
# Minimizando C63831271_mmff94.sdf
# Minimizando C63836087_mmff94.sdf
# Minimizando C63855249_mmff94.sdf
# Minimizando C63874061_mmff94.sdf
# Minimizando C63899644_mmff94.sdf
# Minimizando C63907071_mmff94.sdf
# Minimizando C63933355_mmff94.sdf
# Minimizando C63933777_mmff94.sdf
# Minimizando C63941209_mmff94.sdf
# Minimizando C63985273_mmff94.sdf
# Minimizando C64015023_mmff94.sdf
# Minimizando C64015086_mmff94.sdf
# Minimizando C64055370_mmff94.sdf
# Minimizando C64081777_mmff94.sdf
# Minimizando C64097879_mmff94.sdf
# Minimizando C64097983_mmff94.sdf
# Minimizando C64097984_mmff94.sdf
# Minimizando C64098016_mmff94.sdf
# Minimizando C64104215_mmff94.sdf
# Minimizando C64137634_mmff94.sdf
# Minimizando C64152495_mmff94.sdf
# Minimizando C64164328_mmff94.sdf
# Minimizando C64164331_mmff94.sdf
# Minimizando C64197790_mmff94.sdf
# Minimizando C64220383_mmff94.sdf
# Minimizando C64220384_mmff94.sdf
# Minimizando C64228641_mmff94.sdf
# Minimizando C64291076_mmff94.sdf
# Minimizando C64305278_mmff94.sdf
# Minimizando C64428214_mmff94.sdf
# Minimizando C64435864_mmff94.sdf
# Minimizando C64450346_mmff94.sdf
# Minimizando C64450876_mmff94.sdf
# Minimizando C64450877_mmff94.sdf
# Minimizando C64480290_mmff94.sdf
# Minimizando C64502579_mmff94.sdf
# Minimizando C64517337_mmff94.sdf
# Minimizando C64517341_mmff94.sdf
# Minimizando C64519995_mmff94.sdf
# Minimizando C64534955_mmff94.sdf
# Minimizando C64540132_mmff94.sdf
# Minimizando C64568649_mmff94.sdf
# Minimizando C64600259_mmff94.sdf
# Minimizando C64637523_mmff94.sdf
# Minimizando C64637524_mmff94.sdf
# Minimizando C64652783_mmff94.sdf
# Minimizando C64717885_mmff94.sdf
# Minimizando C64717891_mmff94.sdf
# Minimizando C64718320_mmff94.sdf
# Minimizando C64788507_mmff94.sdf
# Minimizando C64788511_mmff94.sdf
# Minimizando C64806210_mmff94.sdf
# Minimizando C64819178_mmff94.sdf
# Minimizando C64858083_mmff94.sdf
# Minimizando C64870236_mmff94.sdf
# Minimizando C64890992_mmff94.sdf
# Minimizando C64891186_mmff94.sdf
# Minimizando C64891188_mmff94.sdf
# Minimizando C64926403_mmff94.sdf
# Minimizando C64960851_mmff94.sdf
# Minimizando C65021742_mmff94.sdf
# Minimizando C65021902_mmff94.sdf
# Minimizando C65101206_mmff94.sdf
# Minimizando C65133920_mmff94.sdf
# Minimizando C65135403_mmff94.sdf
# Minimizando C65136714_mmff94.sdf
# Minimizando C65142676_mmff94.sdf
# Minimizando C65146163_mmff94.sdf
# Minimizando C65181997_mmff94.sdf
# Minimizando C65182015_mmff94.sdf
# Minimizando C65182016_mmff94.sdf
# Minimizando C65182741_mmff94.sdf
# Minimizando C65202978_mmff94.sdf
# Minimizando C65257732_mmff94.sdf
# Minimizando C65260724_mmff94.sdf
# Minimizando C65308535_mmff94.sdf
# Minimizando C65329703_mmff94.sdf
# Minimizando C65360131_mmff94.sdf
# Minimizando C65365285_mmff94.sdf
# Minimizando C65373509_mmff94.sdf
# Minimizando C65382625_mmff94.sdf
# Minimizando C65385083_mmff94.sdf
# Minimizando C65399175_mmff94.sdf
# Minimizando C65404940_mmff94.sdf
# Minimizando C65406166_mmff94.sdf
# Minimizando C65461026_mmff94.sdf
# Minimizando C65461998_mmff94.sdf
# Minimizando C65482401_mmff94.sdf
# Minimizando C65482852_mmff94.sdf
# Minimizando C65483163_mmff94.sdf
# Minimizando C65490234_mmff94.sdf
# Minimizando C65499076_mmff94.sdf
# Minimizando C65510313_mmff94.sdf
# Minimizando C65525878_mmff94.sdf
# Minimizando C65531809_mmff94.sdf
# Minimizando C65533074_mmff94.sdf
# Minimizando C65552670_mmff94.sdf
# Minimizando C65577758_mmff94.sdf
# Minimizando C65578504_mmff94.sdf
# Minimizando C65591169_mmff94.sdf
# Minimizando C65602226_mmff94.sdf
# Minimizando C65696240_mmff94.sdf
# Minimizando C65734329_mmff94.sdf
# Minimizando C65734332_mmff94.sdf
# Minimizando C65771837_mmff94.sdf
# Minimizando C65933126_mmff94.sdf
# Minimizando C65946228_mmff94.sdf
# Minimizando C65988965_mmff94.sdf
# Minimizando C66057741_mmff94.sdf
# Minimizando C66100766_mmff94.sdf
# Minimizando C66135910_mmff94.sdf
# Minimizando C66135945_mmff94.sdf
# Minimizando C66136159_mmff94.sdf
# Minimizando C66152755_mmff94.sdf
# Minimizando C66179974_mmff94.sdf
# Minimizando C66187621_mmff94.sdf
# Minimizando C66195188_mmff94.sdf
# Minimizando C66203165_mmff94.sdf
# Minimizando C66203166_mmff94.sdf
# Minimizando C66204895_mmff94.sdf
# Minimizando C66213058_mmff94.sdf
# Minimizando C66214462_mmff94.sdf
# Minimizando C66242281_mmff94.sdf
# Minimizando C66242894_mmff94.sdf
# Minimizando C66243664_mmff94.sdf
# Minimizando C66243860_mmff94.sdf
# Minimizando C66243909_mmff94.sdf
# Minimizando C66246527_mmff94.sdf
# Minimizando C66246976_mmff94.sdf
# Minimizando C66262937_mmff94.sdf
# Minimizando C66262939_mmff94.sdf
# Minimizando C66327028_mmff94.sdf
# Minimizando C66327830_mmff94.sdf
# Minimizando C66338764_mmff94.sdf
# Minimizando C66390199_mmff94.sdf
# Minimizando C66396556_mmff94.sdf
# Minimizando C66396557_mmff94.sdf
# Minimizando C66402792_mmff94.sdf
# Minimizando C66426957_mmff94.sdf
# Minimizando C66456615_mmff94.sdf
# Minimizando C66470856_mmff94.sdf
# Minimizando C66497133_mmff94.sdf
# Minimizando C66571468_mmff94.sdf
# Minimizando C66584786_mmff94.sdf
# Minimizando C66591939_mmff94.sdf
# Minimizando C66593800_mmff94.sdf
# Minimizando C66597539_mmff94.sdf
# Minimizando C66597662_mmff94.sdf
# Minimizando C66599530_mmff94.sdf
# Minimizando C66599555_mmff94.sdf
# Minimizando C66602747_mmff94.sdf
# Minimizando C66616915_mmff94.sdf
# Minimizando C66619879_mmff94.sdf
# Minimizando C66631199_mmff94.sdf
# Minimizando C66647038_mmff94.sdf
# Minimizando C66651191_mmff94.sdf
# Minimizando C66651193_mmff94.sdf
# Minimizando C66671297_mmff94.sdf
# Minimizando C66682133_mmff94.sdf
# Minimizando C66682310_mmff94.sdf
# Minimizando C66684536_mmff94.sdf
# Minimizando C66702748_mmff94.sdf
# Minimizando C66714286_mmff94.sdf
# Minimizando C66714326_mmff94.sdf
# Minimizando C66827860_mmff94.sdf
# Minimizando C66876465_mmff94.sdf
# Minimizando C66899225_mmff94.sdf
# Minimizando C66899999_mmff94.sdf
# Minimizando C66906262_mmff94.sdf
# Minimizando C66939192_mmff94.sdf
# Minimizando C66939652_mmff94.sdf
# Minimizando C66956376_mmff94.sdf
# Minimizando C66967150_mmff94.sdf
# Minimizando C66971908_mmff94.sdf
# Minimizando C66981212_mmff94.sdf
# Minimizando C67017519_mmff94.sdf
# Minimizando C67028437_mmff94.sdf
# Minimizando C67028456_mmff94.sdf
# Minimizando C67031406_mmff94.sdf
# Minimizando C67049917_mmff94.sdf
# Minimizando C67062067_mmff94.sdf
# Minimizando C67063629_mmff94.sdf
# Minimizando C67064357_mmff94.sdf
# Minimizando C67100880_mmff94.sdf
# Minimizando C67102468_mmff94.sdf
# Minimizando C67104237_mmff94.sdf
# Minimizando C67104511_mmff94.sdf
# Minimizando C67125649_mmff94.sdf
# Minimizando C67125652_mmff94.sdf
# Minimizando C67130429_mmff94.sdf
# Minimizando C67130430_mmff94.sdf
# Minimizando C67145084_mmff94.sdf
# Minimizando C67163484_mmff94.sdf
# Minimizando C67163485_mmff94.sdf
# Minimizando C67173817_mmff94.sdf
# Minimizando C67193173_mmff94.sdf
# Minimizando C67193419_mmff94.sdf
# Minimizando C67237555_mmff94.sdf
# Minimizando C67247637_mmff94.sdf
# Minimizando C67275664_mmff94.sdf
# Minimizando C67286761_mmff94.sdf
# Minimizando C67287779_mmff94.sdf
# Minimizando C67304061_mmff94.sdf
# Minimizando C67317349_mmff94.sdf
# Minimizando C67330843_mmff94.sdf
# Minimizando C67348607_mmff94.sdf
# Minimizando C67352798_mmff94.sdf
# Minimizando C67381680_mmff94.sdf
# Minimizando C67382688_mmff94.sdf
# Minimizando C67382911_mmff94.sdf
# Minimizando C67389366_mmff94.sdf
# Minimizando C67390126_mmff94.sdf
# Minimizando C67390736_mmff94.sdf
# Minimizando C67406929_mmff94.sdf
# Minimizando C67407800_mmff94.sdf
# Minimizando C67408030_mmff94.sdf
# Minimizando C67410131_mmff94.sdf
# Minimizando C67411380_mmff94.sdf
# Minimizando C67412229_mmff94.sdf
# Minimizando C67412452_mmff94.sdf
# Minimizando C67414887_mmff94.sdf
# Minimizando C67420625_mmff94.sdf
# Minimizando C67426391_mmff94.sdf
# Minimizando C67444032_mmff94.sdf
# Minimizando C67449528_mmff94.sdf
# Minimizando C67456857_mmff94.sdf
# Minimizando C67459848_mmff94.sdf
# Minimizando C67463011_mmff94.sdf
# Minimizando C67463606_mmff94.sdf
# Minimizando C67465362_mmff94.sdf
# Minimizando C67466006_mmff94.sdf
# Minimizando C67469278_mmff94.sdf
# Minimizando C67504122_mmff94.sdf
# Minimizando C67525245_mmff94.sdf
# Minimizando C67557895_mmff94.sdf
# Minimizando C67561196_mmff94.sdf
# Minimizando C67570665_mmff94.sdf
# Minimizando C67570964_mmff94.sdf
# Minimizando C67590756_mmff94.sdf
# Minimizando C67606536_mmff94.sdf
# Minimizando C67609600_mmff94.sdf
# Minimizando C67610390_mmff94.sdf
# Minimizando C67611801_mmff94.sdf
# Minimizando C67611805_mmff94.sdf
# Minimizando C67616008_mmff94.sdf
# Minimizando C67618869_mmff94.sdf
# Minimizando C67626970_mmff94.sdf
# Minimizando C67627565_mmff94.sdf
# Minimizando C67630026_mmff94.sdf
# Minimizando C67631904_mmff94.sdf
# Minimizando C67632321_mmff94.sdf
# Minimizando C67633529_mmff94.sdf
# Minimizando C67643346_mmff94.sdf

# %%
#Mover los archivos .sdf minimizados y no minimizados a sus respectivas carpetas 
os.system('mkdir ligandos_minimizados')
os.system('mv *_mmff94.sdf > ligandos_minimizados')
os.system('mkdir ligandos_no_minimizados')
os.system('mkdir picked_decoys')
os.system('mv *.sdf > picked_decoys')

#creacion a mano de carpeta subconjunto_activos_decoys y ahi se guardó el subconjunto seleccionado
